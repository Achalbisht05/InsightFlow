# %% [markdown]
# # InsightFlow — Raw Data Exploration
#
# ## End-to-End E-Commerce Analytics & Data Engineering Platform
#
# ### Objective
# Analyze and understand the raw Olist e-commerce dataset before performing
# data cleaning, transformation, ETL, SQL analysis, and Power BI visualization.
#
# ### Dataset
# Brazilian E-Commerce Public Dataset by Olist

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\unknown\\OneDrive\\Desktop\\power bi project\\InsightFlow\\notebook'

# %%
orders = pd.read_csv(
    "../data/raw/olist_orders_dataset.csv"
)

# %%
orders.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06  2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39  2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# 1          2018-07-26 14:31:00           2018-08-07 15:27:45
# 2          2018-08-08 13:50:00           2018-08-17 18:06:29
# 3          2017-11-22 13:39:59           2017-12-02 00:28:42
# 4          2018-02-14 19:46:34           2018-02-16 18:17:02
#
#   order_estimated_delivery_date
# 0           2017-10-18 00:00:00
# 1           2018-08-13 00:00:00
# 2           2018-09-04 00:00:00
# 3           2017-12-15 00:00:00
# 4           2018-02-26 00:00:00

# %%
orders.shape
# Out:
# (99441, 8)

# %%
orders.columns
# Out:
# Index(['order_id', 'customer_id', 'order_status', 'order_purchase_timestamp',
#        'order_approved_at', 'order_delivered_carrier_date',
#        'order_delivered_customer_date', 'order_estimated_delivery_date'],
#       dtype='object')

# %%
orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       99441 non-null  object
#  1   customer_id                    99441 non-null  object
#  2   order_status                   99441 non-null  object
#  3   order_purchase_timestamp       99441 non-null  object
#  4   order_approved_at              99281 non-null  object
#  5   order_delivered_carrier_date   97658 non-null  object
#  6   order_delivered_customer_date  96476 non-null  object
#  7   order_estimated_delivery_date  99441 non-null  object
# dtypes: object(8)
# memory usage: 6.1+ MB

# %%
orders.isnull().sum()
# Out:
# order_id                            0
# customer_id                         0
# order_status                        0
# order_purchase_timestamp            0
# order_approved_at                 160
# order_delivered_carrier_date     1783
# order_delivered_customer_date    2965
# order_estimated_delivery_date       0
# dtype: int64

# %%
orders.duplicated().sum()
# Out:
# np.int64(0)

# %%
orders["order_id"].duplicated().sum()
# Out:
# np.int64(0)

# %%
orders["order_status"].value_counts()
# Out:
# order_status
# delivered      96478
# shipped         1107
# canceled         625
# unavailable      609
# invoiced         314
# processing       301
# created            5
# approved           2
# Name: count, dtype: int64

# %%
orders["order_purchase_timestamp"].min()
# Out:
# '2016-09-04 21:15:19'

# %%
orders["order_purchase_timestamp"].max()
# Out:
# '2018-10-17 17:30:18'

# %%
orders["order_id"].nunique()
# Out:
# 99441

# %%
len(orders) - orders["order_id"].nunique()
# Out:
# 0

# %%
orders["customer_id"].nunique()
# Out:
# 99441

# %%
orders["customer_id"].value_counts().head(10)
# Out:
# customer_id
# 9ef432eb6251297304e76186b10a928d    1
# b0830fb4747a6c6d20dea0b8c802d7ef    1
# 41ce2a54c0b03bf3443c3d931a367089    1
# f88197465ea7920adcdbec7375364d82    1
# 8ab97904e6daea8866dbdbc4fb7aad2c    1
# 503740e9ca751ccdda7ba28e9ab8f608    1
# ed0271e0b7da060a393796590e7b737a    1
# 9bdf08b4b3b52b5526ff42d37d47f222    1
# f54a9f0e6b351c431402b8461ea51999    1
# 31ad1d1b63eb9962463f764d4e6e0c9d    1
# Name: count, dtype: int64

# %%
orders["order_purchase_timestamp"].min()
# Out:
# '2016-09-04 21:15:19'

# %%
orders["order_purchase_timestamp"].max()
# Out:
# '2018-10-17 17:30:18'

# %%
status_percentage = (
    orders["order_status"]
    .value_counts(normalize=True)
    .mul(100)
    .round(2)
)

status_percentage
# Out:
# order_status
# delivered      97.02
# shipped         1.11
# canceled        0.63
# unavailable     0.61
# invoiced        0.32
# processing      0.30
# created         0.01
# approved        0.00
# Name: proportion, dtype: float64

# %%
customers = pd.read_csv(
    "../data/raw/olist_customers_dataset.csv"
)

# %%
customers.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
# 3                      8775        mogi das cruzes             SP
# 4                     13056               campinas             SP

# %%
customers.shape
# Out:
# (99441, 5)

# %%
customers.columns
# Out:
# Index(['customer_id', 'customer_unique_id', 'customer_zip_code_prefix',
#        'customer_city', 'customer_state'],
#       dtype='object')

# %%
customers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 5 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   customer_id               99441 non-null  object
#  1   customer_unique_id        99441 non-null  object
#  2   customer_zip_code_prefix  99441 non-null  int64
#  3   customer_city             99441 non-null  object
#  4   customer_state            99441 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 3.8+ MB

# %%
customers.isnull().sum()
# Out:
# customer_id                 0
# customer_unique_id          0
# customer_zip_code_prefix    0
# customer_city               0
# customer_state              0
# dtype: int64

# %%
customers.duplicated().sum()
# Out:
# np.int64(0)

# %%
customers["customer_id"].nunique()
# Out:
# 99441

# %%
len(customers)
# Out:
# 99441

# %%
customers["customer_id"].duplicated().sum()
# Out:
# np.int64(0)

# %%
customers["customer_unique_id"].nunique()
# Out:
# 96096

# %%
customers["customer_id"].duplicated().sum()
# Out:
# np.int64(0)

# %%
customers["customer_unique_id"].duplicated().sum()
# Out:
# np.int64(3345)

# %%
customers["customer_unique_id"].value_counts().head(10)
# Out:
# customer_unique_id
# 8d50f5eadf50201ccdcedfb9e2ac8455    17
# 3e43e6105506432c953e165fb2acf44c     9
# 6469f99c1f9dfae7733b25662e7f1782     7
# ca77025e7201e3b30c44b472ff346268     7
# 1b6c7548a2a1f9037c1fd3ddfed95f33     7
# 12f5d6e1cbf93dafd9dcc19095df0b3d     6
# dc813062e0fc23409cd255f7f53c7074     6
# 47c1a3033b8b77b3ab6e109eb4d5fdf3     6
# de34b16117594161a6a89c50b289d35a     6
# 63cfc61cee11cbe306bff5857d00bfe4     6
# Name: count, dtype: int64

# %%
customers["customer_state"].value_counts().head(10)
# Out:
# customer_state
# SP    41746
# RJ    12852
# MG    11635
# RS     5466
# PR     5045
# SC     3637
# BA     3380
# DF     2140
# ES     2033
# GO     2020
# Name: count, dtype: int64

# %%
customers["customer_city"].value_counts().head(10)
# Out:
# customer_city
# sao paulo                15540
# rio de janeiro            6882
# belo horizonte            2773
# brasilia                  2131
# curitiba                  1521
# campinas                  1444
# porto alegre              1379
# salvador                  1245
# guarulhos                 1189
# sao bernardo do campo      938
# Name: count, dtype: int64

# %%
order_items = pd.read_csv(
    "../data/raw/olist_order_items_dataset.csv"
)

# %%
order_items.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#    shipping_limit_date   price  freight_value
# 0  2017-09-19 09:45:35   58.90          13.29
# 1  2017-05-03 11:05:13  239.90          19.93
# 2  2018-01-18 14:48:30  199.00          17.87
# 3  2018-08-15 10:10:18   12.99          12.79
# 4  2017-02-13 13:57:51  199.90          18.14

# %%
order_items.shape
# Out:
# (112650, 7)

# %%
order_items.columns
# Out:
# Index(['order_id', 'order_item_id', 'product_id', 'seller_id',
#        'shipping_limit_date', 'price', 'freight_value'],
#       dtype='object')

# %%
order_items.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112650 entries, 0 to 112649
# Data columns (total 7 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   order_id             112650 non-null  object
#  1   order_item_id        112650 non-null  int64
#  2   product_id           112650 non-null  object
#  3   seller_id            112650 non-null  object
#  4   shipping_limit_date  112650 non-null  object
#  5   price                112650 non-null  float64
#  6   freight_value        112650 non-null  float64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 6.0+ MB

# %%
order_items.isnull().sum()
# Out:
# order_id               0
# order_item_id          0
# product_id             0
# seller_id              0
# shipping_limit_date    0
# price                  0
# freight_value          0
# dtype: int64

# %%
order_items.duplicated().sum()
# Out:
# np.int64(0)

# %%
order_items["order_id"].nunique()
# Out:
# 98666

# %%
order_items["product_id"].nunique()
# Out:
# 32951

# %%
order_items["seller_id"].nunique()
# Out:
# 3095

# %%
order_items["price"].describe()
# Out:
# count    112650.000000
# mean        120.653739
# std         183.633928
# min           0.850000
# 25%          39.900000
# 50%          74.990000
# 75%         134.900000
# max        6735.000000
# Name: price, dtype: float64

# %%
order_items["freight_value"].describe()
# Out:
# count    112650.000000
# mean         19.990320
# std          15.806405
# min           0.000000
# 25%          13.080000
# 50%          16.260000
# 75%          21.150000
# max         409.680000
# Name: freight_value, dtype: float64

# %%
order_items["item_total"] = (
    order_items["price"] +
    order_items["freight_value"]
)

# %%
order_items["item_total"].sum()
# Out:
# np.float64(15843553.24)

# %%
total_product_value = order_items["price"].sum()

print("Total Product Value:", total_product_value)
# Out:
# Total Product Value: 13591643.7

# %%
total_freight = order_items["freight_value"].sum()

print("Total Freight:", total_freight)
# Out:
# Total Freight: 2251909.54

# %%
print(
    "Product Value + Freight:",
    total_product_value + total_freight
)
# Out:
# Product Value + Freight: 15843553.239999998

# %%
order_items["item_total"].mean()
# Out:
# np.float64(140.6440589436307)

# %%
order_items["price"].mean()
# Out:
# np.float64(120.65373901464713)

# %%
order_items["freight_value"].mean()
# Out:
# np.float64(19.990319928983578)

# %%
print("Total Product Value:", order_items["price"].sum())
# Out:
# Total Product Value: 13591643.7

# %%
print("Total Freight:", order_items["freight_value"].sum())
# Out:
# Total Freight: 2251909.54

# %%
print("Average Product Price:", order_items["price"].mean())
# Out:
# Average Product Price: 120.65373901464713

# %%
print("Average Freight:", order_items["freight_value"].mean())
# Out:
# Average Freight: 19.990319928983578

# %%
print("Average Item Total:", order_items["item_total"].mean())
# Out:
# Average Item Total: 140.6440589436307

# %%
order_items.duplicated().sum()
# Out:
# np.int64(0)

# %%
freight_percentage = (
    order_items["freight_value"].sum()
    / order_items["item_total"].sum()
) * 100

print(f"Freight Percentage: {freight_percentage:.2f}%")
# Out:
# Freight Percentage: 14.21%

# %%
products = pd.read_csv(
    "../data/raw/olist_products_dataset.csv"
)

# %%
products.head()
# Out:
#                          product_id  product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                 40.0                       287.0                 1.0
# 1                 44.0                       276.0                 1.0
# 2                 46.0                       250.0                 1.0
# 3                 27.0                       261.0                 1.0
# 4                 37.0                       402.0                 4.0
#
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm
# 0             225.0               16.0               10.0              14.0
# 1            1000.0               30.0               18.0              20.0
# 2             154.0               18.0                9.0              15.0
# 3             371.0               26.0                4.0              26.0
# 4             625.0               20.0               17.0              13.0

# %%
products.shape
# Out:
# (32951, 9)

# %%
products.columns
# Out:
# Index(['product_id', 'product_category_name', 'product_name_lenght',
#        'product_description_lenght', 'product_photos_qty', 'product_weight_g',
#        'product_length_cm', 'product_height_cm', 'product_width_cm'],
#       dtype='object')

# %%
products.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32951 entries, 0 to 32950
# Data columns (total 9 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   product_id                  32951 non-null  object
#  1   product_category_name       32341 non-null  object
#  2   product_name_lenght         32341 non-null  float64
#  3   product_description_lenght  32341 non-null  float64
#  4   product_photos_qty          32341 non-null  float64
#  5   product_weight_g            32949 non-null  float64
#  6   product_length_cm           32949 non-null  float64
#  7   product_height_cm           32949 non-null  float64
#  8   product_width_cm            32949 non-null  float64
# dtypes: float64(7), object(2)
# memory usage: 2.3+ MB

# %%
products.isnull().sum()
# Out:
# product_id                      0
# product_category_name         610
# product_name_lenght           610
# product_description_lenght    610
# product_photos_qty            610
# product_weight_g                2
# product_length_cm               2
# product_height_cm               2
# product_width_cm                2
# dtype: int64

# %%
products.duplicated().sum()
# Out:
# np.int64(0)

# %%
products["product_id"].duplicated().sum()
# Out:
# np.int64(0)

# %%
products["product_id"].nunique()
# Out:
# 32951

# %%
products["product_category_name"].nunique()
# Out:
# 73

# %%
products["product_category_name"].value_counts().head(20)
# Out:
# product_category_name
# cama_mesa_banho                      3029
# esporte_lazer                        2867
# moveis_decoracao                     2657
# beleza_saude                         2444
# utilidades_domesticas                2335
# automotivo                           1900
# informatica_acessorios               1639
# brinquedos                           1411
# relogios_presentes                   1329
# telefonia                            1134
# bebes                                 919
# perfumaria                            868
# papelaria                             849
# fashion_bolsas_e_acessorios           849
# cool_stuff                            789
# ferramentas_jardim                    753
# pet_shop                              719
# eletronicos                           517
# construcao_ferramentas_construcao     400
# eletrodomesticos                      370
# Name: count, dtype: int64

# %%
products[
    [
        "product_weight_g",
        "product_length_cm",
        "product_height_cm",
        "product_width_cm"
    ]
].describe()
# Out:
#        product_weight_g  product_length_cm  product_height_cm  \
# count      32949.000000       32949.000000       32949.000000
# mean        2276.472488          30.815078          16.937661
# std         4282.038731          16.914458          13.637554
# min            0.000000           7.000000           2.000000
# 25%          300.000000          18.000000           8.000000
# 50%          700.000000          25.000000          13.000000
# 75%         1900.000000          38.000000          21.000000
# max        40425.000000         105.000000         105.000000
#
#        product_width_cm
# count      32949.000000
# mean          23.196728
# std           12.079047
# min            6.000000
# 25%           15.000000
# 50%           20.000000
# 75%           30.000000
# max          118.000000

# %%
products[
    products["product_category_name"].isnull()
].head(10)
# Out:
#                            product_id product_category_name  \
# 105  a41e356c76fab66334f36de622ecbd3a                   NaN
# 128  d8dee61c2034d6d075997acef1870e9b                   NaN
# 145  56139431d72cd51f19eb9f7dae4d1617                   NaN
# 154  46b48281eb6d663ced748f324108c733                   NaN
# 197  5fb61f482620cb672f5e586bb132eae9                   NaN
# 244  e10758160da97891c2fdcbc35f0f031d                   NaN
# 294  39e3b9b12cd0bf8ee681bbc1c130feb5                   NaN
# 299  794de06c32a626a5692ff50e4985d36f                   NaN
# 347  7af3e2da474486a3519b0cba9dea8ad9                   NaN
# 428  629beb8e7317703dcc5f35b5463fd20e                   NaN
#
#      product_name_lenght  product_description_lenght  product_photos_qty  \
# 105                  NaN                         NaN                 NaN
# 128                  NaN                         NaN                 NaN
# 145                  NaN                         NaN                 NaN
# 154                  NaN                         NaN                 NaN
# 197                  NaN                         NaN                 NaN
# 244                  NaN                         NaN                 NaN
# 294                  NaN                         NaN                 NaN
# 299                  NaN                         NaN                 NaN
# 347                  NaN                         NaN                 NaN
# 428                  NaN                         NaN                 NaN
#
#      product_weight_g  product_length_cm  product_height_cm  product_width_cm
# 105             650.0               17.0               14.0              12.0
# 128             300.0               16.0                7.0              20.0
# 145             200.0               20.0               20.0              20.0
# 154           18500.0               41.0               30.0              41.0
# 197             300.0               35.0                7.0              12.0
# 244            2200.0               16.0                2.0              11.0
# 294             300.0               16.0                7.0              11.0
# 299             300.0               18.0                8.0              14.0
# 347             200.0               22.0               14.0              14.0
# 428            1400.0               25.0               25.0              25.0

# %%
products[
    products["product_category_name"].isnull()
].shape
# Out:
# (610, 9)

# %%
products[
    products["product_category_name"].isnull()
][
    [
        "product_category_name",
        "product_name_lenght",
        "product_description_lenght",
        "product_photos_qty"
    ]
].isnull().sum()
# Out:
# product_category_name         610
# product_name_lenght           610
# product_description_lenght    610
# product_photos_qty            610
# dtype: int64

# %%
products[
    products[
        [
            "product_weight_g",
            "product_length_cm",
            "product_height_cm",
            "product_width_cm"
        ]
    ].isnull().any(axis=1)
]
# Out:
#                              product_id product_category_name  \
# 8578   09ff539a621711667c43eba6a3bd8466                 bebes
# 18851  5eb564652db742ff8f28759cd8d2652a                   NaN
#
#        product_name_lenght  product_description_lenght  product_photos_qty  \
# 8578                  60.0                       865.0                 3.0
# 18851                  NaN                         NaN                 NaN
#
#        product_weight_g  product_length_cm  product_height_cm  \
# 8578                NaN                NaN                NaN
# 18851               NaN                NaN                NaN
#
#        product_width_cm
# 8578                NaN
# 18851               NaN

# %% [markdown]
# ## Product Data Quality Findings
#
# The Olist products dataset contains 32,951 product records.
#
# ### Key Findings
#
# - 610 products have missing product category, product name length,
#   product description length, and photo count.
# - These 610 records generally still contain physical product attributes.
# - 2 products have missing weight and all three physical dimensions.
# - One of the two incomplete physical records still has a product category.
# - The raw dataset will remain unchanged.
# - Missing values and data-quality flags will be handled during the ETL stage.

# %%
products["product_category_name"].nunique()
# Out:
# 73

# %%
products["product_category_name"].value_counts().head(20)
# Out:
# product_category_name
# cama_mesa_banho                      3029
# esporte_lazer                        2867
# moveis_decoracao                     2657
# beleza_saude                         2444
# utilidades_domesticas                2335
# automotivo                           1900
# informatica_acessorios               1639
# brinquedos                           1411
# relogios_presentes                   1329
# telefonia                            1134
# bebes                                 919
# perfumaria                            868
# papelaria                             849
# fashion_bolsas_e_acessorios           849
# cool_stuff                            789
# ferramentas_jardim                    753
# pet_shop                              719
# eletronicos                           517
# construcao_ferramentas_construcao     400
# eletrodomesticos                      370
# Name: count, dtype: int64

# %% [markdown]
# ## Product Category Analysis
#
# - The product catalog contains 73 unique product categories.
# - The largest category by product count is `cama_mesa_banho` with 3,029 products.
# - Other major categories include `esporte_lazer`, `moveis_decoracao`,
#   `beleza_saude`, and `utilidades_domesticas`.
# - Product count represents catalog size, not sales performance.
# - Sales performance will be analyzed after joining products with order items.

# %%
payments = pd.read_csv(
    "../data/raw/olist_order_payments_dataset.csv"
)

# %%
payments.head()
# Out:
#                            order_id  payment_sequential payment_type  \
# 0  b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1  a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2  25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3  ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4  42fdf880ba16b47b59251dd489d4441a                   1  credit_card
#
#    payment_installments  payment_value
# 0                     8          99.33
# 1                     1          24.39
# 2                     1          65.71
# 3                     8         107.78
# 4                     2         128.45

# %%
payments.shape
# Out:
# (103886, 5)

# %%
payments.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103886 entries, 0 to 103885
# Data columns (total 5 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   order_id              103886 non-null  object
#  1   payment_sequential    103886 non-null  int64
#  2   payment_type          103886 non-null  object
#  3   payment_installments  103886 non-null  int64
#  4   payment_value         103886 non-null  float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 4.0+ MB

# %%
payments.isnull().sum()
# Out:
# order_id                0
# payment_sequential      0
# payment_type            0
# payment_installments    0
# payment_value           0
# dtype: int64

# %%
payments["order_id"].nunique()
# Out:
# 99440

# %%
orders["order_id"].nunique()
# Out:
# 99441

# %%
payments["payment_type"].value_counts()
# Out:
# payment_type
# credit_card    76795
# boleto         19784
# voucher         5775
# debit_card      1529
# not_defined        3
# Name: count, dtype: int64

# %%
payment_counts = payments["payment_type"].value_counts()

payment_percentage = (
    payments["payment_type"]
    .value_counts(normalize=True)
    .mul(100)
    .round(2)
)

payment_percentage
# Out:
# payment_type
# credit_card    73.92
# boleto         19.04
# voucher         5.56
# debit_card      1.47
# not_defined     0.00
# Name: proportion, dtype: float64

# %%
payments["payment_value"].describe()
# Out:
# count    103886.000000
# mean        154.100380
# std         217.494064
# min           0.000000
# 25%          56.790000
# 50%         100.000000
# 75%         171.837500
# max       13664.080000
# Name: payment_value, dtype: float64

# %%
payments["payment_value"].mean()
# Out:
# np.float64(154.10038041699556)

# %%
payments.groupby("payment_type")["payment_value"].agg(
    ["count", "sum", "mean", "median"]
).sort_values("sum", ascending=False)
# Out:
#               count          sum        mean  median
# payment_type
# credit_card   76795  12542084.19  163.319021  106.87
# boleto        19784   2869361.27  145.034435   93.89
# voucher        5775    379436.87   65.703354   39.28
# debit_card     1529    217989.79  142.570170   89.30
# not_defined       3         0.00    0.000000    0.00

# %%
payments["payment_installments"].describe()
# Out:
# count    103886.000000
# mean          2.853349
# std           2.687051
# min           0.000000
# 25%           1.000000
# 50%           1.000000
# 75%           4.000000
# max          24.000000
# Name: payment_installments, dtype: float64

# %%
payments["payment_installments"].value_counts().sort_index()
# Out:
# payment_installments
# 0         2
# 1     52546
# 2     12413
# 3     10461
# 4      7098
# 5      5239
# 6      3920
# 7      1626
# 8      4268
# 9       644
# 10     5328
# 11       23
# 12      133
# 13       16
# 14       15
# 15       74
# 16        5
# 17        8
# 18       27
# 20       17
# 21        3
# 22        1
# 23        1
# 24       18
# Name: count, dtype: int64

# %%
payments.groupby("payment_type")["payment_installments"].mean().round(2)
# Out:
# payment_type
# boleto         1.00
# credit_card    3.51
# debit_card     1.00
# not_defined    1.00
# voucher        1.00
# Name: payment_installments, dtype: float64

# %%
payment_per_order = payments.groupby("order_id").size()

payment_per_order.value_counts().sort_index()
# Out:
# 1     96479
# 2      2382
# 3       301
# 4       108
# 5        52
# 6        36
# 7        28
# 8        11
# 9         9
# 10        5
# 11        8
# 12        8
# 13        3
# 14        2
# 15        2
# 19        2
# 21        1
# 22        1
# 26        1
# 29        1
# Name: count, dtype: int64

# %%
payment_per_order.max()
# Out:
# np.int64(29)

# %%
missing_payment_orders = set(orders["order_id"]) - set(payments["order_id"])

missing_payment_orders
# Out:
# {'bfbd0f9bdef84302105ad712db648a6c'}

# %%
orders[orders["order_id"].isin(missing_payment_orders)]
# Out:
#                                order_id                       customer_id  \
# 30710  bfbd0f9bdef84302105ad712db648a6c  86dc2ffce2dfff336de2f386a786e574
#
#       order_status order_purchase_timestamp    order_approved_at  \
# 30710    delivered      2016-09-15 12:16:38  2016-09-15 12:16:38
#
#       order_delivered_carrier_date order_delivered_customer_date  \
# 30710          2016-11-07 17:11:53           2016-11-09 07:47:38
#
#       order_estimated_delivery_date
# 30710           2016-10-04 00:00:00

# %% [markdown]
# ## Payment Analysis
#
# * The Payments dataset contains **103,886 payment records** across **99,440 unique orders**.
# * The dataset contains **5 columns** and has **no missing values**.
# * `credit_card` is the dominant payment method with **76,795 payment records (73.92%)**, followed by `boleto` with **19,784 (19.04%)**.
# * The average payment value is approximately **154.10 BRL**, while the median is **100.00 BRL**, indicating a right-skewed distribution caused by higher-value transactions.
# * The maximum recorded payment value is **13,664 BRL**.
# * Credit-card payments contribute the largest share of total payment value, with approximately **12.54 million BRL** in payment records.
# * The average number of installments is approximately **2.85**, while the median is **1 installment**. The maximum is **24 installments**.
# * Most orders have a single payment record (**96,479 orders**), while some orders contain multiple payment records.
# * One order contains as many as **29 payment records**, demonstrating that the Payments table can have multiple rows per order.
# * One order, `bfbd0f9bdef84302105ad712db648a6c`, exists in the Orders table but has **no corresponding payment record**.
# * Payment analysis will be used later to investigate **payment methods, transaction value, installment behavior, and customer purchasing patterns in Power BI**.

# %%
reviews = pd.read_csv(
    "../data/raw/olist_order_reviews_dataset.csv"
)

reviews.head()
# Out:
#                           review_id                          order_id  \
# 0  7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1  80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2  228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 3  e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4  f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
#
#    review_score review_comment_title  \
# 0             4                  NaN
# 1             5                  NaN
# 2             5                  NaN
# 3             5                  NaN
# 4             5                  NaN
#
#                               review_comment_message review_creation_date  \
# 0                                                NaN  2018-01-18 00:00:00
# 1                                                NaN  2018-03-10 00:00:00
# 2                                                NaN  2018-02-17 00:00:00
# 3              Recebi bem antes do prazo estipulado.  2017-04-21 00:00:00
# 4  Parabéns lojas lannister adorei comprar pela I...  2018-03-01 00:00:00
#
#   review_answer_timestamp
# 0     2018-01-18 21:46:59
# 1     2018-03-11 03:05:13
# 2     2018-02-18 14:36:24
# 3     2017-04-21 22:02:06
# 4     2018-03-02 10:26:53

# %%
reviews.shape
# Out:
# (99224, 7)

# %%
reviews.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99224 entries, 0 to 99223
# Data columns (total 7 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   review_id                99224 non-null  object
#  1   order_id                 99224 non-null  object
#  2   review_score             99224 non-null  int64
#  3   review_comment_title     11568 non-null  object
#  4   review_comment_message   40977 non-null  object
#  5   review_creation_date     99224 non-null  object
#  6   review_answer_timestamp  99224 non-null  object
# dtypes: int64(1), object(6)
# memory usage: 5.3+ MB

# %%
reviews.isnull().sum()
# Out:
# review_id                      0
# order_id                       0
# review_score                   0
# review_comment_title       87656
# review_comment_message     58247
# review_creation_date           0
# review_answer_timestamp        0
# dtype: int64

# %%
reviews["review_score"].value_counts().sort_index()
# Out:
# review_score
# 1    11424
# 2     3151
# 3     8179
# 4    19142
# 5    57328
# Name: count, dtype: int64

# %%
reviews["review_score"].value_counts(
    normalize=True
).mul(100).round(2)
# Out:
# review_score
# 5    57.78
# 4    19.29
# 1    11.51
# 3     8.24
# 2     3.18
# Name: proportion, dtype: float64

# %%
reviews["review_score"].mean()
# Out:
# np.float64(4.08642062404257)

# %%
round(reviews["review_score"].mean(), 2)
# Out:
# np.float64(4.09)

# %%
reviews.duplicated().sum()
# Out:
# np.int64(0)

# %%
reviews["review_id"].duplicated().sum()
# Out:
# np.int64(814)

# %%
duplicate_review_ids = reviews[
    reviews["review_id"].duplicated(keep=False)
]

duplicate_review_ids.head(20)
# Out:
#                              review_id                          order_id  \
# 200   28642ce6250b94cc72bc85960aec6c62  e239d280236cdd3c40cb2c033f681d1c
# 344   a0a641414ff718ca079b3967ef5c2495  169d7e0fd71d624d306f132acd791cbe
# 346   f4d74b17cd63ee35efa82cd2567de911  f269e83a82f64baa3de97c2ebf3358f6
# 360   ecbaf1fce7d2c09bfab46f89065afeaf  2451b9756f310d4cff5c7987b393870d
# 393   6b1de94de0f4bd84dfc4136818242faa  92acf87839903a94aeca0e5040d99acb
# 433   957011305e7a4b6c8a266eeeb8e0316d  54b4da510fed5dc3cf3e7a8e50a5f224
# 433      2018-03-10 23:35:51
# 508      2017-05-22 12:02:34
# 661      2017-09-06 16:11:00
# 723      2017-11-27 21:00:47
# 764      2017-08-10 11:11:29
# 778      2017-10-31 15:33:32
# 795      2018-02-23 17:32:41
# 834      2017-10-07 19:47:11
# 841      2017-12-23 19:19:46
# 854      2018-01-02 10:54:06
# 911      2017-11-05 00:21:51
# 986      2017-05-12 00:58:11
# 1009     2017-07-22 01:06:37
# 1153     2018-02-03 23:43:14
# 1163     2018-02-16 01:50:41

# %%
duplicate_review_ids["review_id"].nunique()
# Out:
# 789

# %%
duplicate_review_ids["review_id"].value_counts().head(20)
# Out:
# review_id
# 7b606b0d57b078384f0b58eac1d41d78    3
# 2172867fd5b1a55f98fe4608e1547b4b    3
# 08528f70f579f0c830189efc523d2182    3
# 3415c9f764e478409e8e0660ae816dd2    3
# 4219a80ab469e3fc9901437b73da3f75    3
# 4d0e6dd087008d1f992d25ef6e1f619f    3
# dbdf1ea31790c8ecfcc6750525661a9b    3
# 39b4603793c1c7f5f36d809b4a218664    3
# c444278834184f72b1484dfe47de7f97    3
# f4bb9d6dd4fb6dcc2298f0e7b17b8e1e    3
# e44840754f12fad2b8646712121b349a    3
# 308316408775d1600dad81bd3184556d    3
# 44e9f871226d8a130de3fc39dfbdf0c5    3
# 1fb4ddc969e6bea80e38deec00393a6f    3
# ddc52555ca27b0fe67d5255147682d2d    3
# 2d6ac45f859465b5c185274a1c929637    3
# 0c76e7a547a531e7bf9f0b99cba071c1    3
# 38821b5c496b678cf91acc34892805ad    3
# 832acec9bbf4efe65c3fb6423d8b4ed7    3
# 69a1068c3128a14994e3e422e4539e04    3
# Name: count, dtype: int64

# %%
duplicate_review_analysis = (
    duplicate_review_ids
    .groupby("review_id")["order_id"]
    .nunique()
)

duplicate_review_analysis.value_counts().sort_index()
# Out:
# order_id
# 2    764
# 3     25
# Name: count, dtype: int64

# %%
duplicate_review_ids[
    duplicate_review_ids["review_id"] == duplicate_review_ids["review_id"].iloc[0]
]
# Out:
#                               review_id                          order_id  \
# 200    28642ce6250b94cc72bc85960aec6c62  e239d280236cdd3c40cb2c033f681d1c
# 58385  28642ce6250b94cc72bc85960aec6c62  bc42a955f289870d5789e6e437206300
#
#        review_score review_comment_title review_comment_message  \
# 200               5                  NaN                    NaN
# 58385             5                  NaN                    NaN
#
#       review_creation_date review_answer_timestamp
# 200    2018-03-25 00:00:00     2018-03-25 21:03:02
# 58385  2018-03-25 00:00:00     2018-03-25 21:03:02

# %%
reviews_per_order = reviews.groupby("order_id").size()

reviews_per_order.value_counts().sort_index()
# Out:
# 1    98126
# 2      543
# 3        4
# Name: count, dtype: int64

# %%
reviews_per_order.max()
# Out:
# np.int64(3)

# %%
reviews[[
    "review_creation_date",
    "review_answer_timestamp"
]].dtypes
# Out:
# review_creation_date       object
# review_answer_timestamp    object
# dtype: object

# %%
reviews["review_creation_date"] = pd.to_datetime(
    reviews["review_creation_date"]
)

reviews["review_answer_timestamp"] = pd.to_datetime(
    reviews["review_answer_timestamp"]
)

# %%
reviews[[
    "review_creation_date",
    "review_answer_timestamp"
]].dtypes
# Out:
# review_creation_date       datetime64[ns]
# review_answer_timestamp    datetime64[ns]
# dtype: object

# %%
reviews["review_creation_date"].min()
# Out:
# Timestamp('2016-10-02 00:00:00')

# %%
reviews["review_creation_date"].max()
# Out:
# Timestamp('2018-08-31 00:00:00')

# %%
reviews["review_response_time"] = (
    reviews["review_answer_timestamp"]
    - reviews["review_creation_date"]
)

# %%
reviews["response_time_hours"] = (
    reviews["review_response_time"].dt.total_seconds() / 3600
)

# %%
reviews["response_time_hours"].describe()
# Out:
# count    99224.000000
# mean        75.575842
# std        237.361183
# min          2.141389
# 25%         24.116875
# 50%         40.198750
# 75%         74.485556
# max      12448.781111
# Name: response_time_hours, dtype: float64

# %%
bins = [0, 24, 48, 72, float("inf")]

labels = [
    "< 24 hours",
    "24–48 hours",
    "48–72 hours",
    "72+ hours"
]

reviews["response_time_group"] = pd.cut(
    reviews["response_time_hours"],
    bins=bins,
    labels=labels,
    right=False
)

# %%
reviews["response_time_group"].value_counts().sort_index()
# Out:
# response_time_group
# < 24 hours     24361
# 24–48 hours    30995
# 48–72 hours    15898
# 72+ hours      27970
# Name: count, dtype: int64

# %%
reviews.groupby(
    "response_time_group",
    observed=True
)["review_score"].agg(
    ["count", "mean", "median"]
).round(2)
# Out:
#                      count  mean  median
# response_time_group
# < 24 hours           24361  3.89     5.0
# 24–48 hours          30995  4.24     5.0
# 48–72 hours          15898  4.05     5.0
# 72+ hours            27970  4.12     5.0

# %%
reviews["review_year"] = (
    reviews["review_creation_date"].dt.year
)

# %%
reviews["review_year"].value_counts().sort_index()
# Out:
# review_year
# 2016      325
# 2017    42735
# 2018    56164
# Name: count, dtype: int64

# %%
reviews.groupby("review_year")["review_score"].agg(
    ["count", "mean", "median"]
).round(2)
# Out:
#              count  mean  median
# review_year
# 2016           325  3.55     4.0
# 2017         42735  4.11     5.0
# 2018         56164  4.07     5.0

# %%
reviews["review_month"] = (
    reviews["review_creation_date"]
    .dt.to_period("M")
)

# %%
monthly_reviews = (
    reviews.groupby("review_month")
    .size()
)

monthly_reviews.head(20)
# Out:
# review_month
# 2016-10     179
# 2016-11     101
# 2016-12      45
# 2017-01     239
# 2017-02    1413
# 2017-03    2481
# 2017-04    2055
# 2017-05    3710
# 2017-06    3440
# 2017-07    3503
# 2017-08    4503
# 2017-09    4199
# 2017-10    4424
# 2017-11    4786
# 2017-12    7982
# 2018-01    6179
# 2018-02    6101
# 2018-03    7803
# 2018-04    7287
# 2018-05    7458
# Freq: M, dtype: int64

# %%
monthly_reviews.sort_values(
    ascending=False
).head(10)
# Out:
# review_month
# 2018-08    8987
# 2017-12    7982
# 2018-03    7803
# 2018-05    7458
# 2018-04    7287
# 2018-06    6715
# 2018-01    6179
# 2018-02    6101
# 2018-07    5634
# 2017-11    4786
# Freq: M, dtype: int64

# %%
monthly_rating = (
    reviews.groupby("review_month")["review_score"]
    .agg(["count", "mean"])
    .round(2)
)

monthly_rating.head(20)
# Out:
#               count  mean
# review_month
# 2016-10         179  4.06
# 2016-11         101  3.19
# 2016-12          45  2.36
# 2017-01         239  4.34
# 2017-02        1413  4.28
# 2017-03        2481  4.03
# 2017-04        2055  4.04
# 2017-05        3710  4.10
# 2017-06        3440  4.13
# 2017-07        3503  4.18
# 2017-08        4503  4.22
# 2017-09        4199  4.18
# 2017-10        4424  4.18
# 2017-11        4786  4.11
# 2017-12        7982  3.93
# 2018-01        6179  4.06
# 2018-02        6101  4.01
# 2018-03        7803  3.73
# 2018-04        7287  3.92
# 2018-05        7458  4.19

# %%
monthly_rating.sort_values(
    "mean",
    ascending=False
).head(10)
# Out:
#               count  mean
# review_month
# 2017-01         239  4.34
# 2018-07        5634  4.29
# 2017-02        1413  4.28
# 2017-08        4503  4.22
# 2018-08        8987  4.21
# 2018-06        6715  4.20
# 2018-05        7458  4.19
# 2017-10        4424  4.18
# 2017-07        3503  4.18
# 2017-09        4199  4.18

# %%
monthly_rating.sort_values(
    "mean",
    ascending=True
).head(10)
# Out:
#               count  mean
# review_month
# 2016-12          45  2.36
# 2016-11         101  3.19
# 2018-03        7803  3.73
# 2018-04        7287  3.92
# 2017-12        7982  3.93
# 2018-02        6101  4.01
# 2017-03        2481  4.03
# 2017-04        2055  4.04
# 2018-01        6179  4.06
# 2016-10         179  4.06

# %%
reviews["review_category"] = pd.cut(
    reviews["review_score"],
    bins=[0, 2, 3, 5],
    labels=["Negative", "Neutral", "Positive"]
)

# %%
reviews["review_category"].value_counts()
# Out:
# review_category
# Positive    76470
# Negative    14575
# Neutral      8179
# Name: count, dtype: int64

# %%
reviews["review_category"].value_counts(
    normalize=True
).mul(100).round(2)
# Out:
# review_category
# Positive    77.07
# Negative    14.69
# Neutral      8.24
# Name: proportion, dtype: float64

# %%
reviews["review_comment_message"].notna().value_counts()
# Out:
# review_comment_message
# False    58247
# True     40977
# Name: count, dtype: int64

# %%
reviews["review_comment_message"].notna().value_counts(
    normalize=True
).mul(100).round(2)
# Out:
# review_comment_message
# False    58.7
# True     41.3
# Name: proportion, dtype: float64

# %%
comment_by_category = (
    reviews.groupby("review_category", observed=True)["review_comment_message"]
    .apply(lambda x: x.notna().mean() * 100)
    .round(2)
)

comment_by_category
# Out:
# review_category
# Negative    74.72
# Neutral     43.49
# Positive    34.69
# Name: review_comment_message, dtype: float64

# %%
comment_by_score = (
    reviews.groupby("review_score")["review_comment_message"]
    .apply(lambda x: x.notna().mean() * 100)
    .round(2)
)

comment_by_score
# Out:
# review_score
# 1    76.55
# 2    68.07
# 3    43.49
# 4    31.22
# 5    35.85
# Name: review_comment_message, dtype: float64

# %%
reviews["comment_length"] = (
    reviews["review_comment_message"]
    .fillna("")
    .str.len()
)

# %%
reviews["comment_length"].describe()
# Out:
# count    99224.000000
# mean        28.345622
# std         48.369574
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%         42.000000
# max        208.000000
# Name: comment_length, dtype: float64

# %%
reviews.groupby("review_score")["comment_length"].agg(
    ["count", "mean", "median"]
).round(2)
# Out:
#               count   mean  median
# review_score
# 1             11424  76.50    63.0
# 2              3151  65.93    47.0
# 3              8179  36.24     0.0
# 4             19142  19.27     0.0
# 5             57328  18.59     0.0

# %%
comment_length_by_score = (
    reviews[reviews["review_comment_message"].notna()]
    .groupby("review_score")["comment_length"]
    .agg(["count", "mean", "median"])
    .round(2)
)

comment_length_by_score
# Out:
#               count   mean  median
# review_score
# 1              8745  99.94    89.0
# 2              2145  96.85    88.0
# 3              3557  83.33    70.0
# 4              5976  61.73    47.0
# 5             20554  51.84    42.0

# %%
reviews["review_id"].duplicated().sum()
# Out:
# np.int64(814)

# %%
reviews.duplicated().sum()
# Out:
# np.int64(0)

# %%
reviews["review_score"].value_counts().sort_index()
# Out:
# review_score
# 1    11424
# 2     3151
# 3     8179
# 4    19142
# 5    57328
# Name: count, dtype: int64

# %%
positive_review_rate = (
    reviews["review_score"].ge(4).mean() * 100
)

round(positive_review_rate, 2)
# Out:
# np.float64(77.07)

# %%
negative_review_rate = (
    reviews["review_score"].le(2).mean() * 100
)

round(negative_review_rate, 2)
# Out:
# np.float64(14.69)

# %%
overall_average_rating = reviews["review_score"].mean()

round(overall_average_rating, 2)
# Out:
# np.float64(4.09)

# %%
# ============================================
# RECREATE DELIVERY ANALYSIS
# ============================================

delivery_analysis = orders.copy()

# Convert date columns
date_columns = [
    "order_purchase_timestamp",
    "order_approved_at",
    "order_delivered_carrier_date",
    "order_delivered_customer_date",
    "order_estimated_delivery_date"
]

for col in date_columns:
    delivery_analysis[col] = pd.to_datetime(
        delivery_analysis[col],
        errors="coerce"
    )

# Delivery time in days
delivery_analysis["delivery_days"] = (
    delivery_analysis["order_delivered_customer_date"]
    - delivery_analysis["order_purchase_timestamp"]
).dt.total_seconds() / (24 * 60 * 60)

# Estimated delivery time in days
delivery_analysis["estimated_delivery_days"] = (
    delivery_analysis["order_estimated_delivery_date"]
    - delivery_analysis["order_purchase_timestamp"]
).dt.total_seconds() / (24 * 60 * 60)

# Delivery delay
delivery_analysis["delivery_delay_days"] = (
    delivery_analysis["delivery_days"]
    - delivery_analysis["estimated_delivery_days"]
)

print("Delivery analysis shape:", delivery_analysis.shape)

display(
    delivery_analysis[
        [
            "order_id",
            "customer_id",
            "order_status",
            "delivery_days",
            "estimated_delivery_days",
            "delivery_delay_days"
        ]
    ].head()
)
# Out:
# Delivery analysis shape: (99441, 11)
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status  delivery_days  estimated_delivery_days  delivery_delay_days
# 0    delivered       8.436574                15.544063            -7.107488
# 1    delivered      13.782037                19.137766            -5.355729
# 2    delivered       9.394213                26.639711           -17.245498
# 3    delivered      13.208750                26.188819           -12.980069
# 4    delivered       2.873877                12.112049            -9.238171

# %%
# ============================================
# 9.5 RATING VS DELIVERY PERFORMANCE
# ============================================

review_delivery = reviews[
    ["order_id", "review_score"]
].merge(
    delivery_analysis[
        ["order_id", "delivery_days", "delivery_delay_days"]
    ],
    on="order_id",
    how="left"
)

review_delivery["delivery_performance"] = np.select(
    [
        review_delivery["delivery_delay_days"] > 0,
        review_delivery["delivery_delay_days"] <= 0
    ],
    [
        "Late",
        "Early"
    ],
    default="Unknown"
)

review_delivery_analysis = (
    review_delivery
    .groupby("delivery_performance")
    .agg(
        reviews=("order_id", "nunique"),
        average_rating=("review_score", "mean"),
        average_delivery_days=("delivery_days", "mean"),
        average_delay_days=("delivery_delay_days", "mean")
    )
    .round(2)
    .sort_values("average_rating", ascending=False)
)

review_delivery_analysis
# Out:
#                       reviews  average_rating  average_delivery_days  \
# delivery_performance
# Early                   88168            4.29                  10.88
# Late                     7662            2.57                  31.39
# Unknown                  2843            1.76                    NaN
#
#                       average_delay_days
# delivery_performance
# Early                             -13.02
# Late                                9.45
# Unknown                              NaN

# %%
# ============================================
# 9.6 RATING DISTRIBUTION BY DELIVERY
# ============================================

rating_delivery_matrix = pd.crosstab(
    review_delivery["delivery_performance"],
    review_delivery["review_score"]
)

rating_delivery_matrix
# Out:
# review_score             1     2     3      4      5
# delivery_performance
# Early                 5855  2335  7086  18033  55349
# Late                  3554   606   876    954   1711
# Unknown               2015   210   217    155    268

# %%
# Rating percentage within each delivery group

rating_delivery_percentage = (
    pd.crosstab(
        review_delivery["delivery_performance"],
        review_delivery["review_score"],
        normalize="index"
    ) * 100
).round(2)

rating_delivery_percentage
# Out:
# review_score              1     2      3      4      5
# delivery_performance
# Early                  6.60  2.63   7.99  20.34  62.43
# Late                  46.15  7.87  11.38  12.39  22.22
# Unknown               70.33  7.33   7.57   5.41   9.35

# %%
# ============================================
# 9.7 MONTHLY REVIEW TREND
# ============================================

reviews["review_creation_date"] = pd.to_datetime(
    reviews["review_creation_date"],
    errors="coerce"
)

reviews["year_month"] = (
    reviews["review_creation_date"]
    .dt.to_period("M")
    .astype(str)
)

monthly_review_analysis = (
    reviews
    .groupby("year_month")
    .agg(
        reviews=("review_id", "nunique"),
        average_rating=("review_score", "mean"),
        positive_reviews=(
            "review_score",
            lambda x: (x >= 4).sum()
        ),
        negative_reviews=(
            "review_score",
            lambda x: (x <= 2).sum()
        )
    )
)

monthly_review_analysis["positive_rate"] = (
    monthly_review_analysis["positive_reviews"]
    / monthly_review_analysis["reviews"]
    * 100
).round(2)

monthly_review_analysis["negative_rate"] = (
    monthly_review_analysis["negative_reviews"]
    / monthly_review_analysis["reviews"]
    * 100
).round(2)

monthly_review_analysis["average_rating"] = (
    monthly_review_analysis["average_rating"]
    .round(2)
)

monthly_review_analysis = monthly_review_analysis.reset_index()

monthly_review_analysis
# Out:
#    year_month  reviews  average_rating  positive_reviews  negative_reviews  \
# 0     2016-10      176            4.06               137                29
# 1     2016-11      101            3.19                55                38
# 2     2016-12       45            2.36                15                29
# 3     2017-01      232            4.34               196                20
# 4     2017-02     1392            4.28              1158               135
# 5     2017-03     2459            4.03              1874               390
# 6     2017-04     2036            4.04              1546               315
# 7     2017-05     3670            4.10              2870               511
# 8     2017-06     3393            4.13              2679               452
# 9     2017-07     3460            4.18              2780               422
# 10    2017-08     4442            4.22              3637               523
# 11    2017-09     4153            4.18              3368               521
# 12    2017-10     4389            4.18              3550               540
# 13    2017-11     4738            4.11              3708               640
# 14    2017-12     7912            3.93              5833              1478
# 15    2018-01     6145            4.06              4703               926
# 16    2018-02     6035            4.01              4552               981
# 17    2018-03     7675            3.73              5246              1832
# 18    2018-04     7267            3.92              5293              1392
# 19    2018-05     7442            4.19              5991               903
# 20    2018-06     6702            4.20              5372               823
# 21    2018-07     5604            4.29              4656               583
# 22    2018-08     8942            4.21              7251              1092
#
#     positive_rate  negative_rate
# 0           77.84          16.48
# 1           54.46          37.62
# 2           33.33          64.44
# 3           84.48           8.62
# 4           83.19           9.70
# 5           76.21          15.86
# 6           75.93          15.47
# 7           78.20          13.92
# 8           78.96          13.32
# 9           80.35          12.20
# 10          81.88          11.77
# 11          81.10          12.55
# 12          80.88          12.30
# 13          78.26          13.51
# 14          73.72          18.68
# 15          76.53          15.07
# 16          75.43          16.26
# 17          68.35          23.87
# 18          72.84          19.16
# 19          80.50          12.13
# 20          80.16          12.28
# 21          83.08          10.40
# 22          81.09          12.21

# %%
# ============================================
# 9.8 REVIEW COMMENT ANALYSIS
# ============================================

# Create comment length
reviews["comment_length"] = (
    reviews["review_comment_message"]
    .fillna("")
    .astype(str)
    .str.len()
)

# Create word count
reviews["comment_word_count"] = (
    reviews["review_comment_message"]
    .fillna("")
    .astype(str)
    .str.split()
    .str.len()
)

# Average comment length by rating
comment_length_by_score = (
    reviews
    .groupby("review_score")
    .agg(
        reviews=("review_id", "nunique"),
        average_comment_length=("comment_length", "mean"),
        median_comment_length=("comment_length", "median"),
        average_word_count=("comment_word_count", "mean")
    )
    .round(2)
)

comment_length_by_score
# Out:
#               reviews  average_comment_length  median_comment_length  \
# review_score
# 1               11282                   76.50                   63.0
# 2                3114                   65.93                   47.0
# 3                8097                   36.24                    0.0
# 4               19007                   19.27                    0.0
# 5               56910                   18.59                    0.0
#
#               average_word_count
# review_score
# 1                          13.39
# 2                          11.67
# 3                           6.37
# 4                           3.31
# 5                           3.03

# %%
# ============================================
# 9.8.1 REVIEW COMMENT AVAILABILITY
# ============================================

reviews["has_comment"] = (
    reviews["review_comment_message"]
    .fillna("")
    .str.strip()
    .ne("")
)

comment_availability = (
    reviews
    .groupby("review_score")
    .agg(
        total_reviews=("review_id", "nunique"),
        reviews_with_comment=("has_comment", "sum")
    )
)

comment_availability["comment_rate"] = (
    comment_availability["reviews_with_comment"]
    / comment_availability["total_reviews"]
    * 100
).round(2)

comment_availability
# Out:
#               total_reviews  reviews_with_comment  comment_rate
# review_score
# 1                     11282                  8744         77.50
# 2                      3114                  2145         68.88
# 3                      8097                  3556         43.92
# 4                     19007                  5970         31.41
# 5                     56910                 20535         36.08

# %%
# ============================================
# 9.8.2 MOST COMMON REVIEW WORDS
# ============================================

from collections import Counter
import re

review_text = " ".join(
    reviews.loc[
        reviews["has_comment"],
        "review_comment_message"
    ].astype(str)
).lower()

words = re.findall(r"\b[a-z]{3,}\b", review_text)

common_words = (
    pd.DataFrame(
        Counter(words).most_common(30),
        columns=["word", "count"]
    )
)

common_words
# Out:
#          word  count
# 0     produto  18428
# 1       prazo   8475
# 2         que   8324
# 3       muito   7925
# 4     entrega   6528
# 5         com   5787
# 6       antes   5626
# 7      chegou   5555
# 8      recebi   5274
# 9         bom   4607
# 10        foi   4548
# 11  recomendo   4337
# 12   entregue   3779
# 13       veio   3285
# 14       para   3164
# 15        bem   3112
# 16        mas   2989
# 17  qualidade   2772
# 18    comprei   2763
# 19        uma   2673
# 20       loja   2409
# 21      ainda   2337
# 22       tudo   2332
# 23     compra   2206
# 24       mais   2083
# 25        meu   2044
# 26     gostei   1896
# 27      estou   1851
# 28  excelente   1807
# 29       como   1783

# %%
# ============================================
# 9.9 FINAL REVIEW SUMMARY
# ============================================

review_summary = pd.DataFrame({
    "metric": [
        "Total Reviews",
        "Average Rating",
        "Positive Review Rate",
        "Negative Review Rate",
        "1-Star Reviews",
        "5-Star Reviews",
        "Reviews With Comments",
        "Average Comment Length - 1 Star",
        "Average Comment Length - 5 Star",
        "Early Delivery Average Rating",
        "Late Delivery Average Rating"
    ],
    "value": [
        reviews["review_id"].nunique(),
        round(reviews["review_score"].mean(), 2),
        round((reviews["review_score"] >= 4).mean() * 100, 2),
        round((reviews["review_score"] <= 2).mean() * 100, 2),
        (reviews["review_score"] == 1).sum(),
        (reviews["review_score"] == 5).sum(),
        reviews["has_comment"].sum(),
        round(
            reviews.loc[
                reviews["review_score"] == 1,
                "comment_length"
            ].mean(), 2
        ),
        round(
            reviews.loc[
                reviews["review_score"] == 5,
                "comment_length"
            ].mean(), 2
        ),
        review_delivery_analysis.loc[
            "Early", "average_rating"
        ],
        review_delivery_analysis.loc[
            "Late", "average_rating"
        ]
    ]
})

review_summary
# Out:
#                              metric     value
# 0                     Total Reviews  98410.00
# 1                    Average Rating      4.09
# 2              Positive Review Rate     77.07
# 3              Negative Review Rate     14.69
# 4                    1-Star Reviews  11424.00
# 5                    5-Star Reviews  57328.00
# 6             Reviews With Comments  40950.00
# 7   Average Comment Length - 1 Star     76.50
# 8   Average Comment Length - 5 Star     18.59
# 9     Early Delivery Average Rating      4.29
# 10     Late Delivery Average Rating      2.57

# %% [markdown]
# ## Review Analysis
#
# * The Reviews dataset contains **99,224 review records**.
# * There are **no missing values** in `review_id`, `order_id`, `review_score`, `review_creation_date`, or `review_answer_timestamp`.
# * `review_comment_title` has **87,656 missing values**, while `review_comment_message` has **58,247 missing values**.
# * Customer ratings range from **1 to 5**, with **5-star reviews being the most common** at 57.78%.
# * The overall average review score is **4.09 out of 5**, indicating generally positive customer satisfaction.
# * **77.07%** of reviews are positive (4–5 stars), **8.24%** are neutral (3 stars), and **14.69%** are negative (1–2 stars).
# * Only **41.30%** of reviews contain written comments, while **58.70%** contain only a rating.
# * Negative reviews are more likely to contain written feedback: **74.72%** of negative reviews had comments compared with **34.69%** of positive reviews.
# * Among reviews containing comments, **1-star reviews had the longest average comments (99.94 characters)**, compared with **51.84 characters** for 5-star reviews.
# * The median review response time was **40.20 hours**, while the average was **75.58 hours**, indicating a right-skewed response-time distribution caused by some very long response times.
# * The **24–48 hour** response group had the highest average rating at **4.24**, while reviews answered within 24 hours had an average rating of **3.89**. This represents an association, not necessarily a causal relationship.
# * Review volume increased substantially over time, with **2018 accounting for 56,164 reviews** compared with 42,735 in 2017.
# * **August 2018** recorded the highest monthly review volume with **8,987 reviews**.
# * There are **814 duplicate `review_id` values**, but **no completely duplicated rows**. These duplicate IDs should be investigated rather than automatically removed.
# * All review scores are valid values between **1 and 5**.
#
# ### Key Business Insight
#
# Overall customer satisfaction was strong, with an average rating of **4.09/5** and **77.07% positive reviews**. However, negative reviews are particularly valuable for improvement because customers giving low ratings were much more likely to provide detailed written feedback.

# %% [markdown]
# # STEP 10 — Geolocation Analysis

# %%
geolocation = pd.read_csv(
    "../data/raw/olist_geolocation_dataset.csv"
)

# %%
geolocation.head()
# Out:
#    geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 0                         1037       -23.545621       -46.639292
# 1                         1046       -23.546081       -46.644820
# 2                         1046       -23.546129       -46.642951
# 3                         1041       -23.544392       -46.639499
# 4                         1035       -23.541578       -46.641607
#
#   geolocation_city geolocation_state
# 0        sao paulo                SP
# 1        sao paulo                SP
# 2        sao paulo                SP
# 3        sao paulo                SP
# 4        sao paulo                SP

# %%
geolocation.shape
# Out:
# (1000163, 5)

# %%
geolocation.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000163 entries, 0 to 1000162
# Data columns (total 5 columns):
#  #   Column                       Non-Null Count    Dtype
# ---  ------                       --------------    -----
#  0   geolocation_zip_code_prefix  1000163 non-null  int64
#  1   geolocation_lat              1000163 non-null  float64
#  2   geolocation_lng              1000163 non-null  float64
#  3   geolocation_city             1000163 non-null  object
#  4   geolocation_state            1000163 non-null  object
# dtypes: float64(2), int64(1), object(2)
# memory usage: 38.2+ MB

# %%
geolocation.isnull().sum()
# Out:
# geolocation_zip_code_prefix    0
# geolocation_lat                0
# geolocation_lng                0
# geolocation_city               0
# geolocation_state              0
# dtype: int64

# %%
geolocation.duplicated().sum()
# Out:
# np.int64(261831)

# %%
geolocation["geolocation_zip_code_prefix"].duplicated().sum()
# Out:
# np.int64(981148)

# %%
geolocation["geolocation_zip_code_prefix"].nunique()
# Out:
# 19015

# %%
geolocation["geolocation_city"].nunique()
# Out:
# 8011

# %%
geolocation["geolocation_state"].nunique()
# Out:
# 27

# %%
geolocation["geolocation_state"].value_counts()
# Out:
# geolocation_state
# SP    404268
# MG    126336
# RJ    121169
# RS     61851
# PR     57859
# SC     38328
# BA     36045
# GO     20139
# ES     16748
# PE     16432
# DF     12986
# MT     12031
# CE     11674
# PA     10853
# MS     10431
# MA      7853
# PB      5538
# RN      5041
# PI      4549
# AL      4183
# TO      3576
# SE      3563
# RO      3478
# AM      2432
# AC      1301
# AP       853
# RR       646
# Name: count, dtype: int64

# %%
state_percentage = (
    geolocation["geolocation_state"]
    .value_counts(normalize=True)
    .mul(100)
    .round(2)
)

state_percentage
# Out:
# geolocation_state
# SP    40.42
# MG    12.63
# RJ    12.11
# RS     6.18
# PR     5.78
# SC     3.83
# BA     3.60
# GO     2.01
# ES     1.67
# PE     1.64
# DF     1.30
# MT     1.20
# CE     1.17
# PA     1.09
# MS     1.04
# MA     0.79
# PB     0.55
# RN     0.50
# PI     0.45
# AL     0.42
# TO     0.36
# SE     0.36
# RO     0.35
# AM     0.24
# AC     0.13
# AP     0.09
# RR     0.06
# Name: proportion, dtype: float64

# %%
state_percentage.head(10)
# Out:
# geolocation_state
# SP    40.42
# MG    12.63
# RJ    12.11
# RS     6.18
# PR     5.78
# SC     3.83
# BA     3.60
# GO     2.01
# ES     1.67
# PE     1.64
# Name: proportion, dtype: float64

# %%
city_counts = geolocation["geolocation_city"].value_counts()

city_counts.head(20)
# Out:
# geolocation_city
# sao paulo                135800
# rio de janeiro            62151
# belo horizonte            27805
# são paulo                 24918
# curitiba                  16593
# porto alegre              13521
# salvador                  11865
# guarulhos                 11340
# brasilia                  10470
# sao bernardo do campo      8112
# osasco                     7658
# santo andre                6863
# niteroi                    6534
# recife                     6168
# goiania                    5661
# fortaleza                  5538
# campinas                   5479
# sorocaba                   5361
# santos                     5000
# barueri                    4971
# Name: count, dtype: int64

# %%
city_counts.head(10)
# Out:
# geolocation_city
# sao paulo                135800
# rio de janeiro            62151
# belo horizonte            27805
# são paulo                 24918
# curitiba                  16593
# porto alegre              13521
# salvador                  11865
# guarulhos                 11340
# brasilia                  10470
# sao bernardo do campo      8112
# Name: count, dtype: int64

# %%
import unicodedata

def normalize_city(city):
    city = str(city).lower().strip()
    city = unicodedata.normalize("NFKD", city)
    city = "".join(
        c for c in city
        if not unicodedata.combining(c)
    )
    return city

geolocation["city_normalized"] = (
    geolocation["geolocation_city"]
    .apply(normalize_city)
)

# %%
geolocation["city_normalized"].nunique()
# Out:
# 5968

# %%
print("Original unique cities:", geolocation["geolocation_city"].nunique())
print("Normalized unique cities:", geolocation["city_normalized"].nunique())
# Out:
# Original unique cities: 8011
# Normalized unique cities: 5968

# %%
normalized_city_counts = (
    geolocation["city_normalized"]
    .value_counts()
)

normalized_city_counts.head(20)
# Out:
# city_normalized
# sao paulo                160718
# rio de janeiro            62151
# belo horizonte            27805
# curitiba                  16593
# porto alegre              13521
# brasilia                  12650
# salvador                  11866
# guarulhos                 11340
# sao bernardo do campo      9629
# santo andre                8051
# osasco                     7658
# niteroi                    7563
# goiania                    6730
# recife                     6168
# fortaleza                  5538
# campinas                   5479
# sorocaba                   5361
# ribeirao preto             5010
# santos                     5000
# florianopolis              4998
# Name: count, dtype: int64

# %%
normalized_city_counts.head(10)
# Out:
# city_normalized
# sao paulo                160718
# rio de janeiro            62151
# belo horizonte            27805
# curitiba                  16593
# porto alegre              13521
# brasilia                  12650
# salvador                  11866
# guarulhos                 11340
# sao bernardo do campo      9629
# santo andre                8051
# Name: count, dtype: int64

# %%
geolocation["geolocation_lat"].describe()
# Out:
# count    1.000163e+06
# mean    -2.117615e+01
# std      5.715866e+00
# min     -3.660537e+01
# 25%     -2.360355e+01
# 50%     -2.291938e+01
# 75%     -1.997962e+01
# max      4.506593e+01
# Name: geolocation_lat, dtype: float64

# %%
geolocation["geolocation_lng"].describe()
# Out:
# count    1.000163e+06
# mean    -4.639054e+01
# std      4.269748e+00
# min     -1.014668e+02
# 25%     -4.857317e+01
# 50%     -4.663788e+01
# 75%     -4.376771e+01
# max      1.211054e+02
# Name: geolocation_lng, dtype: float64

# %%
geo_outliers = geolocation[
    (geolocation["geolocation_lat"] < -35) |
    (geolocation["geolocation_lat"] > 6) |
    (geolocation["geolocation_lng"] < -75) |
    (geolocation["geolocation_lng"] > -30)
]

geo_outliers.shape
# Out:
# (29, 6)

# %%
len(geo_outliers)
# Out:
# 29

# %%
geo_outliers.head(20)
# Out:
#         geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 387565                        18243        28.008978       -15.536867
# 513631                        28165        41.614052        -8.411675
# 513754                        28155        42.439286        13.820214
# 514429                        28333        38.381672        -6.328200
# 516682                        28595        43.684961        -7.411080
# 538512                        29654        29.409252       -98.484121
# 538557                        29654        21.657547      -101.466766
# 585242                        35179        25.995203       -98.078544
# 585260                        35179        25.995245       -98.078533
# 695377                        45936        38.323939        -6.775035
# 697048                        46560        38.991963        -4.947823
# 698466                        47310        38.268205        -7.803886
# 727755                        57319        45.065933         9.341528
# 732362                        58441        41.385328        -8.717342
# 769333                        68275        41.146203        -8.577855
# 769351                        68275        42.166805        -6.898531
# 769391                        68275        42.167251        -6.898559
# 769436                        68275        42.167251        -6.898559
# 769489                        68275        42.167251        -6.898559
# 769924                        68379        38.713128        -9.135741
#
#                geolocation_city geolocation_state          city_normalized
# 387565  bom retiro da esperanca                SP  bom retiro da esperanca
# 513631      vila nova de campos                RJ      vila nova de campos
# 513754              santa maria                RJ              santa maria
# 514429                   raposo                RJ                   raposo
# 516682                  portela                RJ                  portela
# 538512   santo antônio do canaã                ES   santo antonio do canaa
# 538557   santo antonio do canaa                ES   santo antonio do canaa
# 585242       santana do paraíso                MG       santana do paraiso
# 585260       santana do paraiso                MG       santana do paraiso
# 695377                 itabatan                BA                 itabatan
# 697048                 ibiajara                BA                 ibiajara
# 698466       santana do sobrado                BA       santana do sobrado
# 727755               pau d'arco                AL               pau d'arco
# 732362         são josé da mata                PB         sao jose da mata
# 769333          porto trombetas                PA          porto trombetas
# 769351          porto trombetas                PA          porto trombetas
# 769391          porto trombetas                PA          porto trombetas
# 769436          porto trombetas                PA          porto trombetas
# 769489          porto trombetas                PA          porto trombetas
# 769924       castelo dos sonhos                PA       castelo dos sonhos

# %%
geolocation[
    ["geolocation_lat", "geolocation_lng"]
].drop_duplicates().shape
# Out:
# (718463, 2)

# %%
geolocation["geolocation_lat"].nunique()
# Out:
# 717360

# %%
geolocation["geolocation_lng"].nunique()
# Out:
# 717613

# %%
zip_counts = (
    geolocation["geolocation_zip_code_prefix"]
    .value_counts()
)

zip_counts.head(20)
# Out:
# geolocation_zip_code_prefix
# 24220    1146
# 24230    1102
# 38400     965
# 35500     907
# 11680     879
# 22631     832
# 30140     810
# 11740     788
# 38408     773
# 28970     743
# 36400     733
# 39400     724
# 37701     714
# 35162     713
# 35900     709
# 37200     696
# 88330     694
# 22790     687
# 35700     678
# 36570     667
# Name: count, dtype: int64

# %%
geo_summary = {
    "Total records": len(geolocation),
    "Unique ZIP prefixes": geolocation["geolocation_zip_code_prefix"].nunique(),
    "Unique cities": geolocation["city_normalized"].nunique(),
    "Unique states": geolocation["geolocation_state"].nunique(),
    "Unique coordinates": geolocation[
        ["geolocation_lat", "geolocation_lng"]
    ].drop_duplicates().shape[0],
    "Coordinate outliers": len(geo_outliers),
    "Duplicate rows": geolocation.duplicated().sum()
}

geo_summary
# Out:
# {'Total records': 1000163,
#  'Unique ZIP prefixes': 19015,
#  'Unique cities': 5968,
#  'Unique states': 27,
#  'Unique coordinates': 718463,
#  'Coordinate outliers': 29,
#  'Duplicate rows': np.int64(261831)}

# %% [markdown]
# ## Geolocation Analysis
#
# - The geolocation dataset contains 1,000,163 records covering 19,015 unique ZIP-code prefixes.
# - The dataset covers all 27 Brazilian states and 5,968 normalized cities.
# - São Paulo has the highest concentration of geolocation records, accounting for 40.42% of the dataset.
# - There are 718,463 unique latitude/longitude coordinate pairs.
# - City names were normalized to improve consistency, reducing unique city names from 8,011 to 5,968.
# - The dataset contains 261,831 duplicate rows, indicating repeated geographic records.
# - 29 geographic coordinate outliers were identified and should be treated carefully when creating maps.
# - ZIP-code prefixes can contain multiple geographic records, so ZIP prefix should not automatically be treated as a single geographic coordinate.
# - Geographic analysis can be used later to analyze customer, seller, and order distribution by location.

# %% [markdown]
# # Sellers Analysis

# %%
sellers = pd.read_csv(
    "../data/raw/olist_sellers_dataset.csv"
)

sellers.head()
# Out:
#                           seller_id  seller_zip_code_prefix  \
# 0  3442f8959a84dea7ee197c632cb2df15                   13023
# 1  d1b65fc7debc3361ea86b5f14c68d2e2                   13844
# 2  ce3ad9de960102d0677a81f5d0bb7b2d                   20031
# 3  c0f3eea2e14555b6faeea3dd58c1b1c3                    4195
# 4  51a04a8a6bdcb23deccc82b0b80742cf                   12914
#
#          seller_city seller_state
# 0           campinas           SP
# 1         mogi guacu           SP
# 2     rio de janeiro           RJ
# 3          sao paulo           SP
# 4  braganca paulista           SP

# %%
sellers.shape
# Out:
# (3095, 4)

# %%
sellers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3095 entries, 0 to 3094
# Data columns (total 4 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   seller_id               3095 non-null   object
#  1   seller_zip_code_prefix  3095 non-null   int64
#  2   seller_city             3095 non-null   object
#  3   seller_state            3095 non-null   object
# dtypes: int64(1), object(3)
# memory usage: 96.8+ KB

# %%
sellers.isnull().sum()
# Out:
# seller_id                 0
# seller_zip_code_prefix    0
# seller_city               0
# seller_state              0
# dtype: int64

# %%
sellers["seller_id"].nunique()
# Out:
# 3095

# %%
seller_state_counts = sellers["seller_state"].value_counts()

seller_state_counts.head(10)
# Out:
# seller_state
# SP    1849
# PR     349
# MG     244
# SC     190
# RJ     171
# RS     129
# GO      40
# DF      30
# ES      23
# BA      19
# Name: count, dtype: int64

# %%
seller_state_percentage = (
    sellers["seller_state"]
    .value_counts(normalize=True)
    .mul(100)
    .round(2)
)

seller_state_percentage.head(10)
# Out:
# seller_state
# SP    59.74
# PR    11.28
# MG     7.88
# SC     6.14
# RJ     5.53
# RS     4.17
# GO     1.29
# DF     0.97
# ES     0.74
# BA     0.61
# Name: proportion, dtype: float64

# %%
seller_city_counts = sellers["seller_city"].value_counts()

seller_city_counts.head(15)
# Out:
# seller_city
# sao paulo                694
# curitiba                 127
# rio de janeiro            96
# belo horizonte            68
# ribeirao preto            52
# guarulhos                 50
# ibitinga                  49
# santo andre               45
# campinas                  41
# maringa                   40
# sao jose do rio preto     33
# sorocaba                  32
# sao bernardo do campo     32
# osasco                    32
# porto alegre              28
# Name: count, dtype: int64

# %%
sellers.duplicated().sum()
# Out:
# np.int64(0)

# %%
sellers["seller_id"].nunique()
# Out:
# 3095

# %%
seller_city_analysis["revenue_per_seller"] = (
    seller_city_analysis["revenue"] /
    seller_city_analysis["sellers"]
)

seller_city_analysis.sort_values(
    "revenue_per_seller",
    ascending=False
).head(20)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[409], line 2
#       1 seller_city_analysis["revenue_per_seller"] = (
# ----> 2     seller_city_analysis["revenue"] /
#       3     seller_city_analysis["sellers"]
#       4 )
#       6 seller_city_analysis.sort_values(
#       7     "revenue_per_seller",
#       8     ascending=False
#       9 ).head(20)
#
# NameError: name 'seller_city_analysis' is not defined

# %%
seller_city_analysis["orders_per_seller"] = (
    seller_city_analysis["orders"] /
    seller_city_analysis["sellers"]
)

seller_city_analysis.sort_values(
    "orders_per_seller",
    ascending=False
).head(20)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[410], line 2
#       1 seller_city_analysis["orders_per_seller"] = (
# ----> 2     seller_city_analysis["orders"] /
#       3     seller_city_analysis["sellers"]
#       4 )
#       6 seller_city_analysis.sort_values(
#       7     "orders_per_seller",
#       8     ascending=False
#       9 ).head(20)
#
# NameError: name 'seller_city_analysis' is not defined

# %%
seller_performance["items_per_order"] = (
    seller_performance["items"] /
    seller_performance["orders"]
)

seller_performance[
    ["seller_id", "orders", "items", "items_per_order"]
].sort_values(
    "items_per_order",
    ascending=False
).head(20)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[411], line 2
#       1 seller_performance["items_per_order"] = (
# ----> 2     seller_performance["items"] /
#       3     seller_performance["orders"]
#       4 )
#       6 seller_performance[
#       7     ["seller_id", "orders", "items", "items_per_order"]
#       8 ].sort_values(
#       9     "items_per_order",
#      10     ascending=False
#      11 ).head(20)
#
# NameError: name 'seller_performance' is not defined

# %%
seller_performance["seller_segment"] = pd.cut(
    seller_performance["revenue"],
    bins=[
        -float("inf"),
        seller_performance["revenue"].quantile(0.25),
        seller_performance["revenue"].quantile(0.50),
        seller_performance["revenue"].quantile(0.75),
        float("inf")
    ],
    labels=[
        "Low",
        "Medium",
        "High",
        "Top"
    ]
)

seller_performance["seller_segment"].value_counts()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[412], line 2
#       1 seller_performance["seller_segment"] = pd.cut(
# ----> 2     seller_performance["revenue"],
#       3     bins=[
#       4         -float("inf"),
#       5         seller_performance["revenue"].quantile(0.25),
#       6         seller_performance["revenue"].quantile(0.50),
#       7         seller_performance["revenue"].quantile(0.75),
#       8         float("inf")
#       9     ],
#      10     labels=[
#      11         "Low",
#      12         "Medium",
#      13         "High",
#      14         "Top"
#      15     ]
#      16 )
#      18 seller_performance["seller_segment"].value_counts()
#
# NameError: name 'seller_performance' is not defined

# %%
high_freight_sellers = seller_performance[
    (seller_performance["revenue"] >= seller_performance["revenue"].quantile(0.75)) &
    (seller_performance["freight_percentage"] >= seller_performance["freight_percentage"].median())
].sort_values(
    "revenue",
    ascending=False
)

high_freight_sellers[
    [
        "seller_id",
        "seller_city",
        "seller_state",
        "orders",
        "revenue",
        "freight",
        "freight_percentage"
    ]
].head(20)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[413], line 1
# ----> 1 high_freight_sellers = seller_performance[
#       2     (seller_performance["revenue"] >= seller_performance["revenue"].quantile(0.75)) &
#       3     (seller_performance["freight_percentage"] >= seller_performance["freight_percentage"].median())
#       4 ].sort_values(
#       5     "revenue",
#       6     ascending=False
#       7 )
#       9 high_freight_sellers[
#      10     [
#      11         "seller_id",
#    (...)
#      18     ]
#      19 ].head(20)
#
# NameError: name 'seller_performance' is not defined

# %% [markdown]
# ## Seller Analysis
#
# - The sellers dataset contains 3,095 unique sellers.
# - No duplicate rows or missing values were found.
# - Seller locations cover multiple Brazilian states and cities.
# - São Paulo has the highest number of sellers with 1,849 sellers, representing 59.74% of the seller base.
# - Other major seller states include Paraná, Minas Gerais, Santa Catarina, Rio de Janeiro, and Rio Grande do Sul.
# - São Paulo is also the leading seller city with 694 sellers.
# - The seller base is geographically concentrated, particularly in São Paulo state.
# - Seller count represents seller presence, not sales performance.
# - Seller performance will be analyzed later by joining sellers with order items and orders.

# %% [markdown]
# # Order Items Analysis

# %%
order_items = pd.read_csv(
    "../data/raw/olist_order_items_dataset.csv"
)

order_items.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#    shipping_limit_date   price  freight_value
# 0  2017-09-19 09:45:35   58.90          13.29
# 1  2017-05-03 11:05:13  239.90          19.93
# 2  2018-01-18 14:48:30  199.00          17.87
# 3  2018-08-15 10:10:18   12.99          12.79
# 4  2017-02-13 13:57:51  199.90          18.14

# %%
order_items.shape
# Out:
# (112650, 7)

# %%
order_items.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112650 entries, 0 to 112649
# Data columns (total 7 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   order_id             112650 non-null  object
#  1   order_item_id        112650 non-null  int64
#  2   product_id           112650 non-null  object
#  3   seller_id            112650 non-null  object
#  4   shipping_limit_date  112650 non-null  object
#  5   price                112650 non-null  float64
#  6   freight_value        112650 non-null  float64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 6.0+ MB

# %%
order_items.isnull().sum()
# Out:
# order_id               0
# order_item_id          0
# product_id             0
# seller_id              0
# shipping_limit_date    0
# price                  0
# freight_value          0
# dtype: int64

# %%
order_items.duplicated().sum()
# Out:
# np.int64(0)

# %%
order_items["order_id"].nunique()
# Out:
# 98666

# %%
order_items["product_id"].nunique()
# Out:
# 32951

# %%
order_items["seller_id"].nunique()
# Out:
# 3095

# %%
items_per_order = order_items.groupby("order_id").size()

items_per_order.describe()
# Out:
# count    98666.000000
# mean         1.141731
# std          0.538452
# min          1.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max         21.000000
# dtype: float64

# %%
order_items["price"].describe()
# Out:
# count    112650.000000
# mean        120.653739
# std         183.633928
# min           0.850000
# 25%          39.900000
# 50%          74.990000
# 75%         134.900000
# max        6735.000000
# Name: price, dtype: float64

# %%
order_items["freight_value"].describe()
# Out:
# count    112650.000000
# mean         19.990320
# std          15.806405
# min           0.000000
# 25%          13.080000
# 50%          16.260000
# 75%          21.150000
# max         409.680000
# Name: freight_value, dtype: float64

# %%
order_items["price"].sum()
# Out:
# np.float64(13591643.7)

# %%
order_items["freight_value"].sum()
# Out:
# np.float64(2251909.54)

# %%
(
    order_items["price"] + order_items["freight_value"]
).sum()
# Out:
# np.float64(15843553.24)

# %%
order_items["price"].mean()
# Out:
# np.float64(120.65373901464713)

# %%
 seller_sales = (
    order_items.groupby("seller_id")
    .agg(
        orders=("order_id", "nunique"),
        items=("order_item_id", "count"),
        revenue=("price", "sum"),
        freight=("freight_value", "sum")
    )
    .sort_values("revenue", ascending=False)
)

seller_sales.head(10)
# Out:
#                                   orders  items    revenue   freight
# seller_id
# 4869f7a5dfa277a7dca6462dcf3b52b2    1132   1156  229472.63  20168.07
# 53243585a1d6dc2643021fd1853d8905     358    410  222776.05  13080.63
# 4a3ca9315b744ce9f8e9374361493884    1806   1987  200472.92  35067.04
# fa1c13f2614d7b5c4749cbc52fecda94     585    586  194042.03  10042.70
# 7c67e1448b00f6e969d365cea6b010ab     982   1364  187923.89  51612.55
# 7e93a43ef30c4f03f38b393420bc753a     336    340  176431.87   6322.18
# da8622b14eb17ae2831f4ac5b9dab84a    1314   1551  160236.57  24955.75
# 7a67c85e85bb2ce8582c35f2203ad736    1160   1171  141745.53  20902.85
# 1025f0e2d44d7041d6cf58b6550e0bfa     915   1428  138968.55  33892.14
# 955fee9216a65b617aa5c0531780ce60    1287   1499  135171.70  25430.98

# %%
product_sales = (
    order_items.groupby("product_id")
    .agg(
        orders=("order_id", "nunique"),
        items=("order_item_id", "count"),
        revenue=("price", "sum"),
        freight=("freight_value", "sum")
    )
    .sort_values("revenue", ascending=False)
)

product_sales.head(10)
# Out:
#                                   orders  items   revenue   freight
# product_id
# bb50f2e236e5eea0100680137654686c     187    195  63885.00   3721.10
# 6cdd53843498f92890544667809f1595     151    156  54730.20   4363.79
# d6160fb7873f184099d9bc95e30376af      35     35  48899.34   1426.84
# d1c427060a0f73f6b889a5c7c61f2ac4     323    343  47214.51  13761.52
# 99a4788cb24856965c36a24e339b6058     467    488  43025.56   8046.04
# 3dd2a17168ec895c781a9191c1e95ad7     255    274  41082.60   7129.62
# 25c38557cf793876c5abdd5931f922db      38     38  38907.32   1404.63
# 5f504b3a1c75b73d6151be81eb05bdc9      63     63  37733.90   3991.91
# 53b36df67ebb7c41585e8d54d6772e08     306    323  37683.42   2274.51
# aca2eb7d00ea1a7b8ebd4e68314663af     431    527  37608.90   7211.86

# %%
order_items_products = order_items.merge(
    products[["product_id", "product_category_name"]],
    on="product_id",
    how="left"
)

order_items_products.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#    shipping_limit_date   price  freight_value product_category_name
# 0  2017-09-19 09:45:35   58.90          13.29            cool_stuff
# 1  2017-05-03 11:05:13  239.90          19.93              pet_shop
# 2  2018-01-18 14:48:30  199.00          17.87      moveis_decoracao
# 3  2018-08-15 10:10:18   12.99          12.79            perfumaria
# 4  2017-02-13 13:57:51  199.90          18.14    ferramentas_jardim

# %%
order_items_products["product_category_name"].isnull().sum()
# Out:
# np.int64(1603)

# %%
category_sales = (
    order_items_products
    .groupby("product_category_name")
    .agg(
        orders=("order_id", "nunique"),
        items=("order_item_id", "count"),
        revenue=("price", "sum"),
        freight=("freight_value", "sum")
    )
    .sort_values("revenue", ascending=False)
)

category_sales.head(15)
# Out:
#                         orders  items     revenue    freight
# product_category_name
# beleza_saude              8836   9670  1258681.34  182566.73
# relogios_presentes        5624   5991  1205005.68  100535.93
# cama_mesa_banho           9417  11115  1036988.68  204693.04
# esporte_lazer             7720   8641   988048.97  168607.51
# informatica_acessorios    6689   7827   911954.32  147318.08
# moveis_decoracao          6449   8334   729762.49  172749.30
# cool_stuff                3632   3796   635290.85   84039.10
# utilidades_domesticas     5884   6964   632248.66  146149.11
# automotivo                3897   4235   592720.11   92664.21
# ferramentas_jardim        3518   4347   485256.46   98962.75
# brinquedos                3886   4117   483946.60   77425.95
# bebes                     2885   3065   411764.89   68353.11
# perfumaria                3162   3419   399124.87   54213.84
# telefonia                 4199   4545   323667.53   71215.79
# moveis_escritorio         1273   1691   273960.70   68571.95

# %%
category_sales.head(10)
# Out:
#                         orders  items     revenue    freight
# product_category_name
# beleza_saude              8836   9670  1258681.34  182566.73
# relogios_presentes        5624   5991  1205005.68  100535.93
# cama_mesa_banho           9417  11115  1036988.68  204693.04
# esporte_lazer             7720   8641   988048.97  168607.51
# informatica_acessorios    6689   7827   911954.32  147318.08
# moveis_decoracao          6449   8334   729762.49  172749.30
# cool_stuff                3632   3796   635290.85   84039.10
# utilidades_domesticas     5884   6964   632248.66  146149.11
# automotivo                3897   4235   592720.11   92664.21
# ferramentas_jardim        3518   4347   485256.46   98962.75

# %%
category_sales["avg_order_value"] = (
    category_sales["revenue"] / category_sales["orders"]
).round(2)

category_sales["avg_item_price"] = (
    category_sales["revenue"] / category_sales["items"]
).round(2)

category_sales["freight_percentage"] = (
    category_sales["freight"] / category_sales["revenue"] * 100
).round(2)

category_sales.head(10)
# Out:
#                         orders  items     revenue    freight  avg_order_value  \
# product_category_name
# beleza_saude              8836   9670  1258681.34  182566.73           142.45
# relogios_presentes        5624   5991  1205005.68  100535.93           214.26
# cama_mesa_banho           9417  11115  1036988.68  204693.04           110.12
# esporte_lazer             7720   8641   988048.97  168607.51           127.99
# informatica_acessorios    6689   7827   911954.32  147318.08           136.34
# moveis_decoracao          6449   8334   729762.49  172749.30           113.16
# cool_stuff                3632   3796   635290.85   84039.10           174.91
# utilidades_domesticas     5884   6964   632248.66  146149.11           107.45
# automotivo                3897   4235   592720.11   92664.21           152.10
# ferramentas_jardim        3518   4347   485256.46   98962.75           137.94
#
#                         avg_item_price  freight_percentage
# product_category_name
# beleza_saude                    130.16               14.50
# relogios_presentes              201.14                8.34
# cama_mesa_banho                  93.30               19.74
# esporte_lazer                   114.34               17.06
# informatica_acessorios          116.51               16.15
# moveis_decoracao                 87.56               23.67
# cool_stuff                      167.36               13.23
# utilidades_domesticas            90.79               23.12
# automotivo                      139.96               15.63
# ferramentas_jardim              111.63               20.39

# %%
category_sales.sort_values(
    "avg_order_value",
    ascending=False
).head(10)
# Out:
#                                                orders  items    revenue  \
# product_category_name
# pcs                                               181    203  222963.13
# portateis_casa_forno_e_cafe                        75     76   47445.71
# eletrodomesticos_2                                234    238  113317.74
# agro_industria_e_comercio                         182    212   72530.47
# instrumentos_musicais                             628    680  191498.88
# eletroportateis                                   630    679  190648.58
# portateis_cozinha_e_preparadores_de_alimentos      14     15    3968.53
# telefonia_fixa                                    217    264   59583.00
# construcao_ferramentas_seguranca                  167    194   40544.52
# climatizacao                                      253    297   55024.96
#
#                                                 freight  avg_order_value  \
# product_category_name
# pcs                                             9836.30          1231.84
# portateis_casa_forno_e_cafe                     2747.86           632.61
# eletrodomesticos_2                             10600.18           484.26
# agro_industria_e_comercio                       5843.60           398.52
# instrumentos_musicais                          18638.49           304.93
# eletroportateis                                16020.25           302.62
# portateis_cozinha_e_preparadores_de_alimentos    309.76           283.47
# telefonia_fixa                                  4637.81           274.58
# construcao_ferramentas_seguranca                3919.10           242.78
# climatizacao                                    6749.23           217.49
#
#                                                avg_item_price  \
# product_category_name
# pcs                                                   1098.34
# portateis_casa_forno_e_cafe                            624.29
# eletrodomesticos_2                                     476.12
# agro_industria_e_comercio                              342.12
# instrumentos_musicais                                  281.62
# eletroportateis                                        280.78
# portateis_cozinha_e_preparadores_de_alimentos          264.57
# telefonia_fixa                                         225.69
# construcao_ferramentas_seguranca                       208.99
# climatizacao                                           185.27
#
#                                                freight_percentage
# product_category_name
# pcs                                                          4.41
# portateis_casa_forno_e_cafe                                  5.79
# eletrodomesticos_2                                           9.35
# agro_industria_e_comercio                                    8.06
# instrumentos_musicais                                        9.73
# eletroportateis                                              8.40
# portateis_cozinha_e_preparadores_de_alimentos                7.81
# telefonia_fixa                                               7.78
# construcao_ferramentas_seguranca                             9.67
# climatizacao                                                12.27

# %%
category_sales.sort_values(
    "freight_percentage",
    ascending=False
).head(10)
# Out:
#                            orders  items    revenue   freight  \
# product_category_name
# casa_conforto_2                24     30     760.27    410.31
# flores                         29     33    1110.04    488.87
# moveis_colchao_e_estofado      38     38    4368.08   1630.46
# artigos_de_natal              128    153    8800.82   3229.30
# fraldas_higiene                27     39    1567.59    573.68
# cds_dvds_musicais              12     14     730.00    224.99
# sinalizacao_e_seguranca       140    199   21509.23   6507.82
# alimentos_bebidas             227    278   15179.48   4507.99
# eletronicos                  2550   2767  160246.74  46578.32
# fashion_esporte                27     30    2119.51    578.13
#
#                            avg_order_value  avg_item_price  freight_percentage
# product_category_name
# casa_conforto_2                      31.68           25.34               53.97
# flores                               38.28           33.64               44.04
# moveis_colchao_e_estofado           114.95          114.95               37.33
# artigos_de_natal                     68.76           57.52               36.69
# fraldas_higiene                      58.06           40.19               36.60
# cds_dvds_musicais                    60.83           52.14               30.82
# sinalizacao_e_seguranca             153.64          108.09               30.26
# alimentos_bebidas                    66.87           54.60               29.70
# eletronicos                          62.84           57.91               29.07
# fashion_esporte                      78.50           70.65               27.28

# %%
category_sales["revenue_percentage"] = (
    category_sales["revenue"] /
    category_sales["revenue"].sum() * 100
).round(2)

category_sales.head(10)
# Out:
#                         orders  items     revenue    freight  avg_order_value  \
# product_category_name
# beleza_saude              8836   9670  1258681.34  182566.73           142.45
# relogios_presentes        5624   5991  1205005.68  100535.93           214.26
# cama_mesa_banho           9417  11115  1036988.68  204693.04           110.12
# esporte_lazer             7720   8641   988048.97  168607.51           127.99
# informatica_acessorios    6689   7827   911954.32  147318.08           136.34
# moveis_decoracao          6449   8334   729762.49  172749.30           113.16
# cool_stuff                3632   3796   635290.85   84039.10           174.91
# utilidades_domesticas     5884   6964   632248.66  146149.11           107.45
# automotivo                3897   4235   592720.11   92664.21           152.10
# ferramentas_jardim        3518   4347   485256.46   98962.75           137.94
#
#                         avg_item_price  freight_percentage  revenue_percentage
# product_category_name
# beleza_saude                    130.16               14.50                9.38
# relogios_presentes              201.14                8.34                8.98
# cama_mesa_banho                  93.30               19.74                7.73
# esporte_lazer                   114.34               17.06                7.37
# informatica_acessorios          116.51               16.15                6.80
# moveis_decoracao                 87.56               23.67                5.44
# cool_stuff                      167.36               13.23                4.74
# utilidades_domesticas            90.79               23.12                4.71
# automotivo                      139.96               15.63                4.42
# ferramentas_jardim              111.63               20.39                3.62

# %%
category_sales.sort_values(
    "revenue",
    ascending=False
).head(15)
# Out:
#                         orders  items     revenue    freight  avg_order_value  \
# product_category_name
# beleza_saude              8836   9670  1258681.34  182566.73           142.45
# relogios_presentes        5624   5991  1205005.68  100535.93           214.26
# cama_mesa_banho           9417  11115  1036988.68  204693.04           110.12
# esporte_lazer             7720   8641   988048.97  168607.51           127.99
# informatica_acessorios    6689   7827   911954.32  147318.08           136.34
# moveis_decoracao          6449   8334   729762.49  172749.30           113.16
# cool_stuff                3632   3796   635290.85   84039.10           174.91
# utilidades_domesticas     5884   6964   632248.66  146149.11           107.45
# automotivo                3897   4235   592720.11   92664.21           152.10
# ferramentas_jardim        3518   4347   485256.46   98962.75           137.94
# brinquedos                3886   4117   483946.60   77425.95           124.54
# bebes                     2885   3065   411764.89   68353.11           142.73
# perfumaria                3162   3419   399124.87   54213.84           126.23
# telefonia                 4199   4545   323667.53   71215.79            77.08
# moveis_escritorio         1273   1691   273960.70   68571.95           215.21
#
#                         avg_item_price  freight_percentage  revenue_percentage
# product_category_name
# beleza_saude                    130.16               14.50                9.38
# relogios_presentes              201.14                8.34                8.98
# cama_mesa_banho                  93.30               19.74                7.73
# esporte_lazer                   114.34               17.06                7.37
# informatica_acessorios          116.51               16.15                6.80
# moveis_decoracao                 87.56               23.67                5.44
# cool_stuff                      167.36               13.23                4.74
# utilidades_domesticas            90.79               23.12                4.71
# automotivo                      139.96               15.63                4.42
# ferramentas_jardim              111.63               20.39                3.62
# brinquedos                      117.55               16.00                3.61
# bebes                           134.34               16.60                3.07
# perfumaria                      116.74               13.58                2.98
# telefonia                        71.21               22.00                2.41
# moveis_escritorio               162.01               25.03                2.04

# %%
product_sales = (
    order_items_products
    .groupby("product_id")
    .agg(
        orders=("order_id", "nunique"),
        items=("order_item_id", "count"),
        revenue=("price", "sum"),
        freight=("freight_value", "sum")
    )
    .sort_values("revenue", ascending=False)
)

product_sales.head(10)
# Out:
#                                   orders  items   revenue   freight
# product_id
# bb50f2e236e5eea0100680137654686c     187    195  63885.00   3721.10
# 6cdd53843498f92890544667809f1595     151    156  54730.20   4363.79
# d6160fb7873f184099d9bc95e30376af      35     35  48899.34   1426.84
# d1c427060a0f73f6b889a5c7c61f2ac4     323    343  47214.51  13761.52
# 99a4788cb24856965c36a24e339b6058     467    488  43025.56   8046.04
# 3dd2a17168ec895c781a9191c1e95ad7     255    274  41082.60   7129.62
# 25c38557cf793876c5abdd5931f922db      38     38  38907.32   1404.63
# 5f504b3a1c75b73d6151be81eb05bdc9      63     63  37733.90   3991.91
# 53b36df67ebb7c41585e8d54d6772e08     306    323  37683.42   2274.51
# aca2eb7d00ea1a7b8ebd4e68314663af     431    527  37608.90   7211.86

# %%
product_sales["avg_price"] = (
    product_sales["revenue"] / product_sales["items"]
).round(2)

product_sales["freight_percentage"] = (
    product_sales["freight"] /
    product_sales["revenue"] * 100
).round(2)

product_sales["revenue_percentage"] = (
    product_sales["revenue"] /
    product_sales["revenue"].sum() * 100
).round(2)

product_sales.head(10)
# Out:
#                                   orders  items   revenue   freight  \
# product_id
# %%
product_sales.sort_values(
    "avg_price",
    ascending=False
).head(10)
# Out:
#                                   orders  items  revenue  freight  avg_price  \
# product_id
# 489ae2aa008f021502940f251d4cce7f       1      1  6735.00   194.31    6735.00
# 69c590f7ffc7bf8db97190b6cb6ed62e       1      1  6729.00   193.21    6729.00
# 1bdf5e6731585cf01aa8169c7028d6ad       1      1  6499.00   227.66    6499.00
# a6492cc69376c469ab6f61d8f44de961       1      1  4799.00   151.34    4799.00
# c3ed642d592594bb648ff4a04cee2747       1      1  4690.00    74.34    4690.00
# 259037a6a41845e455183f89c5035f18       1      1  4590.00    91.78    4590.00
# a1beef8f3992dbd4cd8726796aa69c53       1      1  4399.87   113.45    4399.87
# 6cdf8fc1d741c76586d8b6b15e9eef30       1      1  4099.99    75.27    4099.99
# 6902c1962dd19d540807d0ab8fade5c6       1      1  3999.90    17.01    3999.90
# 4ca7b91a31637bd24fb8e559d5e015e4       1      1  3999.00   195.76    3999.00
#
#                                   freight_percentage  revenue_percentage
# product_id
# 489ae2aa008f021502940f251d4cce7f                2.89                0.05
# 69c590f7ffc7bf8db97190b6cb6ed62e                2.87                0.05
# 1bdf5e6731585cf01aa8169c7028d6ad                3.50                0.05
# a6492cc69376c469ab6f61d8f44de961                3.15                0.04
# c3ed642d592594bb648ff4a04cee2747                1.59                0.03
# 259037a6a41845e455183f89c5035f18                2.00                0.03
# a1beef8f3992dbd4cd8726796aa69c53                2.58                0.03
# 6cdf8fc1d741c76586d8b6b15e9eef30                1.84                0.03
# 6902c1962dd19d540807d0ab8fade5c6                0.43                0.03
# 4ca7b91a31637bd24fb8e559d5e015e4                4.90                0.03

# %% [markdown]
# # Order-Level Sales Analysis

# %%
order_sales = (
    order_items
    .groupby("order_id")
    .agg(
        items=("order_item_id", "count"),
        revenue=("price", "sum"),
        freight=("freight_value", "sum")
    )
)

order_sales["total_value"] = (
    order_sales["revenue"] + order_sales["freight"]
)

order_sales.head()
# Out:
#                                   items  revenue  freight  total_value
# order_id
# 00010242fe8c5a6d1ba2dd792cb16214      1    58.90    13.29        72.19
# 00018f77f2f0320c557190d7a144bdd3      1   239.90    19.93       259.83
# 000229ec398224ef6ca0657da4fc703e      1   199.00    17.87       216.87
# 00024acbcdf0a6daa1e931b038114c75      1    12.99    12.79        25.78
# 00042b26cf59d7ce69dfabb4e55b4fd9      1   199.90    18.14       218.04

# %%
order_sales.shape
# Out:
# (98666, 4)

# %%
order_sales.describe()
# Out:
#               items       revenue       freight   total_value
# count  98666.000000  98666.000000  98666.000000  98666.000000
# mean       1.141731    137.754076     22.823562    160.577638
# std        0.538452    210.645145     21.650909    220.466087
# min        1.000000      0.850000      0.000000      9.590000
# 25%        1.000000     45.900000     13.850000     61.980000
# 50%        1.000000     86.900000     17.170000    105.290000
# 75%        1.000000    149.900000     24.040000    176.870000
# max       21.000000  13440.000000   1794.960000  13664.080000

# %%
print("Total Orders:", len(order_sales))
print("Total Revenue:", round(order_sales["revenue"].sum(), 2))
print("Total Freight:", round(order_sales["freight"].sum(), 2))
print("Total Order Value:", round(order_sales["total_value"].sum(), 2))
print("Average Order Value:", round(order_sales["total_value"].mean(), 2))
print("Median Order Value:", round(order_sales["total_value"].median(), 2))
# Out:
# Total Orders: 98666
# Total Revenue: 13591643.7
# Total Freight: 2251909.54
# Total Order Value: 15843553.24
# Average Order Value: 160.58
# Median Order Value: 105.29

# %%
order_sales["items"].value_counts().sort_index()
# Out:
# items
# 1     88863
# 2      7516
# 3      1322
# 4       505
# 5       204
# 6       198
# 7        22
# 8         8
# 9         3
# 10        8
# 11        4
# 12        5
# 13        1
# 14        2
# 15        2
# 20        2
# 21        1
# Name: count, dtype: int64

# %%
order_sales.sort_values(
    "total_value",
    ascending=False
).head(10)
# Out:
#                                   items  revenue  freight  total_value
# order_id
# 03caa2c082116e1d31e67e9ae3700499      8  13440.0   224.08     13664.08
# 736e1922ae60d0d6a89247b851902527      4   7160.0   114.88      7274.88
# 0812eb902a67711a1cb742b3cdaa65ae      1   6735.0   194.31      6929.31
# fefacc66af859508bf1a7934eab1e97f      1   6729.0   193.21      6922.21
# f5136e38d1a14a4dbd87dff67da82701      1   6499.0   227.66      6726.66
# 2cc9089445046817a7539d90805e6e5a      6   5934.6   146.94      6081.54
# a96610ab360d42a2e5335a3998b4718a      1   4799.0   151.34      4950.34
# b4c4b76c642808cbe472a32b86cddc95      2   4599.9   209.54      4809.44
# 199af31afc78c699f0dbf71fb178d4d4      1   4690.0    74.34      4764.34
# 8dbc85d1447242f3b127dda390d56e19      1   4590.0    91.78      4681.78

# %%
order_sales["freight_percentage"] = (
    order_sales["freight"] /
    order_sales["revenue"] * 100
).round(2)

order_sales["freight_percentage"].describe()
# Out:
# count    98666.000000
# mean        30.838844
# std         31.476213
# min          0.000000
# 25%         13.190000
# 50%         22.440000
# 75%         38.020000
# max       2144.710000
# Name: freight_percentage, dtype: float64

# %%
# 1. Basic statistics of order value
order_sales["total_value"].describe()
# Out:
# count    98666.000000
# mean       160.577638
# std        220.466087
# min          9.590000
# 25%         61.980000
# 50%        105.290000
# 75%        176.870000
# max      13664.080000
# Name: total_value, dtype: float64

# %%
# 2. Average order value
order_sales["total_value"].mean()
# Out:
# np.float64(160.57763809214924)

# %%
# 3. Median order value
order_sales["total_value"].median()
# Out:
# np.float64(105.29)

# %%
# 4. Orders with multiple items
(order_sales["items"] > 1).sum()
# Out:
# np.int64(9803)

# %%
# 5. Percentage of orders with multiple items
((order_sales["items"] > 1).mean() * 100).round(2)
# Out:
# np.float64(9.94)

# %%
order_sales["order_value_group"] = pd.cut(
    order_sales["total_value"],
    bins=[0, 50, 100, 200, 500, 1000, float("inf")],
    labels=[
        "< 50",
        "50–100",
        "100–200",
        "200–500",
        "500–1000",
        "1000+"
    ]
)

order_sales["order_value_group"].value_counts().sort_index()
# Out:
# order_value_group
# < 50        16855
# 50–100      30050
# 100–200     31668
# 200–500     15860
# 500–1000     3085
# 1000+        1148
# Name: count, dtype: int64

# %%
order_value_analysis = (
    order_sales
    .groupby("order_value_group", observed=True)
    .agg(
        orders=("total_value", "count"),
        avg_order_value=("total_value", "mean"),
        median_order_value=("total_value", "median")
    )
    .round(2)
)

order_value_analysis
# Out:
#                    orders  avg_order_value  median_order_value
# order_value_group
# < 50                16855            36.91               37.58
# 50–100              30050            73.31               72.18
# 100–200             31668           142.01              138.60
# 200–500             15860           290.04              267.50
# 500–1000             3085           680.75              651.84
# 1000+                1148          1586.49             1352.61

# %%
order_value_analysis["order_percentage"] = (
    order_value_analysis["orders"]
    / order_value_analysis["orders"].sum()
    * 100
).round(2)

order_value_analysis
# Out:
#                    orders  avg_order_value  median_order_value  \
# order_value_group
# < 50                16855            36.91               37.58
# 50–100              30050            73.31               72.18
# 100–200             31668           142.01              138.60
# 200–500             15860           290.04              267.50
# 500–1000             3085           680.75              651.84
# 1000+                1148          1586.49             1352.61
#
#                    order_percentage
# order_value_group
# < 50                          17.08
# 50–100                        30.46
# 100–200                       32.10
# 200–500                       16.07
# 500–1000                       3.13
# 1000+                          1.16

# %%
high_value_orders = (
    order_sales
    .sort_values("total_value", ascending=False)
    .head(20)
)

high_value_orders
# Out:
#                                   items   revenue  freight  total_value  \
# order_id
# 03caa2c082116e1d31e67e9ae3700499      8  13440.00   224.08     13664.08
# 736e1922ae60d0d6a89247b851902527      4   7160.00   114.88      7274.88
# 0812eb902a67711a1cb742b3cdaa65ae      1   6735.00   194.31      6929.31
# fefacc66af859508bf1a7934eab1e97f      1   6729.00   193.21      6922.21
# f5136e38d1a14a4dbd87dff67da82701      1   6499.00   227.66      6726.66
# 2cc9089445046817a7539d90805e6e5a      6   5934.60   146.94      6081.54
# a96610ab360d42a2e5335a3998b4718a      1   4799.00   151.34      4950.34
# b4c4b76c642808cbe472a32b86cddc95      2   4599.90   209.54      4809.44
# 199af31afc78c699f0dbf71fb178d4d4      1   4690.00    74.34      4764.34
# 8dbc85d1447242f3b127dda390d56e19      1   4590.00    91.78      4681.78
# 426a9742b533fc6fed17d1fd6d143d7e      1   4399.87   113.45      4513.32
# d2f270487125ddc41fd134c4003ad1d7      2   4400.00    45.50      4445.50
# 80dfedb6d17bf23539beeef3c768f4d7      1   3999.00   195.76      4194.76
# 68101694e5c5dc7330c91e1bbc36214f      1   4099.99    75.27      4175.26
# b239ca7cd485940b31882363b52e6674      1   4059.00   104.51      4163.51
# 9a3966c23190dbdbaabed08e8429c006      1   3980.00    62.74      4042.74
# 9de73f3e6157169ad6c32b9f313c7dcb      1   3899.00   135.44      4034.44
# 86c4eab1571921a6a6e248ed312f5a5a      1   3999.90    17.01      4016.91
# 41b7766bb1df487d17fb9725b78ff509      1   3930.00    49.55      3979.55
# a53e05ecd2ed1f46a2b8e1f5828be7c6      1   3690.00   136.80      3826.80
#
#                                   freight_percentage order_value_group
# order_id
# 03caa2c082116e1d31e67e9ae3700499                1.67             1000+
# 736e1922ae60d0d6a89247b851902527                1.60             1000+
# 0812eb902a67711a1cb742b3cdaa65ae                2.89             1000+
# fefacc66af859508bf1a7934eab1e97f                2.87             1000+
# f5136e38d1a14a4dbd87dff67da82701                3.50             1000+
# 2cc9089445046817a7539d90805e6e5a                2.48             1000+
# a96610ab360d42a2e5335a3998b4718a                3.15             1000+
# b4c4b76c642808cbe472a32b86cddc95                4.56             1000+
# 199af31afc78c699f0dbf71fb178d4d4                1.59             1000+
# 8dbc85d1447242f3b127dda390d56e19                2.00             1000+
# 426a9742b533fc6fed17d1fd6d143d7e                2.58             1000+
# d2f270487125ddc41fd134c4003ad1d7                1.03             1000+
# 80dfedb6d17bf23539beeef3c768f4d7                4.90             1000+
# 68101694e5c5dc7330c91e1bbc36214f                1.84             1000+
# b239ca7cd485940b31882363b52e6674                2.57             1000+
# 9a3966c23190dbdbaabed08e8429c006                1.58             1000+
# 9de73f3e6157169ad6c32b9f313c7dcb                3.47             1000+
# 86c4eab1571921a6a6e248ed312f5a5a                0.43             1000+
# 41b7766bb1df487d17fb9725b78ff509                1.26             1000+
# a53e05ecd2ed1f46a2b8e1f5828be7c6                3.71             1000+

# %%
multi_item_orders = order_sales[order_sales["items"] > 1]

multi_item_orders.shape
# Out:
# (9803, 6)

# %%
multi_item_orders["total_value"].describe()
# Out:
# count     9803.000000
# mean       249.699936
# std        314.389291
# min         25.780000
# 25%        110.740000
# 50%        172.320000
# 75%        280.795000
# max      13664.080000
# Name: total_value, dtype: float64

# %% [markdown]
# # Analyze seller performance

# %%
seller_sales = (
    order_items
    .groupby("seller_id")
    .agg(
        orders=("order_id", "nunique"),
        items=("order_item_id", "count"),
        revenue=("price", "sum"),
        freight=("freight_value", "sum")
    )
)

seller_sales["avg_order_value"] = (
    seller_sales["revenue"] / seller_sales["orders"]
).round(2)

seller_sales["avg_item_price"] = (
    seller_sales["revenue"] / seller_sales["items"]
).round(2)

seller_sales["freight_percentage"] = (
    seller_sales["freight"] / seller_sales["revenue"] * 100
).round(2)

seller_sales["revenue_percentage"] = (
    seller_sales["revenue"] /
    seller_sales["revenue"].sum() * 100
).round(2)

# %%
seller_sales.sort_values(
    "revenue",
    ascending=False
).head(15)
# Out:
#                                   orders  items    revenue   freight  \
# seller_id
# 4869f7a5dfa277a7dca6462dcf3b52b2    1132   1156  229472.63  20168.07
# 53243585a1d6dc2643021fd1853d8905     358    410  222776.05  13080.63
# 4a3ca9315b744ce9f8e9374361493884    1806   1987  200472.92  35067.04
# fa1c13f2614d7b5c4749cbc52fecda94     585    586  194042.03  10042.70
# 7c67e1448b00f6e969d365cea6b010ab     982   1364  187923.89  51612.55
# 7e93a43ef30c4f03f38b393420bc753a     336    340  176431.87   6322.18
# da8622b14eb17ae2831f4ac5b9dab84a    1314   1551  160236.57  24955.75
# 7a67c85e85bb2ce8582c35f2203ad736    1160   1171  141745.53  20902.85
# 1025f0e2d44d7041d6cf58b6550e0bfa     915   1428  138968.55  33892.14
# 955fee9216a65b617aa5c0531780ce60    1287   1499  135171.70  25430.98
# 46dc3b2cc0980fb8ec44634e21d2718e     521    542  128111.19  11798.50
# 6560211a19b47992c3666cc44a7e94c0    1854   2033  123304.83  27960.94
# 620c87c171fb2a6dd6e8bb4dec959fc6     740    798  114774.50  14135.21
# 7d13fca15225358621be4086e1eb0964     565    578  113628.97   8632.05
# 5dceca129747e92ff8ef7a997dc4f8ca     325    346  112155.53  13661.39
#
#                                   avg_order_value  avg_item_price  \
# seller_id
# 4869f7a5dfa277a7dca6462dcf3b52b
#
#                                   avg_order_value  avg_item_price  \
# seller_id
# 2bf6a2c1e71bbd29a4ad64e6d3c3629f          1687.63         1633.19
# b839e41795b7f3ad94cc2014a52f6796          1297.85         1189.69
# 7b0df942f46435babab05d49b744b2c4           706.27          706.27
# ba90964cff9b9e0e6f32b23b82465f7b          1163.49         1163.49
# 966cb4760537b1404caedd472cc610a5           683.81          683.81
# 1f1bb1f0859883505541bdd6606193e5           594.11          553.13
# 7e93a43ef30c4f03f38b393420bc753a           525.09          518.92
# 2b3e4a2a3ea8e01938cabda2a3e5cc79           454.41          437.58
# 8cc6a0e5738e61a87b03c78b2ba9db4b           554.68          512.02
# 66e0557ecc2b4dbea057e93f215f68d8           402.58          402.58
# b94cc9f10ddc85e4ba73a6f7974e7101           649.90          649.90
# e7df4cd29ab5abab70fb0783ddb53987           417.77          400.36
# 7b1222c3624aa89b9558b50a2594188c           459.25          459.25
# d650b663c3b5f6fb392b6326366efa9a           320.72          320.72
# ed4acab38528488b65a9a9c603ff024a           398.73          318.99
#
#                                   freight_percentage  revenue_percentage
# seller_id
# 2bf6a2c1e71bbd29a4ad64e6d3c3629f                1.98                0.37
# b839e41795b7f3ad94cc2014a52f6796                2.15                0.32
# 7b0df942f46435babab05d49b744b2c4                2.97                0.17
# ba90964cff9b9e0e6f32b23b82465f7b                2.97                0.33
# 966cb4760537b1404caedd472cc610a5                3.22                0.38
# 1f1bb1f0859883505541bdd6606193e5                3.25                0.12
# 7e93a43ef30c4f03f38b393420bc753a                3.58                1.30
# 2b3e4a2a3ea8e01938cabda2a3e5cc79                3.83                0.17
# 8cc6a0e5738e61a87b03c78b2ba9db4b                3.95                0.10
# 66e0557ecc2b4dbea057e93f215f68d8                3.99                0.09
# b94cc9f10ddc85e4ba73a6f7974e7101                4.03                0.19
# e7df4cd29ab5abab70fb0783ddb53987                4.30                0.07
# 7b1222c3624aa89b9558b50a2594188c                4.53                0.07
# d650b663c3b5f6fb392b6326366efa9a                4.73                0.14
# ed4acab38528488b65a9a9c603ff024a                4.78                0.09

# %% [markdown]
# # Customer-Level Analysis

# %%
customers.shape
# Out:
# (99441, 5)

# %%
customers.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
# 3                      8775        mogi das cruzes             SP
# 4                     13056               campinas             SP

# %%
customers.isnull().sum()
# Out:
# customer_id                 0
# customer_unique_id          0
# customer_zip_code_prefix    0
# customer_city               0
# customer_state              0
# dtype: int64

# %%
customers.duplicated().sum()
# Out:
# np.int64(0)

# %%
customers["customer_id"].nunique()
# Out:
# 99441

# %%
customers["customer_unique_id"].nunique()
# Out:
# 96096

# %%
orders.shape
# Out:
# (99441, 8)

# %%
orders.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06  2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39  2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# 1          2018-07-26 14:31:00           2018-08-07 15:27:45
# 2          2018-08-08 13:50:00           2018-08-17 18:06:29
# 3          2017-11-22 13:39:59           2017-12-02 00:28:42
# 4          2018-02-14 19:46:34           2018-02-16 18:17:02
#
#   order_estimated_delivery_date
# 0           2017-10-18 00:00:00
# 1           2018-08-13 00:00:00
# 2           2018-09-04 00:00:00
# 3           2017-12-15 00:00:00
# 4           2018-02-26 00:00:00

# %%
orders.isnull().sum()
# Out:
# order_id                            0
# customer_id                         0
# order_status                        0
# order_purchase_timestamp            0
# order_approved_at                 160
# order_delivered_carrier_date     1783
# order_delivered_customer_date    2965
# order_estimated_delivery_date       0
# dtype: int64

# %%
orders.duplicated().sum()
# Out:
# np.int64(0)

# %%
orders["order_id"].nunique()
# Out:
# 99441

# %%
orders["customer_id"].nunique()
# Out:
# 99441

# %%
orders["order_status"].value_counts()
# Out:
# order_status
# delivered      96478
# shipped         1107
# canceled         625
# unavailable      609
# invoiced         314
# processing       301
# created            5
# approved           2
# Name: count, dtype: int64

# %%
customer_orders = orders.merge(
    customers[[
        "customer_id",
        "customer_unique_id",
        "customer_city",
        "customer_state"
    ]],
    on="customer_id",
    how="left"
)

# %%
customer_orders.shape
# Out:
# (99441, 11)

# %%
customer_orders["customer_unique_id"].isnull().sum()
# Out:
# np.int64(0)

# %%
customer_orders["customer_unique_id"].nunique()
# Out:
# 96096

# %%
customer_order_frequency = (
    customer_orders
    .groupby("customer_unique_id")
    .agg(
        orders=("order_id", "nunique"),
        first_order=("order_purchase_timestamp", "min"),
        last_order=("order_purchase_timestamp", "max")
    )
)

customer_order_frequency["orders"].describe()
# Out:
# count    96096.000000
# mean         1.034809
# std          0.214384
# min          1.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max         17.000000
# Name: orders, dtype: float64

# %%
customer_order_frequency["orders"].value_counts().sort_index()
# Out:
# orders
# 1     93099
# 2      2745
# 3       203
# 4        30
# 5         8
# 6         6
# 7         3
# 9         1
# 17        1
# Name: count, dtype: int64

# %%
customer_order_frequency["customer_type"] = np.where(
    customer_order_frequency["orders"] == 1,
    "One-time",
    "Repeat"
)

customer_type_analysis = (
    customer_order_frequency["customer_type"]
    .value_counts()
    .to_frame("customers")
)

customer_type_analysis["percentage"] = (
    customer_type_analysis["customers"]
    / customer_type_analysis["customers"].sum()
    * 100
).round(2)

customer_type_analysis
# Out:
#                customers  percentage
# customer_type
# One-time           93099       96.88
# Repeat              2997        3.12

# %%
# Convert order_id from index into a column
order_sales_reset = order_sales.reset_index()

# Check columns
print(order_sales_reset.columns)
# Out:
# Index(['order_id', 'items', 'revenue', 'freight', 'total_value',
#        'freight_percentage', 'order_value_group'],
#       dtype='object')

# %%
customer_sales = customer_orders[
    ["order_id", "customer_unique_id", "customer_city", "customer_state"]
].merge(
    order_sales_reset[
        ["order_id", "items", "revenue", "freight", "total_value"]
    ],
    on="order_id",
    how="inner"
)

# %%
customer_sales.shape
# Out:
# (98666, 8)

# %%
customer_sales.head()
# Out:
#                            order_id                customer_unique_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  7c396fd4830fd04220f754e42b4e5bff
# 1  53cdb2fc8bc7dce0b6741e2150273451  af07308b275d755c9edb36a90c618231
# 2  47770eb9100c2d0c44946d9cf07ec65d  3a653a41f6f9fc3d2a113cf8398680e8
# 3  949d5b44dbf5de918fe9c16f97b45f8a  7c142cf63193a1473d2e66489a9ae977
# 4  ad21c59c0840e6cb83a9ceb5573f8159  72632f0f9dd73dfee390c9b22eb56dd6
#
#              customer_city customer_state  items  revenue  freight  \
# 0                sao paulo             SP      1    29.99     8.72
# 1                barreiras             BA      1   118.70    22.76
# 2               vianopolis             GO      1   159.90    19.22
# 3  sao goncalo do amarante             RN      1    45.00    27.20
# 4              santo andre             SP      1    19.90     8.72
#
#    total_value
# 0        38.71
# 1       141.46
# 2       179.12
# 3        72.20
# 4        28.62

# %%
customer_sales.isnull().sum()
# Out:
# order_id              0
# customer_unique_id    0
# customer_city         0
# customer_state        0
# items                 0
# revenue               0
# freight               0
# total_value           0
# dtype: int64

# %%
customer_revenue = (
    customer_sales
    .groupby("customer_unique_id")
    .agg(
        orders=("order_id", "nunique"),
        items=("items", "sum"),
        revenue=("revenue", "sum"),
        freight=("freight", "sum"),
        total_value=("total_value", "sum")
    )
)

customer_revenue["avg_order_value"] = (
    customer_revenue["total_value"]
    / customer_revenue["orders"]
).round(2)

customer_revenue.head()
# Out:
#                                   orders  items  revenue  freight  \
# customer_unique_id
# 0000366f3b9a7992bf8c76cfdf3221e2       1      1   129.90    12.00
# 0000b849f77a49e4a4ce2b2a4ca5be3f       1      1    18.90     8.29
# 0000f46a3911fa3c0805444483337064       1      1    69.00    17.22
# 0000f6ccb0745a6a4b88665a16c9f078       1      1    25.99    17.63
# 0004aac84e0df4da2b147fca70cf8255       1      1   180.00    16.89
#
#                                   total_value  avg_order_value
# customer_unique_id
# 0000366f3b9a7992bf8c76cfdf3221e2       141.90           141.90
# 0000b849f77a49e4a4ce2b2a4ca5be3f        27.19            27.19
# 0000f46a3911fa3c0805444483337064        86.22            86.22
# 0000f6ccb0745a6a4b88665a16c9f078        43.62            43.62
# 0004aac84e0df4da2b147fca70cf8255       196.89           196.89

# %%
customer_revenue.describe()
# Out:
#              orders        items       revenue       freight   total_value  \
# count  95420.000000  95420.00000  95420.000000  95420.000000  95420.000000
# mean       1.034018      1.18057    142.440198     23.599974    166.040172
# std        0.211234      0.62145    217.656355     22.878663    228.320333
# min        1.000000      1.00000      0.850000      0.000000      9.590000
# 25%        1.000000      1.00000     47.900000     14.080000     63.100000
# 50%        1.000000      1.00000     89.900000     17.600000    107.940000
# 75%        1.000000      1.00000    155.000000     25.540000    183.220000
# max       16.000000     24.00000  13440.000000   1794.960000  13664.080000
#
#        avg_order_value
# count     95420.000000
# mean        161.044772
# std         221.191785
# min           9.590000
# 25%          62.410000
# 50%         105.770000
# 75%         177.122500
# max       13664.080000

# %%
customer_revenue.sort_values(
    "total_value",
    ascending=False
).head(20)
# Out:
#                                   orders  items   revenue  freight  \
# customer_unique_id
# 0a0a92112bd4c708ca5fde585afaa
# %%
customer_revenue["customer_value_group"] = pd.cut(
    customer_revenue["total_value"],
    bins=[0, 50, 100, 200, 500, 1000, float("inf")],
    labels=[
        "< 50",
        "50–100",
        "100–200",
        "200–500",
        "500–1000",
        "1000+"
    ]
)

customer_value_analysis = (
    customer_revenue
    .groupby("customer_value_group", observed=True)
    .agg(
        customers=("total_value", "count"),
        avg_customer_value=("total_value", "mean"),
        median_customer_value=("total_value", "median"),
        total_revenue=("total_value", "sum")
    )
)

customer_value_analysis["customer_percentage"] = (
    customer_value_analysis["customers"]
    / customer_value_analysis["customers"].sum()
    * 100
).round(2)

customer_value_analysis["revenue_percentage"] = (
    customer_value_analysis["total_revenue"]
    / customer_value_analysis["total_revenue"].sum()
    * 100
).round(2)

customer_value_analysis
# Out:
#                       customers  avg_customer_value  median_customer_value  \
# customer_value_group
# < 50                      15768           36.972040                  37.61
# 50–100                    28359           73.373311                  72.28
# 100–200                   30738          142.383134                 138.87
# 200–500                   16131          291.905774                 269.75
# 500–1000                   3233          680.058704                 649.86
# 1000+                      1191         1591.813434                1353.28
#
#                       total_revenue  customer_percentage  revenue_percentage
# customer_value_group
# < 50                      582975.12                16.52                3.68
# 50–100                   2080793.73                29.72               13.13
# 100–200                  4376572.76                32.21               27.62
# 200–500                  4708732.04                16.91               29.72
# 500–1000                 2198629.79                 3.39               13.88
# 1000+                    1895849.80                 1.25               11.97

# %%
top_customers = (
    customer_revenue
    .sort_values("total_value", ascending=False)
    .head(20)
)

top_customers
# Out:
#                                   orders  items   revenue  freight  \
# customer_unique_id
# 0a0a92112bd4c708ca5fde585afaa872       1      8  13440.00   224.08
# da122df9eeddfedc1dc1f5349a1a690c       2      2   7388.00   183.63
# 763c8b1c9c68a0229c42c9fc6f662b93       1      4   7160.00   114.88
# dc4802a71eae9be1dd28f5d788ceb526       1      1   6735.00   194.31
# 459bef486812aa25204be022145caa62       1      1   6729.00   193.21
# ff4159b92c40ebe40454e3e6a7c35ed6       1      1   6499.00   227.66
# 4007669dec559734d6f53e029e360987       1      6   5934.60   146.94
# 5d0a2980b292d049061542014e8960bf       1      2   4599.90   209.54
# eebb5dda148d3893cdaf5b5ca3040ccb       1      1   4690.00    74.34
# 48e1ac109decbb87765a3eade6854098       1      1   4590.00    91.78
# c8460e4251689ba205045f3ea17884a1       4     24   4080.00   575.88
# edde2314c6c30e864a128ac95d6b2112       1      1   4399.87   113.45
# a229eba70ec1c2abef51f04987deb7a5       1      2   4400.00    45.50
# edf81e1f3070b9dac83ec83dacdbb9bc       1      1   3999.00   195.76
# fa562ef24d41361e476e748681810e1e       1      1   4099.99    75.27
# ca27f3dac28fb1063faddd424c9d95fa       1      1   4059.00   104.51
# 055ec572ac7f3c7bdd04a183830ebe59       2      2   3999.98    53.10
# 5e713be0853d8986528d7869a0811d2b       1      1   3980.00    62.74
# 58483a1c055dfb600f57c5b867174542       1      1   3899.00   135.44
# 011875f0176909c5cf0b14a9138bb691       1      1   3999.90    17.01
#
#                                   total_value  avg_order_value  \
# customer_unique_id
# 0a0a92112bd4c708ca5fde585afaa
# customer_unique_id
# 0a0a92112bd4c708ca5fde585afaa872                0.10                1000+
# da122df9eeddfedc1dc1f5349a1a690c                0.05                1000+
# 763c8b1c9c68a0229c42c9fc6f662b93                0.05                1000+
# dc4802a71eae9be1dd28f5d788ceb526                0.05                1000+
# 459bef486812aa25204be022145caa62                0.05                1000+
# ff4159b92c40ebe40454e3e6a7c35ed6                0.05                1000+
# 4007669dec559734d6f53e029e360987                0.04                1000+
# eebb5dda148d3893cdaf5b5ca3040ccb                0.03                1000+
# 5d0a2980b292d049061542014e8960bf                0.03                1000+
# 48e1ac109decbb87765a3eade6854098                0.03                1000+
# a229eba70ec1c2abef51f04987deb7a5                0.03                1000+
# edde2314c6c30e864a128ac95d6b2112                0.03                1000+
# fa562ef24d41361e476e748681810e1e                0.03                1000+
# c8460e4251689ba205045f3ea17884a1                0.03                1000+
# ca27f3dac28fb1063faddd424c9d95fa                0.03                1000+
# 055ec572ac7f3c7bdd04a183830ebe59                0.03                1000+
# 011875f0176909c5cf0b14a9138bb691                0.03                1000+
# edf81e1f3070b9dac83ec83dacdbb9bc                0.03                1000+
# 5e713be0853d8986528d7869a0811d2b                0.03                1000+
# f0767ae738c3d90e7b737d7b8b8bb4d1                0.03                1000+

# %% [markdown]
# # Geographic / State Analysis

# %%
state_customer_analysis = (
    customer_sales
    .groupby("customer_state")
    .agg(
        customers=("customer_unique_id", "nunique"),
        orders=("order_id", "nunique"),
        items=("items", "sum"),
        revenue=("revenue", "sum"),
        freight=("freight", "sum"),
        total_value=("total_value", "sum")
    )
    .sort_values("revenue", ascending=False)
)

state_customer_analysis["revenue_percentage"] = (
    state_customer_analysis["revenue"]
    / state_customer_analysis["revenue"].sum()
    * 100
).round(2)

state_customer_analysis["avg_order_value"] = (
    state_customer_analysis["total_value"]
    / state_customer_analysis["orders"]
).round(2)

state_customer_analysis
# Out:
#                 customers  orders  items     revenue    freight  total_value  \
# customer_state
# SP                  39981   41375  47449  5202955.05  718723.07   5921678.12
# RJ                  12303   12762  14579  1824092.67  305589.31   2129681.98
# MG                  11178   11544  13129  1585308.03  270853.46   1856161.49
# RS                   5249    5432   6235   750304.02  135522.74    885826.76
# PR                   4840    4998   5740   683083.76  117851.68    800935.44
# SC                   3513    3612   4176   520553.34   89660.26    610213.60
# BA                   3257    3358   3799   511349.99  100156.68    611506.67
# DF                   2062    2125   2406   302603.94   50625.50    353229.44
# GO                   1942    2007   2333   294591.95   53114.98    347706.93
# ES                   1956    2025   2256   275037.31   49764.60    324801.91
# PE                   1605    1648   1806   262788.03   59449.66    322237.69
# CE                   1305    1327   1478   227254.71   48351.59    275606.30
# PA                    944     970   1080   178947.81   38699.30    217647.11
# MT                    873     903   1055   156453.53   29715.43    186168.96
# MA                    719     740    824   119648.22   31523.77    151171.99
# MS                    688     709    819   116812.64   19144.03    135956.67
# PB                    516     532    602   115268.08   25719.73    140987.81
# PI                    481     493    542    86914.08   21218.20    108132.28
# RN                    471     482    529    83034.98   18860.10    101895.08
# AL                    399     411    444    80314.81   15914.59     96229.40
# SE                    338     345    385    58920.85   14111.47     73032.32
# TO                    272     279    315    49621.74   11732.68     61354.42
# RO                    235     247    278    46140.64   11417.38     57558.02
# AM                    142     147    165    22356.84    5478.89     27835.73
# AC                     77      81     92    15982.95    3686.75     19669.70
# AP                     67      68     82    13474.30    2788.50     16262.80
# RR                     45      46     52     7829.43    2235.19     10064.62
#
#                 revenue_percentage  avg_order_value
# customer_state
# SP                           38.28           143.12
# RJ                           13.42           166.88
# MG                           11.66           160.79
# RS                            5.52           163.08
# PR                            5.03           160.25
# SC                            3.83           168.94
# BA                            3.76           182.10
# DF                            2.23           166.23
# GO                            2.17           173.25
# ES                            2.02           160.40
# PE                            1.93           195.53
# CE                            1.67           207.69
# PA                            1.32           224.38
# MT                            1.15           206.17
# MA                            0.88           204.29
# MS                            0.86           191.76
# PB                            0.85           265.01
# PI                            0.64           219.34
# RN                            0.61           211.40
# AL                            0.59           234.13
# SE                            0.43           211.69
# TO                            0.37           219.91
# RO                            0.34           233.03
# AM                            0.16           189.36
# AC                            0.12           242.84
# AP                            0.10           239.16
# RR                            0.06           218.80

# %%
state_customer_analysis.head(10)
# Out:
#                 customers  orders  items     revenue    freight  total_value  \
# customer_state
# SP                  39981   41375  47449  5202955.05  718723.07   5921678.12
# RJ                  12303   12762  14579  1824092.67  305589.31   2129681.98
# MG                  11178   11544  13129  1585308.03  270853.46   1856161.49
# RS                   5249    5432   6235   750304.02  135522.74    885826.76
# PR                   4840    4998   5740   683083.76  117851.68    800935.44
# SC                   3513    3612   4176   520553.34   89660.26    610213.60
# BA                   3257    3358   3799   511349.99  100156.68    611506.67
# DF                   2062    2125   2406   302603.94   50625.50    353229.44
# GO                   1942    2007   2333   294591.95   53114.98    347706.93
# ES                   1956    2025   2256   275037.31   49764.60    324801.91
#
#                 revenue_percentage  avg_order_value
# customer_state
# SP                           38.28           143.12
# RJ                           13.42           166.88
# MG                           11.66           160.79
# RS                            5.52           163.08
# PR                            5.03           160.25
# SC                            3.83           168.94
# BA                            3.76           182.10
# DF                            2.23           166.23
# GO                            2.17           173.25
# ES                            2.02           160.40

# %% [markdown]
# # Time / Monthly Sales Analysis

# %%
orders["order_purchase_timestamp"] = pd.to_datetime(
    orders["order_purchase_timestamp"]
)

orders["year"] = orders["order_purchase_timestamp"].dt.year
orders["month"] = orders["order_purchase_timestamp"].dt.month
orders["month_name"] = orders["order_purchase_timestamp"].dt.month_name()
orders["year_month"] = orders["order_purchase_timestamp"].dt.to_period("M")

# %%
orders[
    ["order_purchase_timestamp", "year", "month", "month_name", "year_month"]
].head()
# Out:
#   order_purchase_timestamp  year  month month_name year_month
# 0      2017-10-02 10:56:33  2017     10    October    2017-10
# 1      2018-07-24 20:41:37  2018      7       July    2018-07
# 2      2018-08-08 08:38:49  2018      8     August    2018-08
# 3      2017-11-18 19:28:06  2017     11   November    2017-11
# 4      2018-02-13 21:18:39  2018      2   February    2018-02

# %%
order_sales.columns
# Out:
# Index(['items', 'revenue', 'freight', 'total_value', 'freight_percentage',
#        'order_value_group'],
#       dtype='object')

# %%
monthly_sales = (
    orders[
        ["order_id", "order_purchase_timestamp", "year", "month",
         "month_name", "year_month"]
    ]
    .merge(
        order_sales[
            ["items", "revenue", "freight", "total_value"]
        ],
        left_on="order_id",
        right_index=True,
        how="inner"
    )
)

monthly_sales.head()
# Out:
#                            order_id order_purchase_timestamp  year  month  \
# 0  e481f51cbdc54678b7cc49136f2d6af7      2017-10-02 10:56:33  2017     10
# 1  53cdb2fc8bc7dce0b6741e2150273451      2018-07-24 20:41:37  2018      7
# 2  47770eb9100c2d0c44946d9cf07ec65d      2018-08-08 08:38:49  2018      8
# 3  949d5b44dbf5de918fe9c16f97b45f8a      2017-11-18 19:28:06  2017     11
# 4  ad21c59c0840e6cb83a9ceb5573f8159      2018-02-13 21:18:39  2018      2
#
#   month_name year_month  items  revenue  freight  total_value
# 0    October    2017-10      1    29.99     8.72        38.71
# 1       July    2018-07      1   118.70    22.76       141.46
# 2     August    2018-08      1   159.90    19.22       179.12
# 3   November    2017-11      1    45.00    27.20        72.20
# 4   February    2018-02      1    19.90     8.72        28.62

# %%
monthly_sales.shape
# Out:
# (98666, 10)

# %%
monthly_sales.isnull().sum()
# Out:
# order_id                    0
# order_purchase_timestamp    0
# year                        0
# month                       0
# month_name                  0
# year_month                  0
# items                       0
# revenue                     0
# freight                     0
# total_value                 0
# dtype: int64

# %%
monthly_sales_analysis = (
    monthly_sales
    .groupby("year_month")
    .agg(
        orders=("order_id", "nunique"),
        items=("items", "sum"),
        revenue=("revenue", "sum"),
        freight=("freight", "sum"),
        total_value=("total_value", "sum")
    )
    .sort_index()
)

monthly_sales_analysis["avg_order_value"] = (
    monthly_sales_analysis["total_value"]
    / monthly_sales_analysis["orders"]
).round(2)

monthly_sales_analysis["revenue_percentage"] = (
    monthly_sales_analysis["revenue"]
    / monthly_sales_analysis["revenue"].sum()
    * 100
).round(2)

monthly_sales_analysis
# Out:
#             orders  items     revenue    freight  total_value  \
# year_month
# 2016-09          3      6      267.36      87.39       354.75
# 2016-10        308    363    49507.66    7301.18     56808.84
# 2016-12          1      1       10.90       8.72        19.62
# 2017-01        789    955   120312.87   16875.62    137188.49
# 2017-02       1733   1951   247303.02   38977.60    286280.62
# 2017-03       2641   3000   374344.30   57704.29    432048.59
# 2017-04       2391   2684   359927.23   52495.01    412422.24
# 2017-05       3660   4136   506071.14   80119.81    586190.95
# 2017-06       3217   3583   433038.60   69924.44    502963.04
# 2017-07       3969   4519   498031.48   86940.14    584971.62
# 2017-08       4293   4910   573971.68   94232.92    668204.60
# 2017-09       4243   4831   624401.69   95997.22    720398.91
# 2017-10       4568   5322   664219.43  105092.94    769312.37
# 2017-11       7451   8665  1010271.37  168872.40   1179143.77
# 2017-12       5624   6308   743914.17  119633.06    863547.23
# 2018-01       7220   8208   950030.36  157271.53   1107301.89
# 2018-02       6694   7672   844178.71  142730.25    986908.96
# 2018-03       7188   8217   983213.44  171913.38   1155126.82
# 2018-04       6934   7975   996647.75  163050.29   1159698.04
# 2018-05       6853   7925   996517.68  153264.14   1149781.82
# 2018-06       6160   7078   865124.31  157552.80   1022677.11
# 2018-07       6273   7092   895507.22  163220.81   1058728.03
# 2018-08       6452   7248   854686.33  148622.14   1003308.47
# 2018-09          1      1      145.00      21.46       166.46
#
#             avg_order_value  revenue_percentage
# year_month
# 2016-09              118.25                0.00
# 2016-10              184.44                0.36
# 2016-12               19.62                0.00
# 2017-01              173.88                0.89
# 2017-02              165.19                1.82
# 2017-03              163.59                2.75
# 2017-04              172.49                2.65
# 2017-05              160.16                3.72
# 2017-06              156.35                3.19
# 2017-07              147.39                3.66
# 2017-08              155.65                4.22
# 2017-09              169.79                4.59
# 2017-10              168.41                4.89
# 2017-11              158.25                7.43
# 2017-12              153.55                5.47
# 2018-01              153.37                6.99
# 2018-02              147.43                6.21
# 2018-03              160.70                7.23
# 2018-04              167.25                7.33
# 2018-05              167.78                7.33
# 2018-06              166.02                6.37
# 2018-07              168.78                6.59
# 2018-08              155.50                6.29
# 2018-09              166.46                0.00

# %%
monthly_sales_analysis.sort_values(
    "revenue",
    ascending=False
).head(10)
# Out:
#             orders  items     revenue    freight  total_value  \
# year_month
# 2017-11       7451   8665  1010271.37  168872.40   1179143.77
# 2018-04       6934   7975   996647.75  163050.29   1159698.04
# 2018-05       6853   7925   996517.68  153264.14   1149781.82
# 2018-03       7188   8217   983213.44  171913.38   1155126.82
# 2018-01       7220   8208   950030.36  157271.53   1107301.89
# 2018-07       6273   7092   895507.22  163220.81   1058728.03
# 2018-06       6160   7078   865124.31  157552.80   1022677.11
# 2018-08       6452   7248   854686.33  148622.14   1003308.47
# 2018-02       6694   7672   844178.71  142730.25    986908.96
# 2017-12       5624   6308   743914.17  119633.06    863547.23
#
#             avg_order_value  revenue_percentage
# year_month
# 2017-11              158.25                7.43
# 2018-04              167.25                7.33
# 2018-05              167.78                7.33
# 2018-03              160.70                7.23
# 2018-01              153.37                6.99
# 2018-07              168.78                6.59
# 2018-06              166.02                6.37
# 2018-08              155.50                6.29
# 2018-02              147.43                6.21
# 2017-12              153.55                5.47

# %%
monthly_sales_analysis.sort_values(
    "revenue",
    ascending=True
).head(10)
# Out:
#             orders  items    revenue   freight  total_value  avg_order_value  \
# year_month
# 2016-12          1      1      10.90      8.72        19.62            19.62
# 2018-09          1      1     145.00     21.46       166.46           166.46
# 2016-09          3      6     267.36     87.39       354.75           118.25
# 2016-10        308    363   49507.66   7301.18     56808.84           184.44
# 2017-01        789    955  120312.87  16875.62    137188.49           173.88
# 2017-02       1733   1951  247303.02  38977.60    286280.62           165.19
# 2017-04       2391   2684  359927.23  52495.01    412422.24           172.49
# 2017-03       2641   3000  374344.30  57704.29    432048.59           163.59
# 2017-06       3217   3583  433038.60  69924.44    502963.04           156.35
# 2017-07       3969   4519  498031.48  86940.14    584971.62           147.39
#
#             revenue_percentage
# year_month
# 2016-12                   0.00
# 2018-09                   0.00
# 2016-09                   0.00
# 2016-10                   0.36
# 2017-01                   0.89
# 2017-02                   1.82
# 2017-04                   2.65
# 2017-03                   2.75
# 2017-06                   3.19
# 2017-07                   3.66

# %%
yearly_sales_analysis = (
    monthly_sales
    .groupby("year")
    .agg(
        orders=("order_id", "nunique"),
        items=("items", "sum"),
        revenue=("revenue", "sum"),
        freight=("freight", "sum"),
        total_value=("total_value", "sum")
    )
)

yearly_sales_analysis["avg_order_value"] = (
    yearly_sales_analysis["total_value"]
    / yearly_sales_analysis["orders"]
).round(2)

yearly_sales_analysis
# Out:
#       orders  items     revenue     freight  total_value  avg_order_value
# year
# 2016     312    370    49785.92     7397.29     57183.21           183.28
# 2017   44579  50864  6155806.98   986865.45   7142672.43           160.23
# 2018   53775  61416  7386050.80  1257646.80   8643697.60           160.74

# %%
monthly_sales_analysis = monthly_sales_analysis.sort_index()

monthly_sales_analysis["revenue_growth_pct"] = (
    monthly_sales_analysis["revenue"]
    .pct_change()
    * 100
).round(2)

monthly_sales_analysis["order_growth_pct"] = (
    monthly_sales_analysis["orders"]
    .pct_change()
    * 100
).round(2)

monthly_sales_analysis
# Out:
#             orders  items     revenue    freight  total_value  \
# year_month
# 2016-09          3      6      267.36      87.39       354.75
# 2016-10        308    363    49507.66    7301.18     56808.84
# 2016-12          1      1       10.90       8.72        19.62
# 2017-01        789    955   120312.87   16875.62    137188.49
# 2017-02       1733   1951   247303.02   38977.60    286280.62
# 2017-03       2641   3000   374344.30   57704.29    432048.59
# 2017-04       2391   2684   359927.23   52495.01    412422.24
# 2017-05       3660   4136   506071.14   80119.81    586190.95
# 2017-06       3217   3583   433038.60   69924.44    502963.04
# 2017-07       3969   4519   498031.48   86940.14    584971.62
# 2017-08       4293   4910   573971.68   94232.92    668204.60
# 2017-09       4243   4831   624401.69   95997.22    720398.91
# 2017-10       4568   5322   664219.43  105092.94    769312.37
# 2017-11       7451   8665  1010271.37  168872.40   1179143.77
# 2017-12       5624   6308   743914.17  119633.06    863547.23
# 2018-01       7220   8208   950030.36  157271.53   1107301.89
# 2018-02       6694   7672   844178.71  142730.25    986908.96
# 2018-03       7188   8217   983213.44  171913.38   1155126.82
# 2018-04       6934   7975   996647.75  163050.29   1159698.04
# 2018-05       6853   7925   996517.68  153264.14   1149781.82
# 2018-06       6160   7078   865124.31  157552.80   1022677.11
# 2018-07       6273   7092   895507.22  163220.81   1058728.03
# 2018-08       6452   7248   854686.33  148622.14   1003308.47
# 2018-09          1      1      145.00      21.46       166.46
#
#             avg_order_value  revenue_percentage  revenue_growth_pct  \
# year_month
# 2016-09              118.25                0.00                 NaN
# 2016-10              184.44                0.36            18417.23
# 2016-12               19.62                0.00              -99.98
# 2017-01              173.88                0.89          1103687.80
# 2017-02              165.19                1.82              105.55
# 2017-03              163.59                2.75               51.37
# 2017-04              172.49                2.65               -3.85
# 2017-05              160.16                3.72               40.60
# 2017-06              156.35                3.19              -14.43
# 2017-07              147.39                3.66               15.01
# 2017-08              155.65                4.22               15.25
# 2017-09              169.79                4.59                8.79
# 2017-10              168.41                4.89                6.38
# 2017-11              158.25                7.43               52.10
# 2017-12              153.55                5.47              -26.36
# 2018-01              153.37                6.99               27.71
# 2018-02              147.43                6.21              -11.14
# 2018-03              160.70                7.23               16.47
# 2018-04              167.25                7.33                1.37
# 2018-05              167.78                7.33               -0.01
# 2018-06              166.02                6.37              -13.19
# 2018-07              168.78                6.59                3.51
# 2018-08              155.50                6.29               -4.56
# 2018-09              166.46                0.00              -99.98
#
#             order_growth_pct
# year_month
# 2016-09                  NaN
# 2016-10             10166.67
# 2016-12               -99.68
# 2017-01             78800.00
# 2017-02               119.65
# 2017-03                52.39
# 2017-04                -9.47
# 2017-05                53.07
# 2017-06               -12.10
# 2017-07                23.38
# 2017-08                 8.16
# 2017-09                -1.16
# 2017-10                 7.66
# 2017-11                63.11
# 2017-12               -24.52
# 2018-01                28.38
# 2018-02                -7.29
# 2018-03                 7.38
# 2018-04                -3.53
# 2018-05                -1.17
# 2018-06               -10.11
# 2018-07                 1.83
# 2018-08                 2.85
# 2018-09               -99.98

# %%
yearly_sales_analysis = (
    monthly_sales
    .groupby("year")
    .agg(
        orders=("order_id", "nunique"),
        items=("items", "sum"),
        revenue=("revenue", "sum"),
        freight=("freight", "sum"),
        total_value=("total_value", "sum")
    )
)

yearly_sales_analysis["avg_order_value"] = (
    yearly_sales_analysis["total_value"]
    / yearly_sales_analysis["orders"]
).round(2)

yearly_sales_analysis["revenue_growth_pct"] = (
    yearly_sales_analysis["revenue"]
    .pct_change()
    * 100
).round(2)

yearly_sales_analysis
# Out:
#       orders  items     revenue     freight  total_value  avg_order_value  \
# year
# 2016     312    370    49785.92     7397.29     57183.21           183.28
# 2017   44579  50864  6155806.98   986865.45   7142672.43           160.23
# 2018   53775  61416  7386050.80  1257646.80   8643697.60           160.74
#
#       revenue_growth_pct
# year
# 2016                 NaN
# 2017            12264.55
# 2018               19.99

# %%
best_month = monthly_sales_analysis.loc[
    monthly_sales_analysis["revenue"].idxmax()
]

worst_month = monthly_sales_analysis.loc[
    monthly_sales_analysis["revenue"].idxmin()
]

print("Best Revenue Month:")
print(best_month)

print("\nWorst Revenue Month:")
print(worst_month)
# Out:
# Best Revenue Month:
# orders                   7451.00
# items                    8665.00
# revenue               1010271.37
# freight                168872.40
# total_value           1179143.77
# avg_order_value           158.25
# revenue_percentage          7.43
# revenue_growth_pct         52.10
# order_growth_pct           63.11
# Name: 2017-11, dtype: float64
#
# Worst Revenue Month:
# orders                 1.00
# items                  1.00
# revenue               10.90
# freight                8.72
# total_value           19.62
# avg_order_value       19.62
# revenue_percentage     0.00
# revenue_growth_pct   -99.98
# order_growth_pct     -99.68
# Name: 2016-12, dtype: float64

# %%
monthly_seasonality = (
    monthly_sales
    .groupby("month")
    .agg(
        avg_revenue=("revenue", "mean"),
        avg_orders=("order_id", "nunique"),
        avg_total_value=("total_value", "mean")
    )
    .round(2)
)

monthly_seasonality
# Out:
#        avg_revenue  avg_orders  avg_total_value
# month
# 1           133.64        8009           155.39
# 2           129.52        8427           151.08
# 3           138.12        9829           161.48
# 4           145.48        9325           168.59
# 5           142.93       10513           165.13
# 6           138.44        9377           162.70
# 7           136.06       10242           160.49
# 8           132.96       10745           155.56
# 9           147.12        4247           169.75
# 10          146.38        4876           169.43
# 11          135.59        7451           158.25
# 12          132.25        5625           153.52

# %% [markdown]
# # City-Level Geographic Analysis

# %%
customer_sales.columns
# Out:
# Index(['order_id', 'customer_unique_id', 'customer_city', 'customer_state',
#        'items', 'revenue', 'freight', 'total_value'],
#       dtype='object')

# %%
city_customer_analysis = (
    customer_sales
    .groupby(["customer_state", "customer_city"])
    .agg(
        customers=("customer_unique_id", "nunique"),
        orders=("order_id", "nunique"),
        items=("items", "sum"),
        revenue=("revenue", "sum"),
        freight=("freight", "sum"),
        total_value=("total_value", "sum")
    )
    .sort_values("revenue", ascending=False)
)

city_customer_analysis["revenue_percentage"] = (
    city_customer_analysis["revenue"]
    / city_customer_analysis["revenue"].sum()
    * 100
).round(2)

city_customer_analysis["avg_order_value"] = (
    city_customer_analysis["total_value"]
    / city_customer_analysis["orders"]
).round(2)

city_customer_analysis.head(20)
# Out:
#                                       customers  orders  items     revenue  \
# customer_state customer_city
# SP             sao paulo                  14865   15402  17808  1914924.54
# RJ             rio de janeiro              6576    6834   7837   992538.86
# MG             belo horizonte              2654    2750   3144   355611.13
# DF             brasilia                    2056    2116   2392   301920.25
# PR             curitiba                    1455    1510   1751   211738.06
# RS             porto alegre                1320    1372   1612   190562.08
# SP             campinas                    1386    1429   1654   187844.53
# BA             salvador                    1202    1238   1412   181104.42
# SP             guarulhos                   1143    1178   1329   144268.39
# RJ             niteroi                      807     845    980   117907.12
# GO             goiania                      667     687    817   106111.17
# SP             sao bernardo do campo        898     928   1060   104540.99
#                santos                       686     706    820    98777.09
# CE             fortaleza                    640     650    728    97868.06
# SP             santo andre                  765     792    890    92028.60
# PE             recife                       589     612    677    89803.01
# SC             florianopolis                543     565    660    85925.99
# SP             osasco                       713     742    850    82157.86
#                jundiai                      543     560    656    81310.30
# PA             belem                        430     441    487    80078.49
#
#                                         freight  total_value  \
# customer_state customer_city
# SP             sao paulo              255302.58   2170227.12
# RJ             rio de janeiro         161695.16   1154234.02
# MG             belo horizonte          61122.26    416733.39
# DF             brasilia                50384.89    352305.14
# PR             curitiba                33001.81    244739.87
# RS             porto alegre            33502.01    224064.09
# SP             campinas                24697.17    212541.70
# BA             salvador                35667.98    216772.40
# SP             guarulhos               19307.43    163575.82
# RJ             niteroi                 20012.26    137919.38
# GO             goiania                 17949.36    124060.53
# SP             sao bernardo do campo   14483.86    119024.85
#                santos                  12893.12    111670.21
# CE             fortaleza               20778.01    118646.07
# SP             santo andre             12602.02    104630.62
# PE             recife                  20220.51    110023.52
# SC             florianopolis           13999.38     99925.37
# SP             osasco                  11842.86     94000.72
#                jundiai                 10096.47     91406.77
# PA             belem                   15543.63     95622.12
#
#                                       revenue_percentage  avg_order_value
# customer_state customer_city
# SP             sao paulo                           14.09           140.91
# RJ             rio de janeiro                       7.30           168.90
# MG             belo horizonte                       2.62           151.54
# DF             brasilia                             2.22           166.50
# PR             curitiba                             1.56           162.08
# RS             porto alegre                         1.40           163.31
# SP             campinas                             1.38           148.73
# BA             salvador                             1.33           175.10
# SP             guarulhos                            1.06           138.86
# RJ             niteroi                              0.87           163.22
# GO             goiania                              0.78           180.58
# SP             sao bernardo do campo                0.77           128.26
#                santos                               0.73           158.17
# CE             fortaleza                            0.72           182.53
# SP             santo andre                          0.68           132.11
# PE             recife                               0.66           179.78
# SC             florianopolis                        0.63           176.86
# SP             osasco                               0.60           126.69
#                jundiai                              0.60           163.23
# PA             belem                                0.59           216.83

# %%
top_cities = (
    city_customer_analysis
    .sort_values("revenue", ascending=False)
# RS             porto alegre                1320    1372   1612   190562.08
# BA             salvador                    1202    1238   1412   181104.42
# SP             guarulhos                   1143    1178   1329   144268.39
#                sao bernardo do campo        898     928   1060   104540.99
# RJ             niteroi                      807     845    980   117907.12
# SP             santo andre                  765     792    890    92028.60
#                osasco                       713     742    850    82157.86
#                santos                       686     706    820    98777.09
# GO             goiania                      667     687    817   106111.17
# SP             sao jose dos campos          661     686    781    78650.94
# CE             fortaleza                    640     650    728    97868.06
# SP             sorocaba                     602     624    703    76551.76
# PE             recife                       589     612    677    89803.01
# SC             florianopolis                543     565    660    85925.99
#
#                                         freight  total_value  \
# customer_state customer_city
# SP             sao paulo              255302.58   2170227.12
# RJ             rio de janeiro         161695.16   1154234.02
# MG             belo horizonte          61122.26    416733.39
# DF             brasilia                50384.89    352305.14
# PR             curitiba                33001.81    244739.87
# SP             campinas                24697.17    212541.70
# RS             porto alegre            33502.01    224064.09
# BA             salvador                35667.98    216772.40
# SP             guarulhos               19307.43    163575.82
#                sao bernardo do campo   14483.86    119024.85
# RJ             niteroi                 20012.26    137919.38
# SP             santo andre             12602.02    104630.62
#                osasco                  11842.86     94000.72
#                santos                  12893.12    111670.21
# GO             goiania                 17949.36    124060.53
# SP             sao jose dos campos     11336.37     89987.31
# CE             fortaleza               20778.01    118646.07
# SP             sorocaba                10597.08     87148.84
# PE             recife                  20220.51    110023.52
# SC             florianopolis           13999.38     99925.37
#
#                                       revenue_percentage  avg_order_value
# customer_state customer_city
# SP             sao paulo                           14.09           140.91
# RJ             rio de janeiro                       7.30           168.90
# MG             belo horizonte                       2.62           151.54
# DF             brasilia                             2.22           166.50
# PR             curitiba                             1.56           162.08
# SP             campinas                             1.38           148.73
# RS             porto alegre                         1.40           163.31
# BA             salvador                             1.33           175.10
# SP             guarulhos                            1.06           138.86
#                sao bernardo do campo                0.77           128.26
# RJ             niteroi                              0.87           163.22
# SP             santo andre                          0.68           132.11
#                osasco                               0.60           126.69
#                santos                               0.73           158.17
# GO             goiania                              0.78           180.58
# SP             sao jose dos campos                  0.58           131.18
# CE             fortaleza                            0.72           182.53
# SP             sorocaba                             0.56           139.66
# PE             recife                               0.66           179.78
# SC             florianopolis                        0.63           176.86

# %%
highest_aov_cities = (
    city_customer_analysis[
        city_customer_analysis["orders"] >= 10
    ]
    .sort_values("avg_order_value", ascending=False)
    .head(20)
)

highest_aov_cities
# Out:
#                                           customers  orders  items   revenue  \
# customer_state customer_city
# SC             taio                              14      15     18   5965.23
# PA             abaetetuba                        11      11     14   4028.57
# BA             cicero dantas                      9      10     23   3010.05
#                campo formoso                     10      10     11   3419.13
# MA             balsas                            16      17     20   5274.43
# SC             gaspar                            29      30     42  10643.04
# MG             andradas                          11      12     14   4070.31
# RO             ariquemes                         12      13     21   4124.97
# CE             sobral                            35      35     36  11368.84
# MT             campo novo do parecis             16      16     24   4970.79
#                nova xavantina                    10      10     11   3274.69
# BA             porto seguro                      37      40     51  12890.09
# PE             escada                            10      10     11   2658.43
# MA             bacabal                           11      11     14   3243.71
# AL             arapiraca                         28      29     34   8728.71
# PA             tucurui                           17      17     20   5096.70
# PB             campina grande                    68      68     75  17500.53
# RS             santo antonio da patrulha         17      17     18   5100.08
# MT             alta floresta                     10      12     15   3495.55
# GO             pires do rio                      11      12     17   3500.83
#
#                                           freight  total_value  \
# customer_state customer_city
# SC             taio                        510.57      6475.80
# PA             abaetetuba                  643.70      4672.27
# BA             cicero dantas              1146.33      4156.38
#                campo formoso               635.21      4054.34
# MA             balsas                     1333.31      6607.74
# SC             gaspar                      990.57     11633.61
# MG             andradas                    525.66      4595.97
# RO             ariquemes                   844.67      4969.64
# CE             sobral                     1926.89     13295.73
# MT             campo novo do parecis       944.99      5915.78
#                nova xavantina              327.47      3602.16
# BA             porto seguro               1474.33     14364.42
# PE             escada                      898.27      3556.70
# MA             bacabal                     639.79      3883.50
# AL             arapiraca                  1421.32     10150.03
# PA             tucurui                     835.05      5931.75
# PB             campina grande             5282.76     22783.29
# RS             santo antonio da patrulha   503.04      5603.12
# MT             alta floresta               455.53      3951.08
# GO             pires do rio                429.20      3930.03
#
#                                           revenue_percentage  avg_order_value
# customer_state customer_city
# SC             taio                                     0.04           431.72
# PA             abaetetuba                               0.03           424.75
# BA             cicero dantas                            0.02           415.64
#                campo formoso                            0.03           405.43
# MA             balsas                                   0.04           388.69
# SC             gaspar                                   0.08           387.79
# MG             andradas                                 0.03           383.00
# RO             ariquemes                                0.03           382.28
# CE             sobral                                   0.08           379.88
# MT             campo novo do parecis                    0.04           369.74
#                nova xavantina                           0.02           360.22
# BA             porto seguro                             0.09           359.11
# PE             escada                                   0.02           355.67
# MA             bacabal                                  0.02           353.05
# AL             arapiraca                                0.06           350.00
# PA             tucurui                                  0.04           348.93
# PB             campina grande                           0.13           335.05
# RS             santo antonio da patrulha                0.04           329.60
# MT             alta floresta                            0.03           329.26
# GO             pires do rio                             0.03           327.50

# %% [markdown]
# # Delivery / Logistics Analysis

# %%
orders.columns
# Out:
# Index(['order_id', 'customer_id', 'order_status', 'order_purchase_timestamp',
#        'order_approved_at', 'order_delivered_carrier_date',
#        'order_delivered_customer_date', 'order_estimated_delivery_date',
#        'year', 'month', 'month_name', 'year_month'],
#       dtype='object')

# %%
delivery_analysis = orders.copy()

# Convert date columns to datetime
date_columns = [
    "order_purchase_timestamp",
    "order_approved_at",
    "order_delivered_carrier_date",
    "order_delivered_customer_date",
    "order_estimated_delivery_date"
]

for col in date_columns:
    delivery_analysis[col] = pd.to_datetime(
        delivery_analysis[col],
        errors="coerce"
    )

# Actual delivery time in days
delivery_analysis["delivery_days"] = (
    delivery_analysis["order_delivered_customer_date"]
    - delivery_analysis["order_purchase_timestamp"]
).dt.total_seconds() / (24 * 60 * 60)

# Approval time in days
delivery_analysis["approval_days"] = (
    delivery_analysis["order_approved_at"]
    - delivery_analysis["order_purchase_timestamp"]
).dt.total_seconds() / (24 * 60 * 60)

# Carrier handling time in days
delivery_analysis["carrier_days"] = (
    delivery_analysis["order_delivered_carrier_date"]
    - delivery_analysis["order_approved_at"]
).dt.total_seconds() / (24 * 60 * 60)

# Estimated delivery time in days
delivery_analysis["estimated_delivery_days"] = (
    delivery_analysis["order_estimated_delivery_date"]
    - delivery_analysis["order_purchase_timestamp"]
).dt.total_seconds() / (24 * 60 * 60)

# Delivery delay
delivery_analysis["delivery_delay_days"] = (
    delivery_analysis["order_delivered_customer_date"]
    - delivery_analysis["order_estimated_delivery_date"]
).dt.total_seconds() / (24 * 60 * 60)

delivery_analysis.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp   order_approved_at  \
# 0    delivered      2017-10-02 10:56:33 2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37 2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49 2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06 2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39 2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# 1          2018-07-26 14:31:00           2018-08-07 15:27:45
# 2          2018-08-08 13:50:00           2018-08-17 18:06:29
# 3          2017-11-22 13:39:59           2017-12-02 00:28:42
# 4          2018-02-14 19:46:34           2018-02-16 18:17:02
#
#   order_estimated_delivery_date  year  month month_name year_month  \
# 0                    2017-10-18  2017     10    October    2017-10
# 1                    2018-08-13  2018      7       July    2018-07
# 2                    2018-09-04  2018      8     August    2018-08
# 3                    2017-12-15  2017     11   November    2017-11
# 4                    2018-02-26  2018      2   February    2018-02
#
#    delivery_days  approval_days  carrier_days  estimated_delivery_days  \
# 0       8.436574       0.007431      2.366493                15.544063
# 1      13.782037       1.279745      0.462882                19.137766
# 2       9.394213       0.011505      0.204595                26.639711
# 3      13.208750       0.012419      3.745833                26.188819
# 4       2.873877       0.042940      0.893113                12.112049
#
#    delivery_delay_days
# 0            -7.107488
# 1            -5.355729
# 2           -17.245498
# 3           -12.980069
# 4            -9.238171

# %%
delivery_analysis[
    [
        "order_id",
        "order_status",
        "delivery_days",
        "approval_days",
        "carrier_days",
        "estimated_delivery_days",
        "delivery_delay_days"
    ]
].head(10)
# Out:
#                            order_id order_status  delivery_days  \
# 0  e481f51cbdc54678b7cc49136f2d6af7    delivered       8.436574
# 1  53cdb2fc8bc7dce0b6741e2150273451    delivered      13.782037
# 2  47770eb9100c2d0c44946d9cf07ec65d    delivered       9.394213
# 3  949d5b44dbf5de918fe9c16f97b45f8a    delivered      13.208750
# 4  ad21c59c0840e6cb83a9ceb5573f8159    delivered       2.873877
# 5  a4591c265e18cb1dcee52889e2d8acc3    delivered      16.542245
# 6  136cce7faa42fdb2cefd53fdc79a6098     invoiced            NaN
# 7  6514b8ad8028c9f2cc2374ded245783f    delivered       9.989826
# 8  76c6e866289321a7c93b82b54852dc33    delivered       9.818762
# 9  e69bfb5eb88e0ed6a785585b27e16dbf    delivered      18.221852
#
#    approval_days  carrier_days  estimated_delivery_days  delivery_delay_days
# 0       0.007431      2.366493                15.544063            -7.107488
# 1       1.279745      0.462882                19.137766            -5.355729
# 2       0.011505      0.204595                26.639711           -17.245498
# 3       0.012419      3.745833                26.188819           -12.980069
# 4       0.042940      0.893113                12.112049            -9.238171
# 5       0.009120      1.699896                22.085359            -5.543113
# 6       2.043854           NaN                27.484630                  NaN
# 7       0.008113      5.864988                21.451042           -11.461215
# 8       1.348356      1.476204                41.229757           -31.410995
# 9       0.007292     12.319352                24.503449            -6.281597

# %%
delivery_kpis = {
    "total_orders": delivery_analysis["order_id"].nunique(),
    "delivered_orders": delivery_analysis["order_delivered_customer_date"].notna().sum(),
    "average_delivery_days": delivery_analysis["delivery_days"].mean(),
    "median_delivery_days": delivery_analysis["delivery_days"].median(),
    "average_approval_days": delivery_analysis["approval_days"].mean(),
    "average_carrier_days": delivery_analysis["carrier_days"].mean(),
    "average_estimated_delivery_days": delivery_analysis["estimated_delivery_days"].mean(),
    "average_delivery_delay_days": delivery_analysis["delivery_delay_days"].mean()
}

delivery_kpis
# Out:
# {'total_orders': 99441,
#  'delivered_orders': np.int64(96476),
#  'average_delivery_days': np.float64(12.558702304032053),
#  'median_delivery_days': np.float64(10.21775462962963),
#  'average_approval_days': np.float64(0.43412892924665386),
#  'average_carrier_days': np.float64(2.8050381811449983),
#  'average_estimated_delivery_days': np.float64(23.767649925118448),
#  'average_delivery_delay_days': np.float64(-11.179119879819465)}

# %% [markdown]
# # On-Time vs Late Delivery

# %%
# Consider only delivered orders
delivered_orders = delivery_analysis[
    delivery_analysis["order_status"] == "delivered"
].copy()

# Classify delivery performance
delivered_orders["delivery_performance"] = np.select(
    [
        delivered_orders["delivery_delay_days"] < 0,
        delivered_orders["delivery_delay_days"] == 0,
        delivered_orders["delivery_delay_days"] > 0
    ],
    [
        "Early",
        "On Time",
        "Late"
    ],
    default="Unknown"
)

# Summary
delivery_performance_summary = (
    delivered_orders
    .groupby("delivery_performance")
    .agg(
        orders=("order_id", "nunique")
    )
    .sort_values("orders", ascending=False)
)

# Percentage
delivery_performance_summary["percentage"] = (
    delivery_performance_summary["orders"]
    / delivery_performance_summary["orders"].sum()
    * 100
).round(2)

delivery_performance_summary
# Out:
#                       orders  percentage
# delivery_performance
# Early                  88644       91.88
# Late                    7826        8.11
# Unknown                    8        0.01

# %% [markdown]
# # Delay Analysis

# %%
delay_analysis = (
    delivered_orders["delivery_delay_days"]
    .agg(
        average_delay="mean",
        median_delay="median",
        minimum_delay="min",
        maximum_delay="max"
    )
    .to_frame()
)

delay_analysis.round(2)
# Out:
#                delivery_delay_days
# average_delay               -11.18
# median_delay                -11.95
# minimum_delay              -146.02
# maximum_delay               188.98

# %%
late_deliveries = delivered_orders[
    delivered_orders["delivery_delay_days"] > 0
].copy()

late_delivery_analysis = {
    "late_orders": late_deliveries["order_id"].nunique(),
    "average_late_days": late_deliveries["delivery_delay_days"].mean(),
    "median_late_days": late_deliveries["delivery_delay_days"].median(),
    "maximum_late_days": late_deliveries["delivery_delay_days"].max()
}

late_delivery_analysis
# Out:
# {'late_orders': 7826,
#  'average_late_days': np.float64(9.551775917880569),
#  'median_late_days': np.float64(5.806481481481482),
#  'maximum_late_days': np.float64(188.97508101851852)}

# %%
most_delayed_orders = (
    late_deliveries
    .sort_values("delivery_delay_days", ascending=False)
    [[
        "order_id",
        "order_status",
        "delivery_days",
        "estimated_delivery_days",
        "delivery_delay_days"
    ]]
    .head(20)
)

most_delayed_orders
# Out:
#                                order_id order_status  delivery_days  \
# 55619  1b3190b2dfa9d789e1f14c05b647a14a    delivered     208.351759
# 19590  ca07593549f1816d26a572e06dc1eab6    delivered     209.628611
# 11399  47b40429ed8cce3aee9199792275433f    delivered     191.463542
# 81401  2fe324febf907e3ea3f2aa9650869fa5    delivered     189.863160
# 89130  285ab9426d6982034523a855f55a885e    delivered     194.633611
# 61610  440d0d17af552815d15a9e41abe49359    delivered     195.634016
# 68769  c27815f7e3dd0b926b58552628481575    delivered     187.743843
# 40847  d24e8541128cea179a11a65176e0a96f    delivered     175.223819
# 38509  0f4519c5f1c541ddec9f21b3bddd533a    delivered     194.049583
# 54480  2d7561026d542c8dbd8f0daeadf67a43    delivered     188.134618
# 70307  2fb597c2f772eca01b1f5c561bf6cc7b    delivered     194.850174
# 74117  6e82dcfb5eada6283dba34f164e636f5    delivered     182.658137
# 86520  ed8e9faf1b75f43ee027103957135663    delivered     173.133380
# 31228  dfe5f68118c2576143240b8d78e5940a    delivered     186.236771
# 66407  2ba1366baecad3c3536f27546d129017    delivered     181.060521
# 62286  437222e3fd1b07396f1d9ba8c15fba59    delivered     187.203449
# 29265  6e6527028de694ccade37f5a15a6d84a    delivered     165.010023
# 83872  a452fba32eab28a4a62af18eed010c0b    delivered     167.601470
# 64489  3566eabb132f8d64741ae7b921bbd10e    delivered     174.048079
# 29519  4fbc8d6f2f4db3e789d5a876fa349b56    delivered     168.082801
#
#        estimated_delivery_days  delivery_delay_days
# 55619                19.376678           188.975081
# 19590                28.019826           181.608785
# 11399                15.594433           175.869109
# 81401                22.154745           167.708414
# 89130                28.050231           166.583380
# 61610                30.000104           165.633912
# 68769                25.025498           162.718345
# 40847                13.448484           161.775336
# 38509                32.439618           161.609965
# 54480                28.524687           159.609931
# 70307                39.243727           155.606447
# 74117                27.202060           155.456076
# 86520                19.367894           153.765486
# 31228                32.477523           153.759248
# 66407                28.377350           152.683171
# 62286                42.516667           144.686782
# 29265                22.005625           143.004398
# 83872                29.027060           138.574410
# 64489                36.418113           137.629965
# 29519                33.098194           134.984606

# %% [markdown]
# # Step 1 — Customer-level analysis

# %%
print("monthly_sales columns:")
print(monthly_sales.columns.tolist())

print("\ndelivery_analysis columns:")
print(delivery_analysis.columns.tolist())
# Out:
# monthly_sales columns:
# ['order_id', 'order_purchase_timestamp', 'year', 'month', 'month_name', 'year_month', 'items', 'revenue', 'freight', 'total_value']
#
# delivery_analysis columns:
# ['order_id', 'customer_id', 'order_status', 'order_purchase_timestamp', 'order_approved_at', 'order_delivered_carrier_date', 'order_delivered_customer_date', 'order_estimated_delivery_date', 'year', 'month', 'month_name', 'year_month', 'delivery_days', 'approval_days', 'carrier_days', 'estimated_delivery_days', 'delivery_delay_days']

# %%
# %whos DataFrame
# Out:
# Variable                       Type         Data/Info
# -----------------------------------------------------
# category_sales                 DataFrame                             <...>\n\n[73 rows x 8 columns]
# city_customer_analysis         DataFrame                             <...>\n[4300 rows x 8 columns]
# comment_availability           DataFrame                  total_revie<...>      20535         36.08
# comment_length_by_score        DataFrame                  reviews  av<...>                   3.03
# common_words                   DataFrame             word  count\n0  <...>807\n29       como   1783
# customer_order_frequency       DataFrame                             <...>n[96096 rows x 4 columns]
# customer_orders                DataFrame                             <...>[99441 rows x 11 columns]
# customer_revenue               DataFrame                             <...>n[95420 rows x 8 columns]
# customer_sales                 DataFrame                             <...>n[98666 rows x 8 columns]
# customer_type_analysis         DataFrame                   customers <...>         2997        3.12
# customer_value_analysis        DataFrame                          cus<...>.25               11.97
# customers                      DataFrame                             <...>n[99441 rows x 5 columns]
# delay_analysis                 DataFrame                   delivery_d<...>elay           188.975081
# delivered_orders               DataFrame                             <...>[96478 rows x 18 columns]
# delivery_analysis              DataFrame                             <...>[99441 rows x 17 columns]
# delivery_performance_summary   DataFrame                          ord<...>            8        0.01
# duplicate_review_ids           DataFrame                             <...>\n[1603 rows x 7 columns]
# frequent_cities                DataFrame                             <...>  0.63           176.86
# frequent_customers             DataFrame                             <...>00               50–100
# geo_outliers                   DataFrame            geolocation_zip_c<...>             santa rosa
# geolocation                    DataFrame             geolocation_zip_<...>1000163 rows x 6 columns]
# high_value_orders              DataFrame                             <...> 3.71             1000+
# highest_aov_cities             DataFrame                             <...>  0.03           327.50
# late_deliveries                DataFrame                             <...>n[7826 rows x 18 columns]
# monthly_rating                 DataFrame                  count  mean<...>2018-08        8987  4.21
# monthly_review_analysis        DataFrame       year_month  reviews  a<...>   81.09          12.21
# monthly_sales                  DataFrame                             <...>[98666 rows x 10 columns]
# monthly_sales_analysis         DataFrame                orders  items<...>09               -99.98
# monthly_seasonality            DataFrame           avg_revenue  avg_o<...>    5625           153.52
# most_delayed_orders            DataFrame                             <...>94           134.984606
# multi_item_orders              DataFrame                             <...>\n[9803 rows x 6 columns]
# order_items                    DataFrame                             <...>[112650 rows x 7 columns]
# order_items_products           DataFrame                             <...>[112650 rows x 8 columns]
# order_sales                    DataFrame                             <...>n[98666 rows x 6 columns]
# order_sales_reset              DataFrame                             <...>n[98666 rows x 7 columns]
# order_value_analysis           DataFrame                       orders<...>                   1.16
# orders                         DataFrame                             <...>[99441 rows x 12 columns]
# payments                       DataFrame                             <...>[103886 rows x 5 columns]
# product_sales                  DataFrame                             <...>n[32951 rows x 7 columns]
# products                       DataFrame                             <...>n[32951 rows x 9 columns]
# rating_delivery_matrix         DataFrame    review_score             <...>  210   217    155    268
# rating_delivery_percentage     DataFrame    review_score             <...>7.33   7.57   5.41   9.35
# review_delivery                DataFrame                             <...>n[99224 rows x 5 columns]
# review_delivery_analysis       DataFrame                          rev<...>                    NaN
# review_summary                 DataFrame                             <...> Average Rating      2.57
# reviews                        DataFrame                             <...>[99224 rows x 17 columns]
# seller_sales                   DataFrame                             <...>\n[3095 rows x 8 columns]
# sellers                        DataFrame                             <...>\n[3095 rows x 4 columns]
# state_customer_analysis        DataFrame                    customers<...>  0.06           218.80
# top_cities                     DataFrame                             <...>  0.59           216.83
# top_customers                  DataFrame                             <...>03                1000+
# top_products                   DataFrame                             <...>3af                0.28
# top_revenue_customers          DataFrame                             <...>03                1000+
# yearly_sales_analysis          DataFrame          orders  items     r<...>018               19.99

# %%
print("seller_sales columns:")
print(seller_sales.columns.tolist())

print("\nSeller sales:")
display(seller_sales.head(20))
# Out:
# seller_sales columns:
# ['orders', 'items', 'revenue', 'freight', 'avg_order_value', 'avg_item_price', 'freight_percentage', 'revenue_percentage']
#
# Seller sales:
#                                   orders  items   revenue  freight  \
# seller_id
# 0015a82c2db000af6aaaf3ae2ecb0532       3      3   2685.00    63.06
# 001cca7ae9ae17fb1caed9dfb1094831     200    239  25080.03  8854.14
# 001e6ad469a905060d959994f1b41e4f       1      1    250.00    17.94
# 002100f778ceb8431b7a1020ff7ab48f      51     55   1234.50   793.66
# 003554e2dce176b5555353e4f3555ac8       1      1    120.00    19.38
# 004c9cd9d87a3c30c522c48c4fc07416     158    170  19712.71  3551.23
# 00720abe85ba0859807595bbf045a33b      13     26   1007.50   315.98
# 00ab3eff1b5192e5f1a63bcecfee11c8       1      1     98.00    12.08
# 00d8b143d12632bad99c0ad66ad52825       1      1     86.00    51.10
# 00ee68308b45bc5e2660cd833c3f81cc     135    172  20260.00  3180.66
    seller_sales
    .reset_index()
    .merge(
        sellers,
        on="seller_id",
        how="left"
    )
)

# Check result
print("Shape:", seller_performance.shape)

seller_performance.head()
# Out:
# Shape: (3095, 12)
#                           seller_id  orders  items   revenue  freight  \
# 0  0015a82c2db000af6aaaf3ae2ecb0532       3      3   2685.00    63.06
# 1  001cca7ae9ae17fb1caed9dfb1094831     200    239  25080.03  8854.14
# 2  001e6ad469a905060d959994f1b41e4f       1      1    250.00    17.94
# 3  002100f778ceb8431b7a1020ff7ab48f      51     55   1234.50   793.66
# 4  003554e2dce176b5555353e4f3555ac8       1      1    120.00    19.38
#
#    avg_order_value  avg_item_price  freight_percentage  revenue_percentage  \
# 0           895.00          895.00                2.35                0.02
# 1           125.40          104.94               35.30                0.18
# 2           250.00          250.00                7.18                0.00
# 3            24.21           22.45               64.29                0.01
# 4           120.00          120.00               16.15                0.00
#
#    seller_zip_code_prefix  seller_city seller_state
# 0                    9080  santo andre           SP
# 1                   29156    cariacica           ES
# 2                   24754  sao goncalo           RJ
# 3                   14405       franca           SP
# 4                   74565      goiania           GO

# %%
seller_performance[
    ["seller_city", "seller_state"]
].isnull().sum()
# Out:
# seller_city     0
# seller_state    0
# dtype: int64

# %%
seller_state_analysis = (
    seller_performance
    .groupby("seller_state")
    .agg(
        sellers=("seller_id", "nunique"),
        orders=("orders", "sum"),
        items=("items", "sum"),
        revenue=("revenue", "sum"),
        freight=("freight", "sum"),
        avg_order_value=("avg_order_value", "mean")
    )
    .sort_values("revenue", ascending=False)
)

seller_state_analysis["freight_percentage"] = (
    seller_state_analysis["freight"]
    / seller_state_analysis["revenue"]
    * 100
).round(2)

seller_state_analysis.round(2)
# Out:
#               sellers  orders  items     revenue     freight  avg_order_value  \
# seller_state
# SP               1849   70950  80342  8753396.21  1482487.67           180.88
# PR                349    7717   8671  1261887.21   197013.52           211.89
# MG                244    7942   8827  1011564.74   212595.06           179.37
# RJ                171    4355   4818   843984.22    93829.90           216.32
# SC                190    3672   4075   632426.07   106547.06           216.75
# RS                129    1991   2199   378559.54    57243.09           232.27
# BA                 19     569    643   285561.56    19700.68           379.47
# DF                 30     824    899    97749.48    18494.06           158.27
# PE                  9     406    448    91493.85    12392.46           557.99
# GO                 40     463    520    66399.21    12565.50           292.10
# ES                 23     318    372    47689.61    12171.13           207.05
# MA                  1     392    405    36408.95    12141.29            92.88
# CE                 13      91     94    20240.64     4359.83           162.77
# PB                  6      36     38    17095.00     1489.15           372.32
# MT                  4     137    145    17070.72     4631.73           131.29
# RN                  5      51     56     9992.60     1304.11           162.06
# MS                  5      49     50     8551.69     1198.96           163.15
# RO                  2      14     14     4762.20      712.78           372.22
# PI                  1      12     12     2522.00      443.32           210.17
# SE                  2       9     10     1606.20      318.49           188.04
# PA                  1       8      8     1238.00      155.11           154.75
# AM                  1       3      3     1177.00       81.80           392.33
# AC                  1       1      1      267.00       32.84           267.00
#
#               freight_percentage
# seller_state
# SP                         16.94
# PR                         15.61
# MG                         21.02
# RJ                         11.12
# SC                         16.85
# RS                         15.12
# BA                          6.90
# DF                         18.92
# PE                         13.54
# GO                         18.92
# ES                         25.52
# MA                         33.35
# CE                         21.54
# PB                          8.71
# MT                         27.13
# RN                         13.05
# MS                         14.02
# RO                         14.97
# PI                         17.58
# SE                         19.83
# PA                         12.53
# AM                          6.95
# AC                         12.30

# %%
seller_city_analysis = (
    seller_performance
    .groupby(["seller_state", "seller_city"])
    .agg(
        sellers=("seller_id", "nunique"),
        orders=("orders", "sum"),
        items=("items", "sum"),
        revenue=("revenue", "sum"),
        freight=("freight", "sum")
    )
    .sort_values("revenue", ascending=False)
)

seller_city_analysis.head(20)
# Out:
#                                     sellers  orders  items     revenue  \
# seller_state seller_city
# SP           sao paulo                  694   24666  27983  2702878.14
#              ibitinga                    49    6716   7750   624592.94
# PR           curitiba                   124    2657   2944   467821.52
# RJ           rio de janeiro              93    2189   2436   358126.92
# SP           guarulhos                   50    2073   2362   329494.38
#              ribeirao preto              52    2019   2269   275976.44
#              itaquaquecetuba              9    1243   1653   230568.12
#              guariba                      1    1132   1156   229472.63
#              santo andre                 45    2711   2964   228561.60
# BA           lauro de freitas             2     359    411   225525.05
# SP           piracicaba                  12    1626   1903   212677.82
# PR           maringa                     40    1879   2220   207257.51
# SP           barueri                     13     462    474   196053.17
#              sao jose do rio preto       33    1974   2579   195863.38
#              sumare                       5     607    608   195825.21
# MG           belo horizonte              66    2294   2457   193243.58
# SP           sao bernardo do campo       32    1015   1125   179363.91
#              campinas                    41    1294   1430   179285.45
# RJ           teresopolis                  2     223    233   130342.09
# SP           salto                        9    1225   1346   126274.45
#
#                                       freight
# seller_state seller_city
# SP           sao paulo              478867.99
#              ibitinga               137681.07
# PR           curitiba                69815.32
# RJ           rio de janeiro          46088.43
# SP           guarulhos               47287.87
#              ribeirao preto          38705.73
#              itaquaquecetuba         60377.11
#              guariba                 20168.07
#              santo andre             46249.18
# BA           lauro de freitas        13150.37
# SP           piracicaba              31496.57
# PR           maringa                 38652.24
# SP           barueri                  8348.28
#              sao jose do rio preto   50807.22
#              sumare                  10366.91
# MG           belo horizonte          44289.58
# SP           sao bernardo do campo   20978.55
#              campinas                22297.90
# RJ           teresopolis              6761.32
# SP           salto                   24492.34

# %%
high_performing_sellers = seller_performance[
    (seller_performance["orders"] >= 100) &
    (seller_performance["revenue"] >= seller_performance["revenue"].quantile(0.75))
].sort_values(
    "revenue",
    ascending=False
)

high_performing_sellers[
    [
        "seller_id",
        "seller_city",
        "seller_state",
        "orders",
        "items",
        "revenue",
        "freight",
        "avg_order_value",
        "freight_percentage"
    ]
].head(20)
# Out:
#                              seller_id            seller_city seller_state  \
# 857   4869f7a5dfa277a7dca6462dcf3b52b2                guariba           SP
# 1013  53243585a1d6dc2643021fd1853d8905       lauro de freitas           BA
# 881   4a3ca9315b744ce9f8e9374361493884               ibitinga           SP
# 3024  fa1c13f2614d7b5c4749cbc52fecda94                 sumare           SP
# 1535  7c67e1448b00f6e969d365cea6b010ab        itaquaquecetuba           SP
# 1560  7e93a43ef30c4f03f38b393420bc753a                barueri           SP
# 2643  da8622b14eb17ae2831f4ac5b9dab84a             piracicaba           SP
# 1505  7a67c85e85bb2ce8582c35f2203ad736              sao paulo           SP
# 192   1025f0e2d44d7041d6cf58b6550e0bfa              sao paulo           SP
# 1824  955fee9216a65b617aa5c0531780ce60              sao paulo           SP
# 843   46dc3b2cc0980fb8ec44634e21d2718e         rio de janeiro           RJ
# 1235  6560211a19b47992c3666cc44a7e94c0              sao paulo           SP
# 1198  620c87c171fb2a6dd6e8bb4dec959fc6             petropolis           RJ
# 1540  7d13fca15225358621be4086e1eb0964         ribeirao preto           SP
# 1153  5dceca129747e92ff8ef7a997dc4f8ca  santa barbara d´oeste           SP
# 368   1f50f920176fa81dab994f9023523100  sao jose do rio preto           SP
# 2481  cc419e0650a3c5ba77189a1882b7556a            santo andre           SP
# 1954  a1043bafd471dff536d0c462352beb48               ilicinea           MG
# 731   3d871de0142ce09b7081e2b9d1733cb1   campo limpo paulista           SP
# 2871  edb1ef5e36e0c8cd84eb3c9b003e486d            teresopolis           RJ
#
#       orders  items    revenue   freight  avg_order_value  freight_percentage
# 857     1132   1156  229472.63  20168.07           202.71                8.79
# 1013     358    410  222776.05  13080.63           622.28                5.87
# 881     1806   1987  200472.92  35067.04           111.00               17.49
# 3024     585    586  194042.03  10042.70           331.70                5.18
# 1535     982   1364  187923.89  51612.55           191.37               27.46
# 1560     336    340  176431.87   6322.18           525.09                3.58
# 2643    1314   1551  160236.57  24955.75           121.95               15.57
# 1505    1160   1171  141745.53  20902.85           122.19               14.75
# 192      915   1428  138968.55  33892.14           151.88               24.39
# 1824    1287   1499  135171.70  25430.98           105.03               18.81
# 843      521    542  128111.19  11798.50           245.89                9.21
# 1235    1854   2033  123304.83  27960.94            66.51               22.68
# 1198     740    798  114774.50  14135.21           155.10               12.32
# 1540     565    578  113628.97   8632.05           201.11                7.60
# 1153     325    346  112155.53  13661.39           345.09               12.18
# 368     1404   1931  106939.21  35165.77            76.17               32.88
# 2481    1706   1775  104288.42  25668.99            61.13               24.61
# 1954     718    770  101901.16  31844.09           141.92               31.25
# 731     1080   1147   94914.20  22433.51            87.88               23.64
# 2871     166    175   79284.55   3905.10           477.62                4.93

# %%
# ============================================
# 10.1 CREATE CLEANING COPIES
# ============================================

orders_clean = orders.copy()
order_items_clean = order_items.copy()
payments_clean = payments.copy()
reviews_clean = reviews.copy()
products_clean = products.copy()
sellers_clean = sellers.copy()
customers_clean = customers.copy()
geolocation_clean = geolocation.copy()

print("Cleaning copies created successfully.")
# Out:
# Cleaning copies created successfully.

# %%
# ============================================
# 10.2 INITIAL DATA QUALITY CHECK
# ============================================

clean_datasets = {
    "orders": orders_clean,
    "order_items": order_items_clean,
    "payments": payments_clean,
    "reviews": reviews_clean,
    "products": products_clean,
    "sellers": sellers_clean,
    "customers": customers_clean,
    "geolocation": geolocation_clean
}

quality_report = []

for name, df in clean_datasets.items():

    quality_report.append({
        "dataset": name,
        "rows": df.shape[0],
        "columns": df.shape[1],
        "duplicate_rows": df.duplicated().sum(),
        "missing_values": df.isna().sum().sum(),
        "memory_mb": round(df.memory_usage(deep=True).sum() / 1024**2, 2)
    })

quality_report = pd.DataFrame(quality_report)

quality_report
# Out:
#        dataset     rows  columns  duplicate_rows  missing_values  memory_mb
# 0       orders    99441       12               0            4908      59.99
# 1  order_items   112650        7               0               0      39.43
# 2     payments   103886        5               0               0      17.81
# 3      reviews    99224       17               0          145903      40.38
# 4     products    32951        9               0            2448       6.79
# 5      sellers     3095        4               0               0       0.66
# 6    customers    99441        5               0               0      29.62
# 7  geolocation  1000163        6          261831               0     210.44

# %%
# ============================================
# 10.3 DATA TYPE CHECK
# ============================================

for name, df in clean_datasets.items():

    print("=" * 70)
    print(name.upper())
    print(df.dtypes)
    print()
# Out:
# ======================================================================
# ORDERS
# order_id                                 object
# customer_id                              object
# order_status                             object
# order_purchase_timestamp         datetime64[ns]
# order_approved_at                        object
# order_delivered_carrier_date             object
# order_delivered_customer_date            object
# order_estimated_delivery_date            object
# year                                      int32
# month                                     int32
# month_name                               object
# year_month                            period[M]
# dtype: object
#
# ======================================================================
# ORDER_ITEMS
# order_id                object
# order_item_id            int64
# product_id              object
# seller_id               object
# shipping_limit_date     object
# price                  float64
# freight_value          float64
# dtype: object
#
# ======================================================================
# PAYMENTS
# order_id                 object
# payment_sequential        int64
# payment_type             object
# payment_installments      int64
# payment_value           float64
# dtype: object
#
# ======================================================================
# REVIEWS
# review_id                           object
# order_id                            object
# review_score                         int64
# review_comment_title                object
# review_comment_message              object
# review_creation_date        datetime64[ns]
# review_answer_timestamp     datetime64[ns]
# review_response_time       timedelta64[ns]
# response_time_hours                float64
# response_time_group               category
# review_year                          int32
# review_month                     period[M]
# review_category                   category
# comment_length                       int64
# year_month                          object
# comment_word_count                   int64
# has_comment                           bool
# dtype: object
#
# ======================================================================
# PRODUCTS
# product_id                     object
# product_category_name          object
# product_name_lenght           float64
# product_description_lenght    float64
# product_photos_qty            float64
# product_weight_g              float64
# product_length_cm             float64
# product_height_cm             float64
# product_width_cm              float64
# dtype: object
#
# ======================================================================
# SELLERS
# seller_id                 object
# seller_zip_code_prefix     int64
# seller_city               object
# seller_state              object
# dtype: object
#
# ======================================================================
# CUSTOMERS
# customer_id                 object
# customer_unique_id          object
# customer_zip_code_prefix     int64
# customer_city               object
# customer_state              object
# dtype: object
#
# ======================================================================
# GEOLOCATION
# geolocation_zip_code_prefix      int64
# geolocation_lat                float64
# geolocation_lng                float64
# geolocation_city                object
# geolocation_state               object
# city_normalized                 object
# dtype: object

# %%
# ============================================
# 10.4 PRIMARY KEY DUPLICATE CHECK
# ============================================

key_checks = {
    "orders": ["order_id"],
    "customers": ["customer_id"],
    "sellers": ["seller_id"],
    "products": ["product_id"],
    "reviews": ["review_id"],
}

for dataset, keys in key_checks.items():

    df = clean_datasets[dataset]

    print("=" * 70)
    print(dataset.upper())

    for key in keys:
        print(
            f"{key}:",
            df[key].duplicated().sum(),
            "duplicates"
        )
# Out:
# ======================================================================
# ORDERS
# order_id: 0 duplicates
# ======================================================================
# CUSTOMERS
# customer_id: 0 duplicates
# ======================================================================
# SELLERS
# seller_id: 0 duplicates
# ======================================================================
# PRODUCTS
# product_id: 0 duplicates
# ======================================================================
# REVIEWS
# review_id: 814 duplicates

# %%
# ============================================
# 10.5 MISSING VALUE ANALYSIS
# ============================================

missing_report = []

for name, df in clean_datasets.items():

    for column in df.columns:

        missing_count = df[column].isna().sum()

        if missing_count > 0:

            missing_report.append({
                "dataset": name,
                "column": column,
                "missing_count": missing_count,
                "missing_percentage": round(
                    missing_count / len(df) * 100,
                    2
                )
            })

missing_report = (
    pd.DataFrame(missing_report)
    .sort_values(
        ["dataset", "missing_percentage"],
        ascending=[True, False]
    )
)

missing_report
# Out:
#      dataset                         column  missing_count  missing_percentage
# 2     orders  order_delivered_customer_date           2965                2.98
# 1     orders   order_delivered_carrier_date           1783                1.79
# 0     orders              order_approved_at            160                0.16
# 5   products          product_category_name            610                1.85
# 6   products            product_name_lenght            610                1.85
# 7   products     product_description_lenght            610                1.85
# 8   products             product_photos_qty            610                1.85
# 9   products               product_weight_g              2                0.01
# 10  products              product_length_cm              2                0.01
# 11  products              product_height_cm              2                0.01
# 12  products               product_width_cm              2                0.01
# 3    reviews           review_comment_title          87656               88.34
# 4    reviews         review_comment_message          58247               58.70

# %%
# ============================================
# 10.6 REVIEW ID DUPLICATE INVESTIGATION
# ============================================

duplicate_review_ids = (
    reviews_clean[
        reviews_clean["review_id"].duplicated(keep=False)
    ]
    .sort_values("review_id")
)

print("Duplicate review ID rows:", len(duplicate_review_ids))
print(
    "Unique duplicated review IDs:",
    duplicate_review_ids["review_id"].nunique()
)

display(duplicate_review_ids.head(20))
# Out:
# Duplicate review ID rows: 1603
# Unique duplicated review IDs: 789
#                               review_id                          order_id  \
# 46678  00130cbe1f9d422698c812ed8ded1919  dfcdfc43867d1c1381bfaf62d6b9c195
# 29841  00130cbe1f9d422698c812ed8ded1919  04a28263e085d399c97ae49e0b477efa
# 90677  0115633a9c298b6a98bcbe4eee75345f  78a4201f58af3463bdab842eea4bc801
# 63193  0115633a9c298b6a98bcbe4eee75345f  0c9850b2c179c1ef60d2855e2751d1fa
# 92876  0174caf0ee5964646040cd94e15ac95e  f93a732712407c02dce5dd5088d0f47b
# 57280  0174caf0ee5964646040cd94e15ac95e  74db91e33b4e1fd865356c89a61abf1f
# 54832  017808d29fd1f942d97e50184dfb4c13  8daaa9e99d60fbba579cc1c3e3bfae01
# 99167  017808d29fd1f942d97e50184dfb4c13  b1461c8882153b5fe68307c46a506e39
# 20621  0254bd905dc677a6078990aad3331a36  5bf226cf882c5bf4247f89a97c86f273
# 96080  0254bd905dc677a6078990aad3331a36  331b367bdd766f3d1cf518777317b5d9
# 89712  0288d42bef3dfe36930740c9588a570f  33d8795f04dd631f3480d7aaf90da3dc
# 94851  0288d42bef3dfe36930740c9588a570f  f889a5a0b44adc29c5465b99395ac3c1
# 47495  02aa7f5f75e964e3c7efa59a1f515281  d8e17d5f7dacf0970d316e7c03e741e8
# 95860  02aa7f5f75e964e3c7efa59a1f515281  db92613c074f00e53066388d48ad7512
# 71165  034528cb00b6bc981847acafbdf2ae0b  e1e8e3bca903de27e9a1c72b5a5795e0
# 81094  034528cb00b6bc981847acafbdf2ae0b  3d3742a96f24a8fe4e2e57628807e476
# 1988   03a6a25db577d0689440933055111897  2acfdc5131ff2cf4433e668454c9784c
# 9013   03a6a25db577d0689440933055111897  3fde8b7313af6b37b84b5c7594d7add0
# 21587  0467560f511c516ddaa54a60edb0c291  0c995611a99f81268d859184a416f1db
# 24901  0467560f511c516ddaa54a60edb0c291  55b2e390d5d80ada31ad1b795ebeb087
#
#        review_score review_comment_title  \
# 46678             1                  NaN
# 29841             1                  NaN
# 90677             5                  NaN
# 63193             5                  NaN
# 92876             1                  NaN
# 57280             1                  NaN
# 54832             5                  NaN
# 99167             5                  NaN
# 20621             1                  NaN
# 96080             1                  NaN
# 89712             3                  NaN
# 94851             3                  NaN
# 47495             3                  NaN
# 95860             3                  NaN
# 71165             1                  NaN
# 81094             1                  NaN
# 1988              5                  NaN
# 9013              5                  NaN
# 21587             5                  NaN
# 24901             5                  NaN
#
#                                   review_comment_message review_creation_date  \
#
#        comment_length year_month  comment_word_count  has_comment
# 46678             186    2018-03                  30         True
# 29841             186    2018-03                  30         True
# 90677               0    2017-09                   0        False
# 63193               0    2017-09                   0        False
# 92876              90    2018-03                  14         True
# 57280              90    2018-03                  14         True
# 54832               0    2018-03                   0        False
# 99167               0    2018-03                   0        False
# 20621             151    2017-09                  27         True
# 96080             151    2017-09                  27         True
# 89712               0    2017-07                   0        False
# 94851               0    2017-07                   0        False
# 47495               0    2017-07                   0        False
# 95860               0    2017-07                   0        False
# 71165               0    2017-05                   0        False
# 81094               0    2017-05                   0        False
# 1988               93    2017-12                  13         True
# 9013               93    2017-12                  13         True
# 21587               0    2017-02                   0        False
# 24901               0    2017-02                   0        False

# %%
# Check whether duplicate review_id rows are exact duplicates

exact_duplicate_reviews = (
    duplicate_review_ids
    .duplicated()
    .sum()
)

print(
    "Exact duplicate rows among duplicated review IDs:",
    exact_duplicate_reviews
)
# Out:
# Exact duplicate rows among duplicated review IDs: 0

# %%
# Compare duplicated review IDs across important columns

review_id_duplicate_summary = (
    duplicate_review_ids
    .groupby("review_id")
    .agg(
        row_count=("review_id", "size"),
        unique_order_ids=("order_id", "nunique"),
        unique_scores=("review_score", "nunique"),
        unique_titles=("review_comment_title", "nunique"),
        unique_comments=("review_comment_message", "nunique")
    )
    .sort_values("row_count", ascending=False)
)

display(review_id_duplicate_summary.head(20))
# Out:
#                                   row_count  unique_order_ids  unique_scores  \
# review_id
# 4219a80ab469e3fc9901437b73da3f75          3                 3              1
# 7b606b0d57b078384f0b58eac1d41d78          3                 3              1
# 0c76e7a547a531e7bf9f0b99cba071c1          3                 3              1
# 69a1068c3128a14994e3e422e4539e04          3                 3              1
# 308316408775d1600dad81bd3184556d          3                 3              1
# 44e9f871226d8a130de3fc39dfbdf0c5          3                 3              1
# 2172867fd5b1a55f98fe4608e1547b4b          3                 3              1
# 9e25d6e3025e9b9a0fc7f03588d33e2b          3                 3              1
# 38821b5c496b678cf91acc34892805ad          3                 3              1
# 70509c441d994fa03d6c1457930c9024          3                 3              1
# 32415bbf6e341d5d517080a796f79b5c          3                 3              1
# 3415c9f764e478409e8e0660ae816dd2          3                 3              1
# 4d0e6dd087008d1f992d25ef6e1f619f          3                 3              1
# 4548534449b1f572e357211b90724f1b          3                 3              1
# 2d6ac45f859465b5c185274a1c929637          3                 3              1
# 39b4603793c1c7f5f36d809b4a218664          3                 3              1
# 1fb4ddc969e6bea80e38deec00393a6f          3                 3              1
# 08528f70f579f0c830189efc523d2182          3                 3              1
# 832acec9bbf4efe65c3fb6423d8b4ed7          3                 3              1
# abbfacb2964f74f6487c9c10ac46daa6          3                 3              1
#
#                                   unique_titles  unique_comments
# review_id
# 4219a80ab469e3fc9901437b73da3f75              0                1
# 7b606b0d57b078384f0b58eac1d41d78              0                0
# 0c76e7a547a531e7bf9f0b99cba071c1              0                0
# 69a1068c3128a14994e3e422e4539e04              0                0
# 308316408775d1600dad81bd3184556d              0                1
# 44e9f871226d8a130de3fc39dfbdf0c5              0                0
# 2172867fd5b1a55f98fe4608e1547b4b              0                1
# 9e25d6e3025e9b9a0fc7f03588d33e2b              1                1
# 38821b5c496b678cf91acc34892805ad              0                0
# 70509c441d994fa03d6c1457930c9024              0                0
# 32415bbf6e341d5d517080a796f79b5c              1                1
# 3415c9f764e478409e8e0660ae816dd2              0                0
# 4d0e6dd087008d1f992d25ef6e1f619f              0                0
# 4548534449b1f572e357211b90724f1b              0                1
# 2d6ac45f859465b5c185274a1c929637              0                1
# 39b4603793c1c7f5f36d809b4a218664              0                1
# 1fb4ddc969e6bea80e38deec00393a6f              0                0
# 08528f70f579f0c830189efc523d2182              1                1
# 832acec9bbf4efe65c3fb6423d8b4ed7              0                0
# abbfacb2964f74f6487c9c10ac46daa6              0                0

# %%
# ============================================
# 10.7 ORDERS MISSING DATE ANALYSIS
# ============================================

order_missing_analysis = (
    orders_clean
    .assign(
        missing_approved=lambda x:
            x["order_approved_at"].isna(),

        missing_carrier=lambda x:
            x["order_delivered_carrier_date"].isna(),

        missing_customer_delivery=lambda x:
            x["order_delivered_customer_date"].isna()
    )
    .groupby("order_status")
    .agg(
        total_orders=("order_id", "count"),
        missing_approved=("missing_approved", "sum"),
        missing_carrier=("missing_carrier", "sum"),
        missing_customer_delivery=(
            "missing_customer_delivery",
            "sum"
        )
    )
)

order_missing_analysis
# Out:
#               total_orders  missing_approved  missing_carrier  \
# order_status
# approved                 2                 0                2
# canceled               625               141              550
# created                  5                 5                5
# delivered            96478                14                2
# invoiced               314                 0              314
# processing             301                 0              301
# shipped               1107                 0                0
# unavailable            609                 0              609
#
#               missing_customer_delivery
# order_status
# approved                              2
# canceled                            619
# created                               5
# delivered                             8
# invoiced                            314
# processing                          301
# shipped                            1107
# unavailable                         609

# %%
# ============================================
# 10.8 PRODUCTS MISSING VALUE ANALYSIS
# ============================================

product_missing_analysis = (
    products_clean[
        products_clean["product_category_name"].isna()
        |
        products_clean["product_name_lenght"].isna()
        |
        products_clean["product_description_lenght"].isna()
        |
        products_clean["product_photos_qty"].isna()
    ]
)

print(
    "Products with missing category/basic attributes:",
    len(product_missing_analysis)
)

display(product_missing_analysis.head(20))
# Out:
# Products with missing category/basic attributes: 610
#                            product_id product_category_name  \
# 105  a41e356c76fab66334f36de622ecbd3a                   NaN
# 128  d8dee61c2034d6d075997acef1870e9b                   NaN
# 145  56139431d72cd51f19eb9f7dae4d1617                   NaN
# 154  46b48281eb6d663ced748f324108c733                   NaN
# 197  5fb61f482620cb672f5e586bb132eae9                   NaN
# 244  e10758160da97891c2fdcbc35f0f031d                   NaN
# 294  39e3b9b12cd0bf8ee681bbc1c130feb5                   NaN
# 299  794de06c32a626a5692ff50e4985d36f                   NaN
# 347  7af3e2da474486a3519b0cba9dea8ad9                   NaN
# 428  629beb8e7317703dcc5f35b5463fd20e                   NaN
# 436  3a78f64aac654298e4b9aff32fc21818                   NaN
# 459  bcb815bba008d89458e428078c0b9211                   NaN
# 504  6b82874c6b51b92913dcdb364eaaae0f                   NaN
# 514  c68b419d9c6038271b85bac98adb0fc9                   NaN
# 552  1dcd65bb5dd967d7b4c6b0223cefb838                   NaN
# 616  671446e8e3aa3df1eca47b6c354a2921                   NaN
# 627  f0ea71b6e2ab4cb3bd8f5ba522a25a56                   NaN
# 628  fedccbd5e370e8ddb7aae6fb4cb70347                   NaN
# 696  212cc0fa7359ab242a697a03a574f719                   NaN
# 700  6b7879a37ac2dbe5289a16706e859870                   NaN
#
#      product_name_lenght  product_description_lenght  product_photos_qty  \
# 105                  NaN                         NaN                 NaN
# 128                  NaN                         NaN                 NaN
# 145                  NaN                         NaN                 NaN
# 154                  NaN                         NaN                 NaN
# 197                  NaN                         NaN                 NaN
# 244                  NaN                         NaN                 NaN
# 294                  NaN                         NaN                 NaN
# 299                  NaN                         NaN                 NaN
# 347                  NaN                         NaN                 NaN
# 428                  NaN                         NaN                 NaN
# 436                  NaN                         NaN                 NaN
# 459                  NaN                         NaN                 NaN
# 504                  NaN                         NaN                 NaN
# 514                  NaN                         NaN                 NaN
# 552                  NaN                         NaN                 NaN
# 616                  NaN                         NaN                 NaN
# 627                  NaN                         NaN                 NaN
# 628                  NaN                         NaN                 NaN
# 696                  NaN                         NaN                 NaN
# 700                  NaN                         NaN                 NaN
#
#      product_weight_g  product_length_cm  product_height_cm  product_width_cm
# 105             650.0               17.0               14.0              12.0
# 128             300.0               16.0                7.0              20.0
# 145             200.0               20.0               20.0              20.0
# 154           18500.0               41.0               30.0              41.0
# 197             300.0               35.0                7.0              12.0
# 244            2200.0               16.0                2.0              11.0
# 294             300.0               16.0                7.0              11.0
# 299             300.0               18.0                8.0              14.0
# 347             200.0               22.0               14.0              14.0
# 428            1400.0               25.0               25.0              25.0
# 436            4300.0               30.0               10.0              48.0
# 459             150.0               16.0                2.0              11.0
# 504           21450.0               70.0               34.0              50.0
# 514            1000.0               16.0               14.0              30.0
# 552            9150.0               33.0               30.0              44.0
# 616            5500.0               33.0               22.0              33.0
# 627            1300.0               30.0               20.0              30.0
# 628            1200.0               20.0               20.0              20.0
# 696             200.0               16.0                2.0              11.0
# 700             950.0               45.0               12.0              30.0

# %%
# ============================================
# CHECK WHETHER MISSING PRODUCTS WERE SOLD
# ============================================

missing_product_ids = set(
    product_missing_analysis["product_id"]
)

sold_missing_products = order_items_clean[
    order_items_clean["product_id"].isin(
        missing_product_ids
    )
]

print(
    "Missing-attribute products appearing in order items:",
    sold_missing_products["product_id"].nunique()
)

print(
    "Number of order-item records:",
    len(sold_missing_products)
)
# Out:
# Missing-attribute products appearing in order items: 610
# Number of order-item records: 1603

# %%
# ============================================
# 10.9 REVIEW COMMENT FLAGS
# ============================================

reviews_clean["has_comment"] = (
    reviews_clean["review_comment_message"]
    .notna()
    &
    reviews_clean["review_comment_message"]
    .str.strip()
    .ne("")
)

reviews_clean["has_title"] = (
    reviews_clean["review_comment_title"]
    .notna()
    &
    reviews_clean["review_comment_title"]
    .str.strip()
    .ne("")
)

print(
    "Reviews with comments:",
    reviews_clean["has_comment"].sum()
)

print(
    "Reviews with titles:",
    reviews_clean["has_title"].sum()
)
# Out:
# Reviews with comments: 40950
# Reviews with titles: 11566

# %%
# ============================================
# 10.10 REVIEW DUPLICATE INVESTIGATION
# ============================================

review_duplicate_rows = reviews_clean[
    reviews_clean["review_id"].duplicated(keep=False)
].sort_values("review_id")

print(
    "Rows involved in duplicate review_ids:",
    len(review_duplicate_rows)
)

print(
    "Unique duplicated review_ids:",
    review_duplicate_rows["review_id"].nunique()
)

display(
    review_duplicate_rows[
        [
            "review_id",
            "order_id",
            "review_score",
            "review_comment_title",
            "review_comment_message",
            "review_creation_date",
            "review_answer_timestamp"
        ]
    ].head(30)
)
# Out:
# Rows involved in duplicate review_ids: 1603
# Unique duplicated review_ids: 789
#                               review_id                          order_id  \
# 46678  00130cbe1f9d422698c812ed8ded1919  dfcdfc43867d1c1381bfaf62d6b9c195
# 29841  00130cbe1f9d422698c812ed8ded1919  04a28263e085d399c97ae49e0b477efa
# 90677  0115633a9c298b6a98bcbe4eee75345f  78a4201f58af3463bdab842eea4bc801
# 63193  0115633a9c298b6a98bcbe4eee75345f  0c9850b2c179c1ef60d2855e2751d1fa
# 92876  0174caf0ee5964646040cd94e15ac95e  f93a732712407c02dce5dd5088d0f47b
# 57280  0174caf0ee5964646040cd94e15ac95e  74db91e33b4e1fd865356c89a61abf1f
# 54832  017808d29fd1f942d97e50184dfb4c13  8daaa9e99d60fbba579cc1c3e3bfae01
# 99167  017808d29fd1f942d97e50184dfb4c13  b1461c8882153b5fe68307c46a506e39
# 20621  0254bd905dc677a6078990aad3331a36  5bf226cf882c5bf4247f89a97c86f273
# 96080  0254bd905dc677a6078990aad3331a36  331b367bdd766f3d1cf518777317b5d9
# 89712  0288d42bef3dfe36930740c9588a570f  33d8795f04dd631f3480d7aaf90da3dc
# 94851  0288d42bef3dfe36930740c9588a570f  f889a5a0b44adc29c5465b99395ac3c1
# 47495  02aa7f5f75e964e3c7efa59a1f515281  d8e17d5f7dacf0970d316e7c03e741e8
# 95860  02aa7f5f75e964e3c7efa59a1f515281  db92613c074f00e53066388d48ad7512
# 71165  034528cb00b6bc981847acafbdf2ae0b  e1e8e3bca903de27e9a1c72b5a5795e0
# 81094  034528cb00b6bc981847acafbdf2ae0b  3d3742a96f24a8fe4e2e57628807e476
# 1988   03a6a25db577d0689440933055111897  2acfdc5131ff2cf4433e668454c9784c
# 9013   03a6a25db577d0689440933055111897  3fde8b7313af6b37b84b5c7594d7add0
# 21587  0467560f511c516ddaa54a60edb0c291  0c995611a99f81268d859184a416f1db
# 24901  0467560f511c516ddaa54a60edb0c291  55b2e390d5d80ada31ad1b795ebeb087
# 52021  047fd109ced39e02296f6aeb74f6a6f1  236e6ec6171c1870d4bcf4ccfad87f49
# 13872  047fd109ced39e02296f6aeb74f6a6f1  a89abace0dcc01eeb267a9660b5ac126
# 96681  0498e9722f8757426c3c3ee0b91e666d  f318811b0fd898d1edf78d6841470be2
# 77444  0498e9722f8757426c3c3ee0b91e666d  041aa5c38550649d5b51f38ba03a29a4
# 7629   0501aab2f381486c36bf0f071442c0c2  0068c109948b9a1dfb8530d1978acef3
# 66952  0501aab2f381486c36bf0f071442c0c2  d75cb3755738c4ae466303358f97bc55
# 58621  0546d398a833d4c33dec480bedeecfbd  e72a8568c8622825a95439791f668e85
# 92842  0546d398a833d4c33dec480bedeecfbd  879d57dc015759bf30e71a20b5ae0652
# 50517  0655af56f10bc3ef8e3810610828f294  d9e44c3fd2ce16086619f299e92e12d8
exact_review_duplicates = reviews_clean.duplicated().sum()

print(
    "Exact duplicate review rows:",
    exact_review_duplicates
)
# Out:
# Exact duplicate review rows: 0

# %%
# ============================================
# 10.10.2 DUPLICATE REVIEW ID STRUCTURE
# ============================================

duplicate_review_analysis = (
    review_duplicate_rows
    .groupby("review_id")
    .agg(
        rows=("review_id", "size"),
        unique_orders=("order_id", "nunique"),
        unique_scores=("review_score", "nunique")
    )
    .sort_values("rows", ascending=False)
)

display(
    duplicate_review_analysis.head(20)
)
# Out:
#                                   rows  unique_orders  unique_scores
# review_id
# 4219a80ab469e3fc9901437b73da3f75     3              3              1
# 7b606b0d57b078384f0b58eac1d41d78     3              3              1
# 0c76e7a547a531e7bf9f0b99cba071c1     3              3              1
# 69a1068c3128a14994e3e422e4539e04     3              3              1
# 308316408775d1600dad81bd3184556d     3              3              1
# 44e9f871226d8a130de3fc39dfbdf0c5     3              3              1
# 2172867fd5b1a55f98fe4608e1547b4b     3              3              1
# 9e25d6e3025e9b9a0fc7f03588d33e2b     3              3              1
# 38821b5c496b678cf91acc34892805ad     3              3              1
# 70509c441d994fa03d6c1457930c9024     3              3              1
# 32415bbf6e341d5d517080a796f79b5c     3              3              1
# 3415c9f764e478409e8e0660ae816dd2     3              3              1
# 4d0e6dd087008d1f992d25ef6e1f619f     3              3              1
# 4548534449b1f572e357211b90724f1b     3              3              1
# 2d6ac45f859465b5c185274a1c929637     3              3              1
# 39b4603793c1c7f5f36d809b4a218664     3              3              1
# 1fb4ddc969e6bea80e38deec00393a6f     3              3              1
# 08528f70f579f0c830189efc523d2182     3              3              1
# 832acec9bbf4efe65c3fb6423d8b4ed7     3              3              1
# abbfacb2964f74f6487c9c10ac46daa6     3              3              1

# %%
# ============================================
# 10.11 DUPLICATE REVIEW ID INVESTIGATION
# ============================================

# Count rows per review_id
review_id_counts = (
    reviews_clean
    .groupby("review_id")
    .size()
    .sort_values(ascending=False)
)

print("Total review rows:", len(reviews_clean))
print("Unique review IDs:", reviews_clean["review_id"].nunique())
print("Duplicated review IDs:", (review_id_counts > 1).sum())
print("Rows belonging to duplicated IDs:", review_id_counts[review_id_counts > 1].sum())

# Check whether duplicated review IDs represent
# different orders
duplicate_review_structure = (
    reviews_clean[
        reviews_clean["review_id"].isin(
            review_id_counts[review_id_counts > 1].index
        )
    ]
    .groupby("review_id")
    .agg(
        rows=("review_id", "size"),
        unique_orders=("order_id", "nunique"),
        unique_scores=("review_score", "nunique"),
        unique_comments=("review_comment_message", "nunique"),
        unique_creation_dates=("review_creation_date", "nunique")
    )
)

display(
    duplicate_review_structure
    .sort_values(
        ["unique_orders", "rows"],
        ascending=False
    )
    .head(20)
)
# Out:
# Total review rows: 99224
# Unique review IDs: 98410
# Duplicated review IDs: 789
# Rows belonging to duplicated IDs: 1603
#                                   rows  unique_orders  unique_scores  \
# review_id
# 08528f70f579f0c830189efc523d2182     3              3              1
# 0c76e7a547a531e7bf9f0b99cba071c1     3              3              1
# 1fb4ddc969e6bea80e38deec00393a6f     3              3              1
# 2172867fd5b1a55f98fe4608e1547b4b     3              3              1
# 2d6ac45f859465b5c185274a1c929637     3              3              1
# 308316408775d1600dad81bd3184556d     3              3              1
# 32415bbf6e341d5d517080a796f79b5c     3              3              1
# 3415c9f764e478409e8e0660ae816dd2     3              3              1
# 38821b5c496b678cf91acc34892805ad     3              3              1
# 39b4603793c1c7f5f36d809b4a218664     3              3              1
# 4219a80ab469e3fc9901437b73da3f75     3              3              1
# 44e9f871226d8a130de3fc39dfbdf0c5     3              3              1
# 4548534449b1f572e357211b90724f1b     3              3              1
# 4d0e6dd087008d1f992d25ef6e1f619f     3              3              1
# 69a1068c3128a14994e3e422e4539e04     3              3              1
# 70509c441d994fa03d6c1457930c9024     3              3              1
# 7b606b0d57b078384f0b58eac1d41d78     3              3              1
# 832acec9bbf4efe65c3fb6423d8b4ed7     3              3              1
# 9e25d6e3025e9b9a0fc7f03588d33e2b     3              3              1
# abbfacb2964f74f6487c9c10ac46daa6     3              3              1
#
#                                   unique_comments  unique_creation_dates
# review_id
# 08528f70f579f0c830189efc523d2182                1                      1
# 0c76e7a547a531e7bf9f0b99cba071c1                0                      1
# 1fb4ddc969e6bea80e38deec00393a6f                0                      1
# 2172867fd5b1a55f98fe4608e1547b4b                1                      1
# 2d6ac45f859465b5c185274a1c929637                1                      1
# 308316408775d1600dad81bd3184556d                1                      1
# 32415bbf6e341d5d517080a796f79b5c                1                      1
# 3415c9f764e478409e8e0660ae816dd2                0                      1
# 38821b5c496b678cf91acc34892805ad                0                      1
# 39b4603793c1c7f5f36d809b4a218664                1                      1
# 4219a80ab469e3fc9901437b73da3f75                1                      1
# 44e9f871226d8a130de3fc39dfbdf0c5                0                      1
# 4548534449b1f572e357211b90724f1b                1                      1
# 4d0e6dd087008d1f992d25ef6e1f619f                0                      1
# 69a1068c3128a14994e3e422e4539e04                0                      1
# 70509c441d994fa03d6c1457930c9024                0                      1
# 7b606b0d57b078384f0b58eac1d41d78                0                      1
# 832acec9bbf4efe65c3fb6423d8b4ed7                0                      1
# 9e25d6e3025e9b9a0fc7f03588d33e2b                1                      1
# abbfacb2964f74f6487c9c10ac46daa6                0                      1

# %%
# ============================================
# 10.11.1 CLASSIFY DUPLICATE REVIEW IDs
# ============================================

duplicate_structure_summary = pd.Series({
    "Same ID + Same Order":
        (
            (duplicate_review_structure["unique_orders"] == 1)
            & (duplicate_review_structure["rows"] > 1)
        ).sum(),

    "Same ID + Different Orders":
        (
            duplicate_review_structure["unique_orders"] > 1
        ).sum(),

    "Same ID + Different Scores":
        (
            duplicate_review_structure["unique_scores"] > 1
        ).sum(),

    "Same ID + Different Comments":
        (
            duplicate_review_structure["unique_comments"] > 1
        ).sum()
})

display(duplicate_structure_summary)
# Out:
# Same ID + Same Order              0
# Same ID + Different Orders      789
# Same ID + Different Scores        0
# Same ID + Different Comments      0
# dtype: int64

# %%
# ============================================
# 10.12 DUPLICATE REVIEW IDs WITH DIFFERENT ORDERS
# ============================================

review_id_different_orders = (
    duplicate_review_structure[
        duplicate_review_structure["unique_orders"] > 1
    ]
)

print(
    "Review IDs reused across different orders:",
    len(review_id_different_orders)
)

display(
    reviews_clean[
        reviews_clean["review_id"].isin(
            review_id_different_orders.index
        )
    ]
    .sort_values("review_id")
    .head(30)
)
# Out:
# Review IDs reused across different orders: 789
#                               review_id                          order_id  \
# 46678  00130cbe1f9d422698c812ed8ded1919  dfcdfc43867d1c1381bfaf62d6b9c195
#
# 13872               0    2018-07                   0        False      False
# 96681              77    2018-03                  12         True      False
# 77444              77    2018-03                  12         True      False
# 7629              200    2018-02                  34         True      False
# 66952             200    2018-02                  34         True      False
# 58621               0    2017-10                   0        False      False
# 92842               0    2017-10                   0        False      False
# 50517              23    2017-05                   4         True      False
# 23987              23    2017-05                   4         True      False

# %%
# ============================================
# 10.13 DATA QUALITY DECISION SUMMARY
# ============================================

data_quality_summary = pd.DataFrame({
    "dataset": [
        "orders",
        "customers",
        "sellers",
        "products",
        "reviews"
    ],
    "issue": [
        "Missing delivery/approval dates",
        "No primary-key duplicates",
        "No primary-key duplicates",
        "610 products with missing category/basic attributes",
        "789 review IDs reused across different orders"
    ],
    "impact": [
        "Low to moderate",
        "None",
        "None",
        "1603 sold order-item records affected",
        "1603 review rows affected"
    ],
    "recommended_action": [
        "Keep as NULL; treat as business/process information",
        "No action required",
        "No action required",
        "Keep products; use 'Unknown' category where required",
        "Do NOT drop by review_id; retain records and document key-quality issue"
    ]
})

display(data_quality_summary)
# Out:
#      dataset                                              issue  \
# 0     orders                    Missing delivery/approval dates
# 1  customers                          No primary-key duplicates
# 2    sellers                          No primary-key duplicates
# 3   products  610 products with missing category/basic attri...
# 4    reviews      789 review IDs reused across different orders
#
#                                   impact  \
# 0                        Low to moderate
# 1                                   None
# 2                                   None
# 3  1603 sold order-item records affected
# 4              1603 review rows affected
#
#                                   recommended_action
# 0  Keep as NULL; treat as business/process inform...
# 1                                 No action required
# 2                                 No action required
# 3  Keep products; use 'Unknown' category where re...
# 4  Do NOT drop by review_id; retain records and d...

# %%
# ============================================
# 10.14 FINAL CLEANING
# ============================================

# Product category
products_clean["product_category_name"] = (
    products_clean["product_category_name"]
    .fillna("Unknown")
)

# Keep review records because duplicated review_ids
# correspond to different orders
reviews_clean = reviews_clean.copy()

# Convert important order date columns
order_date_columns = [
    "order_purchase_timestamp",
    "order_approved_at",
    "order_delivered_carrier_date",
    "order_delivered_customer_date",
    "order_estimated_delivery_date"
]

for col in order_date_columns:
    orders_clean[col] = pd.to_datetime(
        orders_clean[col],
        errors="coerce"
    )

# Convert shipping date
order_items_clean["shipping_limit_date"] = pd.to_datetime(
    order_items_clean["shipping_limit_date"],
    errors="coerce"
)

print("Final cleaning completed.")
# Out:
# Final cleaning completed.

# %%
# ============================================
# 10.15 FINAL DATA QUALITY VALIDATION
# ============================================

print("=" * 70)
print("FINAL DATA QUALITY VALIDATION")
print("=" * 70)

# --------------------------------------------
# 1. PRIMARY KEY VALIDATION
# --------------------------------------------

print("\n1. PRIMARY KEY VALIDATION")

final_key_checks = {
    "orders": ["order_id"],
    "customers": ["customer_id"],
    "sellers": ["seller_id"],
    "products": ["product_id"],
    "reviews": ["review_id"]
}

for dataset, keys in final_key_checks.items():
    df = clean_datasets[dataset]

    print(f"\n{dataset.upper()}")

    for key in keys:
        duplicates = df[key].duplicated().sum()

        print(
            f"{key}: {duplicates} duplicated rows"
        )


# --------------------------------------------
# 2. MISSING VALUE VALIDATION
# --------------------------------------------

print("\n" + "=" * 70)
print("2. MISSING VALUE VALIDATION")
print("=" * 70)

final_missing_report = []

for name, df in clean_datasets.items():

    for column in df.columns:

        missing_count = df[column].isna().sum()

        if missing_count > 0:

            final_missing_report.append({
                "dataset": name,
                "column": column,
                "missing_count": missing_count,
                "missing_percentage": round(
                    missing_count / len(df) * 100,
                    2
                )
            })

final_missing_report = pd.DataFrame(
    final_missing_report
)

display(final_missing_report)


# --------------------------------------------
# 3. DATE TYPE VALIDATION
# --------------------------------------------

print("\n" + "=" * 70)
print("3. DATE TYPE VALIDATION")
print("=" * 70)

print("\nORDERS DATE TYPES")

for col in order_date_columns:
    print(
        f"{col}:",
        orders_clean[col].dtype
    )

print(
    "\nshipping_limit_date:",
    order_items_clean["shipping_limit_date"].dtype
)


# --------------------------------------------
# 4. PRODUCT CATEGORY VALIDATION
# --------------------------------------------

print("\n" + "=" * 70)
print("4. PRODUCT CATEGORY VALIDATION")
print("=" * 70)

print(
    "Missing product categories:",
    products_clean["product_category_name"].isna().sum()
)

print(
    "Unknown product categories:",
    (products_clean["product_category_name"] == "Unknown").sum()
)


# --------------------------------------------
# 5. REVIEW DUPLICATE VALIDATION
# --------------------------------------------

print("\n" + "=" * 70)
print("5. REVIEW DUPLICATE VALIDATION")
print("=" * 70)

review_duplicate_count = (
    reviews_clean["review_id"]
    .duplicated()
    .sum()
)

print(
    "Duplicated review_id rows retained:",
    review_duplicate_count
)

print(
    "Exact duplicate review rows:",
    reviews_clean.duplicated().sum()
)


# --------------------------------------------
# 6. FINAL ROW COUNTS
# --------------------------------------------

print("\n" + "=" * 70)
print("6. FINAL DATASET ROW COUNTS")
print("=" * 70)

for name, df in clean_datasets.items():

    print(
        f"{name.upper():15} : {len(df):,} rows"
    )


# --------------------------------------------
# 7. FINAL VALIDATION STATUS
# --------------------------------------------

print("\n" + "=" * 70)
print("FINAL VALIDATION STATUS")
print("=" * 70)

print("Data quality validation completed successfully.")
# Out:
# ======================================================================
# FINAL DATA QUALITY VALIDATION
# ======================================================================
#
# 1. PRIMARY KEY VALIDATION
#
# ORDERS
# order_id: 0 duplicated rows
#
# CUSTOMERS
# customer_id: 0 duplicated rows
#
# SELLERS
# seller_id: 0 duplicated rows
#
# PRODUCTS
# product_id: 0 duplicated rows
#
# REVIEWS
# review_id: 814 duplicated rows
#
# ======================================================================
# 2. MISSING VALUE VALIDATION
# ======================================================================
#      dataset                         column  missing_count  missing_percentage
# 0     orders              order_approved_at            160                0.16
# 1     orders   order_delivered_carrier_date           1783                1.79
# 2     orders  order_delivered_customer_date           2965                2.98
# 3    reviews           review_comment_title          87656               88.34
# 4    reviews         review_comment_message          58247               58.70
# 5   products            product_name_lenght            610                1.85
# 6   products     product_description_lenght            610                1.85
# 7   products             product_photos_qty            610                1.85
# 8   products               product_weight_g              2                0.01
# 9   products              product_length_cm              2                0.01
# 10  products              product_height_cm              2                0.01
# 11  products               product_width_cm              2                0.01
# ======================================================================
# 3. DATE TYPE VALIDATION
# ======================================================================
#
# ORDERS DATE TYPES
# order_purchase_timestamp: datetime64[ns]
# order_approved_at: datetime64[ns]
# order_delivered_carrier_date: datetime64[ns]
# order_delivered_customer_date: datetime64[ns]
# order_estimated_delivery_date: datetime64[ns]
#
# shipping_limit_date: datetime64[ns]
#
# ======================================================================
# 4. PRODUCT CATEGORY VALIDATION
# ======================================================================
# Missing product categories: 0
# Unknown product categories: 610
#
# ======================================================================
# 5. REVIEW DUPLICATE VALIDATION
# ======================================================================
# Duplicated review_id rows retained: 814
# Exact duplicate review rows: 0
#
# ======================================================================
# 6. FINAL DATASET ROW COUNTS
# ======================================================================
# ORDERS          : 99,441 rows
# ORDER_ITEMS     : 112,650 rows
# PAYMENTS        : 103,886 rows
# REVIEWS         : 99,224 rows
# PRODUCTS        : 32,951 rows
# SELLERS         : 3,095 rows
# CUSTOMERS       : 99,441 rows
# GEOLOCATION     : 1,000,163 rows
#
# ======================================================================
# FINAL VALIDATION STATUS
# ======================================================================
# Data quality validation completed successfully.

# %%
# ============================================
# SECTION 11 — DATA INTEGRATION
# 11.1 RELATIONSHIP KEY VALIDATION
# ============================================

print("=" * 70)
print("SECTION 11 — DATA INTEGRATION")
print("11.1 RELATIONSHIP KEY VALIDATION")
print("=" * 70)


# ============================================
# ORDERS → ORDER ITEMS
# ============================================

order_item_orders = (
    order_items_clean["order_id"]
    .isin(orders_clean["order_id"])
)

print("\nORDERS → ORDER_ITEMS")

print(
    "Order-item rows with valid order_id:",
    order_item_orders.sum()
)

print(
    "Order-item rows with missing order_id:",
    (~order_item_orders).sum()
)


# ============================================
# ORDERS → PAYMENTS
# ============================================

payment_orders = (
    payments_clean["order_id"]
    .isin(orders_clean["order_id"])
)

print("\nORDERS → PAYMENTS")

print(
    "Payment rows with valid order_id:",
    payment_orders.sum()
)

print(
    "Payment rows with missing order_id:",
    (~payment_orders).sum()
)


# ============================================
# ORDERS → REVIEWS
# ============================================

review_orders = (
    reviews_clean["order_id"]
    .isin(orders_clean["order_id"])
)

print("\nORDERS → REVIEWS")

print(
    "Review rows with valid order_id:",
    review_orders.sum()
)

print(
    "Review rows with missing order_id:",
    (~review_orders).sum()
)


# ============================================
# ORDER ITEMS → PRODUCTS
# ============================================

item_products = (
    order_items_clean["product_id"]
    .isin(products_clean["product_id"])
)

print("\nORDER_ITEMS → PRODUCTS")

print(
    "Order-item rows with valid product_id:",
    item_products.sum()
)

print(
    "Order-item rows with missing product_id:",
    (~item_products).sum()
)


# ============================================
# ORDER ITEMS → SELLERS
# ============================================

item_sellers = (
    order_items_clean["seller_id"]
    .isin(sellers_clean["seller_id"])
)

print("\nORDER_ITEMS → SELLERS")

print(
    "Order-item rows with valid seller_id:",
    item_sellers.sum()
)

print(
    "Order-item rows with missing seller_id:",
    (~item_sellers).sum()
)


# ============================================
# ORDERS → CUSTOMERS
# ============================================

order_customers = (
    orders_clean["customer_id"]
    .isin(customers_clean["customer_id"])
)

print("\nORDERS → CUSTOMERS")

print(
    "Orders with valid customer_id:",
    order_customers.sum()
)

print(
    "Orders with missing customer_id:",
    (~order_customers).sum()
)


print("\n" + "=" * 70)
print("RELATIONSHIP VALIDATION COMPLETED")
print("=" * 70)
# Out:
# ======================================================================
# SECTION 11 — DATA INTEGRATION
# 11.1 RELATIONSHIP KEY VALIDATION
# ======================================================================
#
# ORDERS → ORDER_ITEMS
# Order-item rows with valid order_id: 112650
# Order-item rows with missing order_id: 0
#
# ORDERS → PAYMENTS
# Payment rows with valid order_id: 103886
# Payment rows with missing order_id: 0
#
# ORDERS → REVIEWS
# Review rows with valid order_id: 99224
# Review rows with missing order_id: 0
#
# ORDER_ITEMS → PRODUCTS
# Order-item rows with valid product_id: 112650
# Order-item rows with missing product_id: 0
#
# ORDER_ITEMS → SELLERS
# Order-item rows with valid seller_id: 112650
# Order-item rows with missing seller_id: 0
#
# ORDERS → CUSTOMERS
# Orders with valid customer_id: 99441
# Orders with missing customer_id: 0
#
# ======================================================================
# RELATIONSHIP VALIDATION COMPLETED
# ======================================================================

# %%
# ============================================
# 11.2 RELATIONSHIP CARDINALITY ANALYSIS
# ============================================

print("=" * 70)
print("11.2 RELATIONSHIP CARDINALITY ANALYSIS")
print("=" * 70)


# ============================================
# ORDERS → ORDER ITEMS
# ============================================

items_per_order = (
    order_items_clean
    .groupby("order_id")
    .size()
)

print("\nORDERS → ORDER_ITEMS")

print("Orders with order items:", items_per_order.shape[0])
print("Maximum items in one order:", items_per_order.max())
print("Average items per order:", round(items_per_order.mean(), 2))

print(
    "Orders with multiple items:",
    (items_per_order > 1).sum()
)


# ============================================
# ORDERS → PAYMENTS
# ============================================

payments_per_order = (
    payments_clean
    .groupby("order_id")
    .size()
)

print("\nORDERS → PAYMENTS")

print("Orders with payments:", payments_per_order.shape[0])
print("Maximum payments in one order:", payments_per_order.max())
print("Average payments per order:", round(payments_per_order.mean(), 2))

print(
    "Orders with multiple payments:",
    (payments_per_order > 1).sum()
)


# ============================================
# ORDERS → REVIEWS
# ============================================

reviews_per_order = (
    reviews_clean
    .groupby("order_id")
    .size()
)

print("\nORDERS → REVIEWS")

print("Orders with reviews:", reviews_per_order.shape[0])
print("Maximum reviews for one order:", reviews_per_order.max())
print("Average reviews per order:", round(reviews_per_order.mean(), 2))

print(
    "Orders with multiple review rows:",
    (reviews_per_order > 1).sum()
)


# ============================================
# ORDERS → CUSTOMERS
# ============================================

orders_per_customer = (
    orders_clean
    .groupby("customer_id")
    .size()
)

print("\nORDERS → CUSTOMERS")

print("Customers with orders:", orders_per_customer.shape[0])
print("Maximum orders per customer:", orders_per_customer.max())
print("Average orders per customer:", round(orders_per_customer.mean(), 2))

print(
    "Customers with multiple orders:",
    (orders_per_customer > 1).sum()
)


# ============================================
# PRODUCTS → ORDER ITEMS
# ============================================

items_per_product = (
    order_items_clean
    .groupby("product_id")
    .size()
)

print("\nPRODUCTS → ORDER_ITEMS")

print("Products sold:", items_per_product.shape[0])
print("Maximum sales records for one product:", items_per_product.max())
print("Average sales records per product:", round(items_per_product.mean(), 2))


# ============================================
# SELLERS → ORDER ITEMS
# ============================================

items_per_seller = (
    order_items_clean
    .groupby("seller_id")
    .size()
)

print("\nSELLERS → ORDER_ITEMS")

print("Sellers with sales:", items_per_seller.shape[0])
print("Maximum order-item records for one seller:", items_per_seller.max())
print("Average order-item records per seller:", round(items_per_seller.mean(), 2))


print("\n" + "=" * 70)
print("CARDINALITY ANALYSIS COMPLETED")
print("=" * 70)
# Out:
# ======================================================================
# 11.2 RELATIONSHIP CARDINALITY ANALYSIS
# ======================================================================
#
# ORDERS → ORDER_ITEMS
# Orders with order items: 98666
# Maximum items in one order: 21
# Average items per order: 1.14
# Orders with multiple items: 9803
#
# ORDERS → PAYMENTS
# Orders with payments: 99440
# Maximum payments in one order: 29
# Average payments per order: 1.04
# Orders with multiple payments: 2961
#
# ORDERS → REVIEWS
# Orders with reviews: 98673
# Maximum reviews for one order: 3
# Average reviews per order: 1.01
# Orders with multiple review rows: 547
#
# ORDERS → CUSTOMERS
# Customers with orders: 99441
# Maximum orders per customer: 1
# Average orders per customer: 1.0
# Customers with multiple orders: 0
#
# PRODUCTS → ORDER_ITEMS
# Products sold: 32951
# Maximum sales records for one product: 527
# Average sales records per product: 3.42
#
# SELLERS → ORDER_ITEMS
# Sellers with sales: 3095
# Maximum order-item records for one seller: 2033
# Average order-item records per seller: 36.4
#
# ======================================================================
# CARDINALITY ANALYSIS COMPLETED
# ======================================================================

# %%
# ============================================
# 11.3 CUSTOMER IDENTITY VALIDATION
# ============================================

print("=" * 70)
print("11.3 CUSTOMER IDENTITY VALIDATION")
print("=" * 70)


# ============================================
# CUSTOMER_ID → CUSTOMER_UNIQUE_ID
# ============================================

customer_mapping = (
    customers_clean
    .groupby("customer_unique_id")
    .agg(
        customer_ids=("customer_id", "nunique"),
        total_orders=("customer_id", "size")
    )
    .sort_values("total_orders", ascending=False)
)

print("\nCUSTOMER UNIQUE ID ANALYSIS")

print(
    "Total customer_id records:",
    customers_clean["customer_id"].nunique()
)

print(
    "Unique customer_unique_id:",
    customers_clean["customer_unique_id"].nunique()
)

print(
    "Customers with multiple customer_id records:",
    (customer_mapping["customer_ids"] > 1).sum()
)

print(
    "Maximum customer_id records for one customer_unique_id:",
    customer_mapping["customer_ids"].max()
)

print(
    "Average customer_id records per customer_unique_id:",
    round(customer_mapping["customer_ids"].mean(), 2)
)


# ============================================
# REPEAT CUSTOMER ANALYSIS
# ============================================

repeat_customers = customer_mapping[
    customer_mapping["total_orders"] > 1
]

print("\nREPEAT CUSTOMER ANALYSIS")

print(
    "Customers with multiple orders:",
    len(repeat_customers)
)

print(
    "Maximum orders by one customer:",
    repeat_customers["total_orders"].max()
)


# ============================================
# TOP REPEAT CUSTOMERS
# ============================================

print("\nTOP 20 CUSTOMERS BY ORDER COUNT")

display(
    repeat_customers
    .head(20)
)


# ============================================
# CUSTOMER IDENTITY MAPPING
# ============================================

customer_identity = (
    customers_clean[
        [
            "customer_id",
            "customer_unique_id"
        ]
    ]
    .drop_duplicates()
)

print("\nCUSTOMER IDENTITY MAPPING")

print(
    "Unique customer_id → customer_unique_id mappings:",
    len(customer_identity)
)

print(
    "Duplicate customer_id mappings:",
    customer_identity["customer_id"].duplicated().sum()
)


print("\n" + "=" * 70)
print("CUSTOMER IDENTITY VALIDATION COMPLETED")
print("=" * 70)
# Out:
# ======================================================================
# 11.3 CUSTOMER IDENTITY VALIDATION
# ======================================================================
#
# CUSTOMER UNIQUE ID ANALYSIS
# Total customer_id records: 99441
# Unique customer_unique_id: 96096
# Customers with multiple customer_id records: 2997
# Maximum customer_id records for one customer_unique_id: 17
# Average customer_id records per customer_unique_id: 1.03
#
# REPEAT CUSTOMER ANALYSIS
# Customers with multiple orders: 2997
# Maximum orders by one customer: 17
#
# TOP 20 CUSTOMERS BY ORDER COUNT
#                                   customer_ids  total_orders
# customer_unique_id
# 8d50f5eadf50201ccdcedfb9e2ac8455            17            17
# 3e43e6105506432c953e165fb2acf44c             9             9
# 1b6c7548a2a1f9037c1fd3ddfed95f33             7             7
# 6469f99c1f9dfae7733b25662e7f1782             7             7
# ca77025e7201e3b30c44b472ff346268             7             7
# 47c1a3033b8b77b3ab6e109eb4d5fdf3             6             6
# 12f5d6e1cbf93dafd9dcc19095df0b3d             6             6
# 63cfc61cee11cbe306bff5857d00bfe4             6             6
# dc813062e0fc23409cd255f7f53c7074             6             6
# de34b16117594161a6a89c50b289d35a             6             6
# f0e310a6839dce9de1638e0fe5ab282a             6             6
# 35ecdf6858edc6427223b64804cf028e             5             5
# 394ac4de8f3acb14253c177f0e15bc58             5             5
# 56c8638e7c058b98aae6d74d2dd6ea23             5             5
# 74cb1ad7e6d5674325c1f99b5ea30d82             5             5
# fe81bb32c243a86b2f86fbf053fe6140             5             5
# 5e8f38a9a1c023f3db718edcf926a2db             5             5
# 4e65032f1f574189fb793bac5a867bbc             5             5
# b4e4f24de1e8725b74e4a1f4975116ed             5             5
# 083ca1aa470c280236380973a48f77c6             4             4
# CUSTOMER IDENTITY MAPPING
# Unique customer_id → customer_unique_id mappings: 99441
# Duplicate customer_id mappings: 0
#
# ======================================================================
# CUSTOMER IDENTITY VALIDATION COMPLETED
# ======================================================================

# %%
# ============================================
# 11.4 FACT & DIMENSION TABLE DESIGN
# ============================================

print("=" * 70)
print("SECTION 11.4 — FACT & DIMENSION TABLE DESIGN")
print("=" * 70)


# ============================================
# FACT TABLE GRAIN ANALYSIS
# ============================================

print("\n1. FACT TABLE CANDIDATE: ORDER ITEMS")

print(
    "Rows:",
    len(order_items_clean)
)

print(
    "Unique orders:",
    order_items_clean["order_id"].nunique()
)

print(
    "Unique products:",
    order_items_clean["product_id"].nunique()
)

print(
    "Unique sellers:",
    order_items_clean["seller_id"].nunique()
)

print(
    "Average items per order:",
    round(
        len(order_items_clean)
        / order_items_clean["order_id"].nunique(),
        2
    )
)


# ============================================
# PAYMENT FACT
# ============================================

print("\n2. FACT TABLE CANDIDATE: PAYMENTS")

print(
    "Rows:",
    len(payments_clean)
)

print(
    "Unique orders:",
    payments_clean["order_id"].nunique()
)

print(
    "Payment rows per order:",
    round(
        len(payments_clean)
        / payments_clean["order_id"].nunique(),
        2
    )
)


# ============================================
# REVIEW FACT
# ============================================

print("\n3. FACT TABLE CANDIDATE: REVIEWS")

print(
    "Rows:",
    len(reviews_clean)
)

print(
    "Unique orders:",
    reviews_clean["order_id"].nunique()
)

print(
    "Unique review IDs:",
    reviews_clean["review_id"].nunique()
)

print(
    "Review rows per order:",
    round(
        len(reviews_clean)
        / reviews_clean["order_id"].nunique(),
        2
    )
)


# ============================================
# DIMENSION TABLES
# ============================================

print("\n4. DIMENSION TABLE CANDIDATES")

dimension_summary = pd.DataFrame({
    "dimension": [
        "Customers",
        "Products",
        "Sellers",
        "Orders"
    ],
    "rows": [
        len(customers_clean),
        len(products_clean),
        len(sellers_clean),
        len(orders_clean)
    ],
    "unique_key": [
        customers_clean["customer_unique_id"].nunique(),
        products_clean["product_id"].nunique(),
        sellers_clean["seller_id"].nunique(),
        orders_clean["order_id"].nunique()
    ]
})

display(dimension_summary)


# ============================================
# RECOMMENDED MODEL STRUCTURE
# ============================================

print("\n5. RECOMMENDED POWER BI MODEL")

print("""
FACT TABLES
-----------
Fact_Order_Items
Fact_Payments
Fact_Reviews


DIMENSION TABLES
----------------
Dim_Customer
Dim_Product
Dim_Seller
Dim_Order
Dim_Date


IMPORTANT
---------
customer_unique_id should be used for customer-level analysis.
customer_id should remain available for order-level mapping.
""")


print("=" * 70)
print("FACT & DIMENSION TABLE DESIGN COMPLETED")
print("=" * 70)
# Out:
# ======================================================================
# SECTION 11.4 — FACT & DIMENSION TABLE DESIGN
# ======================================================================
#
# 1. FACT TABLE CANDIDATE: ORDER ITEMS
# Rows: 112650
# Unique orders: 98666
# Unique products: 32951
# Unique sellers: 3095
# Average items per order: 1.14
#
# 2. FACT TABLE CANDIDATE: PAYMENTS
# Rows: 103886
# Unique orders: 99440
# Payment rows per order: 1.04
#
# 3. FACT TABLE CANDIDATE: REVIEWS
# Rows: 99224
# Unique orders: 98673
# Unique review IDs: 98410
# Review rows per order: 1.01
#
# 4. DIMENSION TABLE CANDIDATES
#    dimension   rows  unique_key
# 0  Customers  99441       96096
# 1   Products  32951       32951
# 2    Sellers   3095        3095
# 3     Orders  99441       99441
# 5. RECOMMENDED POWER BI MODEL
#
# FACT TABLES
# -----------
# Fact_Order_Items
# Fact_Payments
# Fact_Reviews
#
#
# DIMENSION TABLES
# ----------------
# Dim_Customer
# Dim_Product
# Dim_Seller
# Dim_Order
# Dim_Date
#
#
# IMPORTANT
# ---------
# customer_unique_id should be used for customer-level analysis.
# customer_id should remain available for order-level mapping.
#
# ======================================================================
# FACT & DIMENSION TABLE DESIGN COMPLETED
# ======================================================================

# %%
# ============================================
# 11.5 INTEGRATED MODEL TABLE CONSTRUCTION
# ============================================

print("=" * 70)
print("SECTION 11.5 — INTEGRATED MODEL TABLE CONSTRUCTION")
print("=" * 70)


# ============================================
# DIM CUSTOMER
# ============================================

dim_customer = (
    customers_clean[
        [
            "customer_unique_id",
            "customer_city",
            "customer_state"
        ]
    ]
    .drop_duplicates("customer_unique_id")
    .reset_index(drop=True)
)

print("\nDIM_CUSTOMER")
print("Rows:", len(dim_customer))
print(
    "Unique customers:",
    dim_customer["customer_unique_id"].nunique()
)


# ============================================
# DIM PRODUCT
# ============================================

dim_product = (
    products_clean[
        [
            "product_id",
            "product_category_name",
            "product_name_lenght",
            "product_description_lenght",
            "product_photos_qty",
            "product_weight_g",
            "product_length_cm",
            "product_height_cm",
            "product_width_cm"
        ]
    ]
    .drop_duplicates("product_id")
    .reset_index(drop=True)
)

print("\nDIM_PRODUCT")
print("Rows:", len(dim_product))
print(
    "Unique products:",
    dim_product["product_id"].nunique()
)


# ============================================
# DIM SELLER
# ============================================

dim_seller = (
    sellers_clean[
        [
            "seller_id",
            "seller_city",
            "seller_state"
        ]
    ]
    .drop_duplicates("seller_id")
    .reset_index(drop=True)
)

print("\nDIM_SELLER")
print("Rows:", len(dim_seller))
print(
    "Unique sellers:",
    dim_seller["seller_id"].nunique()
)


# ============================================
# DIM ORDER
# ============================================

dim_order = (
    orders_clean[
        [
            "order_id",
            "customer_id",
            "order_status",
            "order_purchase_timestamp",
            "order_approved_at",
            "order_delivered_carrier_date",
            "order_delivered_customer_date",
            "order_estimated_delivery_date"
        ]
    ]
    .drop_duplicates("order_id")
    .reset_index(drop=True)
)

print("\nDIM_ORDER")
print("Rows:", len(dim_order))
print(
    "Unique orders:",
    dim_order["order_id"].nunique()
)


# ============================================
# FACT ORDER ITEMS
# ============================================

fact_order_items = (
    order_items_clean[
        [
            "order_id",
            "order_item_id",
            "product_id",
            "seller_id",
            "shipping_limit_date",
            "price",
            "freight_value"
        ]
    ]
    .copy()
    .reset_index(drop=True)
)

print("\nFACT_ORDER_ITEMS")
print("Rows:", len(fact_order_items))


# ============================================
# FACT PAYMENTS
# ============================================

fact_payments = (
    payments_clean[
        [
            "order_id",
            "payment_sequential",
            "payment_type",
            "payment_installments",
            "payment_value"
        ]
    ]
    .copy()
    .reset_index(drop=True)
)

print("\nFACT_PAYMENTS")
print("Rows:", len(fact_payments))


# ============================================
# FACT REVIEWS
# ============================================

fact_reviews = (
    reviews_clean[
        [
            "review_id",
            "order_id",
            "review_score",
            "review_creation_date",
            "review_answer_timestamp",
            "review_response_time",
            "response_time_hours",
            "response_time_group",
            "review_category",
            "comment_length",
            "comment_word_count",
            "has_comment",
            "has_title"
        ]
    ]
    .copy()
    .reset_index(drop=True)
)

print("\nFACT_REVIEWS")
print("Rows:", len(fact_reviews))


# ============================================
# MODEL SUMMARY
# ============================================

model_summary = pd.DataFrame({
    "table": [
        "Dim_Customer",
        "Dim_Product",
        "Dim_Seller",
        "Dim_Order",
        "Fact_Order_Items",
        "Fact_Payments",
        "Fact_Reviews"
    ],
    "rows": [
        len(dim_customer),
        len(dim_product),
        len(dim_seller),
        len(dim_order),
        len(fact_order_items),
        len(fact_payments),
        len(fact_reviews)
    ]
})

print("\nMODEL SUMMARY")
display(model_summary)


print("=" * 70)
print("INTEGRATED MODEL TABLE CONSTRUCTION COMPLETED")
print("=" * 70)
# Out:
# ======================================================================
# SECTION 11.5 — INTEGRATED MODEL TABLE CONSTRUCTION
# ======================================================================
#
# DIM_CUSTOMER
# Rows: 96096
# Unique customers: 96096
#
# DIM_PRODUCT
# Rows: 32951
# Unique products: 32951
#
# DIM_SELLER
# Rows: 3095
# Unique sellers: 3095
#
# DIM_ORDER
# Rows: 99441
# Unique orders: 99441
#
# FACT_ORDER_ITEMS
# Rows: 112650
#
# FACT_PAYMENTS
# Rows: 103886
#
# FACT_REVIEWS
# Rows: 99224
#
# MODEL SUMMARY
#               table    rows
# 0      Dim_Customer   96096
# 1       Dim_Product   32951
# 2        Dim_Seller    3095
# 3         Dim_Order   99441
# 4  Fact_Order_Items  112650
# 5     Fact_Payments  103886
# 6      Fact_Reviews   99224
# ======================================================================
# INTEGRATED MODEL TABLE CONSTRUCTION COMPLETED
# ======================================================================

# %%
# ============================================
# DIM CUSTOMER
# ============================================

dim_customer = (
    customers_clean[
        [
            "customer_unique_id",
            "customer_id",
            "customer_city",
            "customer_state"
        ]
    ]
    .drop_duplicates("customer_id")
    .reset_index(drop=True)
)

print("\nDIM_CUSTOMER")
print("Rows:", len(dim_customer))
print(
    "Unique customer_unique_id:",
    dim_customer["customer_unique_id"].nunique()
)

print(
    "Unique customer_id:",
    dim_customer["customer_id"].nunique()
)
# Out:
# DIM_CUSTOMER
# Rows: 99441
# Unique customer_unique_id: 96096
# Unique customer_id: 99441

# %%
# ============================================
# 11.6 FINAL INTEGRATION VALIDATION
# ============================================

print("=" * 70)
print("SECTION 11.6 — FINAL INTEGRATION VALIDATION")
print("=" * 70)


# ============================================
# 1. ROW COUNT VALIDATION
# ============================================

print("\n1. ROW COUNT VALIDATION")
print("-" * 70)

row_validation = pd.DataFrame({
    "table": [
        "Dim_Customer",
        "Dim_Product",
        "Dim_Seller",
        "Dim_Order",
        "Fact_Order_Items",
        "Fact_Payments",
        "Fact_Reviews"
    ],
    "model_rows": [
        len(dim_customer),
        len(dim_product),
        len(dim_seller),
        len(dim_order),
        len(fact_order_items),
        len(fact_payments),
        len(fact_reviews)
    ],
    "source_rows": [
        len(customers_clean),
        len(products_clean),
        len(sellers_clean),
        len(orders_clean),
        len(order_items_clean),
        len(payments_clean),
        len(reviews_clean)
    ]
})

row_validation["difference"] = (
    row_validation["model_rows"]
    - row_validation["source_rows"]
)

display(row_validation)


# ============================================
# 2. PRIMARY KEY VALIDATION
# ============================================

print("\n2. PRIMARY KEY VALIDATION")
print("-" * 70)

primary_key_checks = {
    "Dim_Customer": ("customer_id", dim_customer),
    "Dim_Product": ("product_id", dim_product),
    "Dim_Seller": ("seller_id", dim_seller),
    "Dim_Order": ("order_id", dim_order)
}

for table_name, (key, df) in primary_key_checks.items():

    print(
        f"{table_name} | {key}:",
        df[key].duplicated().sum(),
        "duplicates"
    )


# ============================================
# 3. FACT → DIMENSION KEY VALIDATION
# ============================================

print("\n3. FACT → DIMENSION KEY VALIDATION")
print("-" * 70)


# Order Items → Order

valid_order_items = fact_order_items[
    fact_order_items["order_id"].isin(
        dim_order["order_id"]
    )
]

print(
    "Fact_Order_Items → Dim_Order:",
    len(valid_order_items),
    "/",
    len(fact_order_items),
    "valid"
)


# Order Items → Product

valid_product_items = fact_order_items[
    fact_order_items["product_id"].isin(
        dim_product["product_id"]
    )
]

print(
    "Fact_Order_Items → Dim_Product:",
    len(valid_product_items),
    "/",
    len(fact_order_items),
    "valid"
)


# Order Items → Seller

valid_seller_items = fact_order_items[
    fact_order_items["seller_id"].isin(
        dim_seller["seller_id"]
    )
]

print(
    "Fact_Order_Items → Dim_Seller:",
    len(valid_seller_items),
    "/",
    len(fact_order_items),
    "valid"
)


# Payments → Order

valid_payments = fact_payments[
    fact_payments["order_id"].isin(
        dim_order["order_id"]
    )
]

print(
    "Fact_Payments → Dim_Order:",
    len(valid_payments),
    "/",
    len(fact_payments),
    "valid"
)


# Reviews → Order

valid_reviews = fact_reviews[
    fact_reviews["order_id"].isin(
        dim_order["order_id"]
    )
]

print(
    "Fact_Reviews → Dim_Order:",
    len(valid_reviews),
    "/",
    len(fact_reviews),
    "valid"
)


# Orders → Customer

valid_orders = dim_order[
    dim_order["customer_id"].isin(
        dim_customer["customer_id"]
    )
]

print(
    "Dim_Order → Dim_Customer:",
    len(valid_orders),
    "/",
    len(dim_order),
    "valid"
)


# ============================================
# 4. FOREIGN KEY ORPHAN CHECK
# ============================================

print("\n4. ORPHAN KEY CHECK")
print("-" * 70)

print(
    "Orphan order-item orders:",
    len(fact_order_items)
    - len(valid_order_items)
)

print(
    "Orphan order-item products:",
    len(fact_order_items)
    - len(valid_product_items)
)

print(
    "Orphan order-item sellers:",
    len(fact_order_items)
    - len(valid_seller_items)
)

print(
    "Orphan payment orders:",
    len(fact_payments)
    - len(valid_payments)
)

print(
    "Orphan review orders:",
    len(fact_reviews)
    - len(valid_reviews)
)

print(
    "Orphan customer orders:",
    len(dim_order)
    - len(valid_orders)
)


# ============================================
# 5. FACT TABLE DUPLICATE CHECK
# ============================================

print("\n5. FACT TABLE DUPLICATE CHECK")
print("-" * 70)

print(
    "Exact duplicate order-item rows:",
    fact_order_items.duplicated().sum()
)

print(
    "Exact duplicate payment rows:",
    fact_payments.duplicated().sum()
)

print(
    "Exact duplicate review rows:",
    fact_reviews.duplicated().sum()
)


# ============================================
# 6. CUSTOMER IDENTITY VALIDATION
# ============================================

print("\n6. CUSTOMER IDENTITY VALIDATION")
print("-" * 70)

print(
    "Customer IDs:",
    dim_customer["customer_id"].nunique()
)

print(
    "Unique Customers:",
    dim_customer["customer_unique_id"].nunique()
)

print(
    "Repeat Customers:",
    (
        dim_customer
        .groupby("customer_unique_id")
        ["customer_id"]
        .nunique()
        .gt(1)
        .sum()
    )
)


# ============================================
# 7. FINAL MODEL SUMMARY
# ============================================

print("\n7. FINAL MODEL SUMMARY")
print("-" * 70)

final_model_summary = pd.DataFrame({
    "table": [
        "Dim_Customer",
        "Dim_Product",
        "Dim_Seller",
        "Dim_Order",
        "Fact_Order_Items",
        "Fact_Payments",
        "Fact_Reviews"
    ],
    "rows": [
        len(dim_customer),
        len(dim_product),
        len(dim_seller),
        len(dim_order),
        len(fact_order_items),
        len(fact_payments),
        len(fact_reviews)
    ]
})

display(final_model_summary)


# ============================================
# 8. FINAL STATUS
# ============================================

print("\n" + "=" * 70)
print("FINAL INTEGRATION VALIDATION COMPLETED")
print("=" * 70)
# Out:
# ======================================================================
# SECTION 11.6 — FINAL INTEGRATION VALIDATION
# ======================================================================
#
# 1. ROW COUNT VALIDATION
# ----------------------------------------------------------------------
#               table  model_rows  source_rows  difference
# 0      Dim_Customer       99441        99441           0
# 1       Dim_Product       32951        32951           0
# 2        Dim_Seller        3095         3095           0
# 3         Dim_Order       99441        99441           0
# 4  Fact_Order_Items      112650       112650           0
# 5     Fact_Payments      103886       103886           0
# 6      Fact_Reviews       99224        99224           0
# 2. PRIMARY KEY VALIDATION
# ----------------------------------------------------------------------
# Dim_Customer | customer_id: 0 duplicates
# Dim_Product | product_id: 0 duplicates
# Dim_Seller | seller_id: 0 duplicates
# Dim_Order | order_id: 0 duplicates
#
# 3. FACT → DIMENSION KEY VALIDATION
# ----------------------------------------------------------------------
# Fact_Order_Items → Dim_Order: 112650 / 112650 valid
# Fact_Order_Items → Dim_Product: 112650 / 112650 valid
# Fact_Order_Items → Dim_Seller: 112650 / 112650 valid
# Fact_Payments → Dim_Order: 103886 / 103886 valid
# Fact_Reviews → Dim_Order: 99224 / 99224 valid
# Dim_Order → Dim_Customer: 99441 / 99441 valid
#
# 4. ORPHAN KEY CHECK
# ----------------------------------------------------------------------
# Orphan order-item orders: 0
# Orphan order-item products: 0
# Orphan order-item sellers: 0
# Orphan payment orders: 0
# Orphan review orders: 0
# Orphan customer orders: 0
#
# 5. FACT TABLE DUPLICATE CHECK
# ----------------------------------------------------------------------
# Exact duplicate order-item rows: 0
# Exact duplicate payment rows: 0
# Exact duplicate review rows: 0
#
# 6. CUSTOMER IDENTITY VALIDATION
# ----------------------------------------------------------------------
# Customer IDs: 99441
# Unique Customers: 96096
# Repeat Customers: 2997
#
# 7. FINAL MODEL SUMMARY
# ----------------------------------------------------------------------
#               table    rows
# 0      Dim_Customer   99441
# 1       Dim_Product   32951
# 2        Dim_Seller    3095
# 3         Dim_Order   99441
# 4  Fact_Order_Items  112650
# 5     Fact_Payments  103886
# 6      Fact_Reviews   99224
# ======================================================================
# FINAL INTEGRATION VALIDATION COMPLETED
# ======================================================================

# %%
# ============================================
# SECTION 12 — POWER BI DATA MODEL
# 12.1 DATE DIMENSION CREATION
# ============================================

print("=" * 70)
print("SECTION 12.1 — DATE DIMENSION CREATION")
print("=" * 70)


# ============================================
# DETERMINE DATE RANGE
# ============================================

date_columns = [
    "order_purchase_timestamp",
    "order_approved_at",
    "order_delivered_carrier_date",
    "order_delivered_customer_date",
    "order_estimated_delivery_date"
]

all_dates = pd.concat([
    orders_clean[col]
    for col in date_columns
]).dropna()

min_date = all_dates.min().normalize()
max_date = all_dates.max().normalize()

print("\nDATE RANGE")
print("Minimum date:", min_date)
print("Maximum date:", max_date)


# ============================================
# CREATE DATE TABLE
# ============================================

date_range = pd.date_range(
    start=min_date,
    end=max_date,
    freq="D"
)

dim_date = pd.DataFrame({
    "date": date_range
})


# ============================================
# DATE ATTRIBUTES
# ============================================

dim_date["year"] = dim_date["date"].dt.year

dim_date["quarter"] = (
    "Q" +
    dim_date["date"].dt.quarter.astype(str)
)

dim_date["month_number"] = (
    dim_date["date"].dt.month
)

dim_date["month_name"] = (
    dim_date["date"].dt.month_name()
)

dim_date["month_short"] = (
    dim_date["date"].dt.strftime("%b")
)

dim_date["year_month"] = (
    dim_date["date"].dt.to_period("M").astype(str)
)

dim_date["week_number"] = (
    dim_date["date"].dt.isocalendar().week.astype(int)
)

dim_date["day"] = (
    dim_date["date"].dt.day
)

dim_date["day_name"] = (
    dim_date["date"].dt.day_name()
)

dim_date["day_of_week"] = (
    dim_date["date"].dt.dayofweek + 1
)

dim_date["is_weekend"] = (
    dim_date["day_of_week"] >= 6
)


# ============================================
# SORTING COLUMNS
# ============================================

dim_date["month_year_sort"] = (
    dim_date["year"] * 100
    + dim_date["month_number"]
)


# ============================================
# VALIDATION
# ============================================

print("\nDATE DIMENSION VALIDATION")

print(
    "Rows:",
    len(dim_date)
)

print(
    "Unique dates:",
    dim_date["date"].nunique()
)

print(
    "Duplicate dates:",
    dim_date["date"].duplicated().sum()
)

print(
    "Missing dates:",
    dim_date["date"].isna().sum()
)


# ============================================
# SAMPLE
# ============================================

print("\nDATE DIMENSION SAMPLE")

display(
    dim_date.head(10)
)


# ============================================
# FINAL STATUS
# ============================================

print("=" * 70)
print("12.1 DATE DIMENSION CREATION COMPLETED")
print("=" * 70)
# Out:
# ======================================================================
# SECTION 12.1 — DATE DIMENSION CREATION
# ======================================================================
#
# DATE RANGE
# Minimum date: 2016-09-04 00:00:00
# Maximum date: 2018-11-12 00:00:00
#
# DATE DIMENSION VALIDATION
# Rows: 800
# Unique dates: 800
# Duplicate dates: 0
# Missing dates: 0
#
# DATE DIMENSION SAMPLE
#         date  year quarter  month_number month_name month_short year_month  \
# 0 2016-09-04  2016      Q3             9  September         Sep    2016-09
# 1 2016-09-05  2016      Q3             9  September         Sep    2016-09
# 2 2016-09-06  2016      Q3             9  September         Sep    2016-09
# 3 2016-09-07  2016      Q3             9  September         Sep    2016-09
# 4 2016-09-08  2016      Q3             9  September         Sep    2016-09
# 5 2016-09-09  2016      Q3             9  September         Sep    2016-09
# 6 2016-09-10  2016      Q3             9  September         Sep    2016-09
# 7 2016-09-11  2016      Q3             9  September         Sep    2016-09
# 8 2016-09-12  2016      Q3             9  September         Sep    2016-09
# 9 2016-09-13  2016      Q3             9  September         Sep    2016-09
#
#    week_number  day   day_name  day_of_week  is_weekend  month_year_sort
# 0           35    4     Sunday            7        True           201609
# 1           36    5     Monday            1       False           201609
# 2           36    6    Tuesday            2       False           201609
# 3           36    7  Wednesday            3       False           201609
# 4           36    8   Thursday            4       False           201609
# 5           36    9     Friday            5       False           201609
# 6           36   10   Saturday            6        True           201609
# 7           36   11     Sunday            7        True           201609
# 8           37   12     Monday            1       False           201609
# 9           37   13    Tuesday            2       False           201609
# ======================================================================
# 12.1 DATE DIMENSION CREATION COMPLETED
# ======================================================================

# %%
# ============================================
# 12.2 DATE DIMENSION RELATIONSHIP VALIDATION
# ============================================

print("=" * 70)
print("SECTION 12.2 — DATE DIMENSION RELATIONSHIP VALIDATION")
print("=" * 70)


# ============================================
# DATE COVERAGE VALIDATION
# ============================================

date_min = dim_date["date"].min()
date_max = dim_date["date"].max()

print("\nDATE DIMENSION RANGE")
print("Minimum date:", date_min)
print("Maximum date:", date_max)


# ============================================
# ORDER DATE COVERAGE
# ============================================

order_date_columns = [
    "order_purchase_timestamp",
    "order_approved_at",
    "order_delivered_carrier_date",
    "order_delivered_customer_date",
    "order_estimated_delivery_date"
]

print("\nORDER DATE COVERAGE")
print("-" * 70)

for col in order_date_columns:

    valid_dates = orders_clean[col].dropna()

    print(f"\n{col}")
    print("Minimum:", valid_dates.min())
    print("Maximum:", valid_dates.max())

    outside_range = (
        (valid_dates.dt.date < date_min.date()) |
        (valid_dates.dt.date > date_max.date())
    ).sum()

    print("Dates outside Dim_Date range:", outside_range)


# ============================================
# PURCHASE DATE KEY VALIDATION
# ============================================

orders_with_purchase_date = (
    orders_clean["order_purchase_timestamp"]
    .dropna()
    .dt.normalize()
)

date_keys = set(
    dim_date["date"]
    .dt.normalize()
)

valid_purchase_dates = orders_with_purchase_date.isin(date_keys).sum()

print("\nPURCHASE DATE KEY VALIDATION")
print("-" * 70)
print(
    "Purchase dates found in Dim_Date:",
    valid_purchase_dates
)
print(
    "Purchase dates missing from Dim_Date:",
    len(orders_with_purchase_date) - valid_purchase_dates
)


# ============================================
# DATE DIMENSION DUPLICATE VALIDATION
# ============================================

print("\nDATE DIMENSION KEY VALIDATION")
print("-" * 70)

print(
    "Duplicate date keys:",
    dim_date["date"].duplicated().sum()
)

print(
    "Total date rows:",
    len(dim_date)
)

print(
    "Unique date keys:",
    dim_date["date"].nunique()
)


# ============================================
# FINAL STATUS
# ============================================

print("\n" + "=" * 70)
print("DATE DIMENSION RELATIONSHIP VALIDATION COMPLETED")
print("=" * 70)
# Out:
# ======================================================================
# SECTION 12.2 — DATE DIMENSION RELATIONSHIP VALIDATION
# ======================================================================
#
# DATE DIMENSION RANGE
# Minimum date: 2016-09-04 00:00:00
# Maximum date: 2018-11-12 00:00:00
#
# ORDER DATE COVERAGE
# ----------------------------------------------------------------------
#
# order_purchase_timestamp
# Minimum: 2016-09-04 21:15:19
# Maximum: 2018-10-17 17:30:18
# Dates outside Dim_Date range: 0
#
# order_approved_at
# Minimum: 2016-09-15 12:16:38
# Maximum: 2018-09-03 17:40:06
# Dates outside Dim_Date range: 0
#
# order_delivered_carrier_date
# Minimum: 2016-10-08 10:34:01
# Maximum: 2018-09-11 19:48:28
# Dates outside Dim_Date range: 0
#
# order_delivered_customer_date
# Minimum: 2016-10-11 13:46:32
# Maximum: 2018-10-17 13:22:46
# Dates outside Dim_Date range: 0
#
# order_estimated_delivery_date
# Minimum: 2016-09-30 00:00:00
# Maximum: 2018-11-12 00:00:00
# Dates outside Dim_Date range: 0
#
# PURCHASE DATE KEY VALIDATION
# ----------------------------------------------------------------------
# Purchase dates found in Dim_Date: 99441
# Purchase dates missing from Dim_Date: 0
#
# DATE DIMENSION KEY VALIDATION
# ----------------------------------------------------------------------
# Duplicate date keys: 0
# Total date rows: 800
# Unique date keys: 800
#
# ======================================================================
# DATE DIMENSION RELATIONSHIP VALIDATION COMPLETED
# ======================================================================

# %%
# ============================================
# 12.3 — CREATE ORDER DATE KEY
# ============================================

dim_order["order_purchase_date"] = (
    dim_order["order_purchase_timestamp"]
    .dt.normalize()
)

print("Order purchase date key created.")

print(
    "Missing purchase date keys:",
    dim_order["order_purchase_date"].isna().sum()
)

print(
    "Unique purchase dates:",
    dim_order["order_purchase_date"].nunique()
)
# Out:
# Order purchase date key created.
# Missing purchase date keys: 0
# Unique purchase dates: 634

# %%
# ============================================
# DATE KEY RELATIONSHIP VALIDATION
# ============================================

valid_date_keys = dim_order["order_purchase_date"].isin(
    dim_date["date"]
)

print("=" * 70)
print("SECTION 12.3 — DATE KEY VALIDATION")
print("=" * 70)

print(
    "Valid order date keys:",
    valid_date_keys.sum()
)

print(
    "Invalid order date keys:",
    (~valid_date_keys).sum()
)

print("=" * 70)
print("DATE KEY VALIDATION COMPLETED")
print("=" * 70)
# Out:
# ======================================================================
# SECTION 12.3 — DATE KEY VALIDATION
# ======================================================================
# Valid order date keys: 99441
# Invalid order date keys: 0
# ======================================================================
# DATE KEY VALIDATION COMPLETED
# ======================================================================

# %%
# ============================================
# SECTION 13.1 — FINAL MODEL TABLE VALIDATION
# ============================================

print("=" * 70)
print("SECTION 13.1 — FINAL MODEL TABLE VALIDATION")
print("=" * 70)


# ============================================================
# 0. REBUILD DIM_CUSTOMER CORRECTLY
# ============================================================

dim_customer = (
    customers_clean[
        [
            "customer_unique_id",
            "customer_city",
            "customer_state"
        ]
    ]
    .drop_duplicates(subset=["customer_unique_id"])
    .reset_index(drop=True)
)


# ============================================================
# 1. ADD CUSTOMER_UNIQUE_ID TO DIM_ORDER
# ============================================================

customer_mapping = (
    customers_clean[
        [
            "customer_id",
            "customer_unique_id"
        ]
    ]
    .drop_duplicates(subset=["customer_id"])
)


dim_order = (
    orders_clean[
        [
            "order_id",
            "customer_id",
            "order_status",
            "order_purchase_timestamp",
            "order_approved_at",
            "order_delivered_carrier_date",
            "order_delivered_customer_date",
            "order_estimated_delivery_date"
        ]
    ]
    .drop_duplicates(subset=["order_id"])
    .reset_index(drop=True)
)


# Merge customer_unique_id into Dim_Order

dim_order = dim_order.merge(
    customer_mapping,
    on="customer_id",
    how="left",
    validate="one_to_one"
)


# Create purchase date

dim_order["order_purchase_date"] = (
    dim_order["order_purchase_timestamp"]
    .dt.normalize()
)


# ============================================================
# 2. DIMENSION TABLE VALIDATION
# ============================================================

print("\n")
print("1. DIMENSION TABLE VALIDATION")
print("-" * 70)


dimension_checks = {

    "Dim_Customer": (
        dim_customer,
        "customer_unique_id"
    ),

    "Dim_Product": (
        dim_product,
        "product_id"
    ),

    "Dim_Seller": (
        dim_seller,
        "seller_id"
    ),

    "Dim_Order": (
        dim_order,
        "order_id"
    ),

    "Dim_Date": (
        dim_date,
        "date"
    )
}


dimension_results = []


for table_name, (df, key) in dimension_checks.items():

    rows = len(df)

    unique_keys = df[key].nunique()

    duplicate_keys = df[key].duplicated().sum()

    missing_keys = df[key].isna().sum()

    status = (
        "PASS"
        if duplicate_keys == 0 and missing_keys == 0
        else "FAIL"
    )

    dimension_results.append({
        "table": table_name,
        "rows": rows,
        "unique_keys": unique_keys,
        "duplicate_keys": duplicate_keys,
        "missing_keys": missing_keys,
        "status": status
    })


dimension_validation = pd.DataFrame(dimension_results)

display(dimension_validation)


# ============================================================
# 3. FACT TABLE ROW COUNT VALIDATION
# ============================================================

print("\n")
print("2. FACT TABLE VALIDATION")
print("-" * 70)


fact_results = []


for table_name, df in {
    "Fact_Order_Items": fact_order_items,
    "Fact_Payments": fact_payments,
    "Fact_Reviews": fact_reviews
}.items():

    fact_results.append({
        "table": table_name,
        "rows": len(df),
        "exact_duplicate_rows": df.duplicated().sum()
    })


fact_validation = pd.DataFrame(fact_results)

display(fact_validation)


# ============================================================
# 4. FOREIGN KEY VALIDATION
# ============================================================

print("\n")
print("3. FACT → DIMENSION KEY VALIDATION")
print("-" * 70)


# Order Items → Orders

order_items_orders_valid = (
    fact_order_items["order_id"]
    .isin(dim_order["order_id"])
    .sum()
)


# Order Items → Products

order_items_products_valid = (
    fact_order_items["product_id"]
    .isin(dim_product["product_id"])
    .sum()
)


# Order Items → Sellers

order_items_sellers_valid = (
    fact_order_items["seller_id"]
    .isin(dim_seller["seller_id"])
    .sum()
)


# Payments → Orders

payments_orders_valid = (
    fact_payments["order_id"]
    .isin(dim_order["order_id"])
    .sum()
)


# Reviews → Orders

reviews_orders_valid = (
    fact_reviews["order_id"]
    .isin(dim_order["order_id"])
    .sum()
)


# Orders → Customers

orders_customers_valid = (
    dim_order["customer_id"]
    .isin(customers_clean["customer_id"])
    .sum()
)


# Orders → Customer Unique ID

orders_unique_customers_valid = (
    dim_order["customer_unique_id"]
    .isin(dim_customer["customer_unique_id"])
    .sum()
)


# Orders → Date

orders_dates_valid = (
    dim_order["order_purchase_date"]
    .isin(dim_date["date"])
    .sum()
)


foreign_key_results = pd.DataFrame({

    "relationship": [
        "Fact_Order_Items → Dim_Order",
        "Fact_Order_Items → Dim_Product",
        "Fact_Order_Items → Dim_Seller",
        "Fact_Payments → Dim_Order",
        "Fact_Reviews → Dim_Order",
        "Dim_Order → Customer",
        "Dim_Order → Dim_Customer",
        "Dim_Order → Dim_Date"
    ],

    "valid_rows": [
        order_items_orders_valid,
        order_items_products_valid,
        order_items_sellers_valid,
        payments_orders_valid,
        reviews_orders_valid,
        orders_customers_valid,
        orders_unique_customers_valid,
        orders_dates_valid
    ],

    "total_rows": [
        len(fact_order_items),
        len(fact_order_items),
        len(fact_order_items),
        len(fact_payments),
        len(fact_reviews),
        len(dim_order),
        len(dim_order),
        len(dim_order)
    ]
})


foreign_key_results["invalid_rows"] = (
    foreign_key_results["total_rows"]
    - foreign_key_results["valid_rows"]
)


foreign_key_results["status"] = (
    foreign_key_results["invalid_rows"]
    .eq(0)
    .map({
        True: "PASS",
        False: "FAIL"
    })
)


display(foreign_key_results)


# ============================================================
# 5. ORPHAN KEY VALIDATION
# ============================================================

print("\n")
print("4. ORPHAN KEY VALIDATION")
print("-" * 70)


orphan_results = {

    "Order-item orders": (
        ~fact_order_items["order_id"]
        .isin(dim_order["order_id"])
    ).sum(),

    "Order-item products": (
        ~fact_order_items["product_id"]
        .isin(dim_product["product_id"])
    ).sum(),

    "Order-item sellers": (
        ~fact_order_items["seller_id"]
        .isin(dim_seller["seller_id"])
    ).sum(),

    "Payment orders": (
        ~fact_payments["order_id"]
        .isin(dim_order["order_id"])
    ).sum(),

    "Review orders": (
        ~fact_reviews["order_id"]
        .isin(dim_order["order_id"])
    ).sum(),

    "Customer orders": (
        ~dim_order["customer_unique_id"]
        .isin(dim_customer["customer_unique_id"])
    ).sum(),

    "Order dates": (
        ~dim_order["order_purchase_date"]
        .isin(dim_date["date"])
    ).sum()
}


for relationship, orphan_count in orphan_results.items():

    print(
        f"{relationship:25} : "
        f"{orphan_count}"
    )


# ============================================================
# 6. CRITICAL NULL VALIDATION
# ============================================================

print("\n")
print("5. CRITICAL NULL VALIDATION")
print("-" * 70)


critical_columns = {

    "Dim_Customer": (
        dim_customer,
        [
            "customer_unique_id"
        ]
    ),

    "Dim_Product": (
        dim_product,
        [
            "product_id"
        ]
    ),

    "Dim_Seller": (
        dim_seller,
        [
            "seller_id"
        ]
    ),

    "Dim_Order": (
        dim_order,
        [
            "order_id",
            "customer_id",
            "customer_unique_id",
            "order_purchase_date"
        ]
    ),

    "Dim_Date": (
        dim_date,
        [
            "date"
        ]
    ),

    "Fact_Order_Items": (
        fact_order_items,
        [
            "order_id",
            "product_id",
            "seller_id"
        ]
    ),

    "Fact_Payments": (
        fact_payments,
        [
            "order_id"
        ]
    ),

    "Fact_Reviews": (
        fact_reviews,
        [
            "review_id",
            "order_id"
        ]
    )
}


null_results = []


for table_name, (df, columns) in critical_columns.items():

    for column in columns:

        missing_count = df[column].isna().sum()

        null_results.append({

            "table": table_name,

            "column": column,

            "missing_count": missing_count,

            "status": (
                "PASS"
                if missing_count == 0
                else "CHECK"
            )
        })


null_validation = pd.DataFrame(null_results)

display(null_validation)


# ============================================================
# 7. EXACT DUPLICATE ROW VALIDATION
# ============================================================

print("\n")
print("6. EXACT DUPLICATE ROW VALIDATION")
print("-" * 70)


duplicate_results = []


for table_name, df in {

    "Dim_Customer": dim_customer,

    "Dim_Product": dim_product,

    "Dim_Seller": dim_seller,

    "Dim_Order": dim_order,

    "Dim_Date": dim_date,

    "Fact_Order_Items": fact_order_items,

    "Fact_Payments": fact_payments,

    "Fact_Reviews": fact_reviews

}.items():

    duplicate_count = df.duplicated().sum()

    duplicate_results.append({

        "table": table_name,

        "exact_duplicate_rows": duplicate_count,

        "status": (
            "PASS"
            if duplicate_count == 0
            else "CHECK"
        )
    })


duplicate_validation = pd.DataFrame(duplicate_results)

display(duplicate_validation)


# ============================================================
# 8. CUSTOMER IDENTITY VALIDATION
# ============================================================

print("\n")
print("7. CUSTOMER IDENTITY VALIDATION")
print("-" * 70)


total_customer_ids = (
    customers_clean["customer_id"]
    .nunique()
)


unique_customers = (
    customers_clean["customer_unique_id"]
    .nunique()
)


repeat_customer_count = (
    customers_clean
    .groupby("customer_unique_id")
    ["customer_id"]
    .nunique()
    .gt(1)
    .sum()
)


print(
    "Customer IDs:",
    total_customer_ids
)


print(
    "Unique Customers:",
    unique_customers
)


print(
    "Repeat Customers:",
    repeat_customer_count
)


print(
    "Dim_Customer rows:",
    len(dim_customer)
)


print(
    "Dim_Customer unique customer_unique_id:",
    dim_customer["customer_unique_id"].nunique()
)


# ============================================================
# 9. DIMENSION ROW COUNT SUMMARY
# ============================================================

print("\n")
print("8. FINAL MODEL ROW COUNTS")
print("-" * 70)


model_summary = pd.DataFrame({

    "table": [

        "Dim_Customer",
        "Dim_Product",
        "Dim_Seller",
        "Dim_Order",
        "Dim_Date",
        "Fact_Order_Items",
        "Fact_Payments",
        "Fact_Reviews"

    ],

    "rows": [

        len(dim_customer),
        len(dim_product),
        len(dim_seller),
        len(dim_order),
        len(dim_date),
        len(fact_order_items),
        len(fact_payments),
        len(fact_reviews)

    ]
})


display(model_summary)


# ============================================================
# 10. FINAL PASS / FAIL CHECK
# ============================================================

print("\n")
print("=" * 70)
print("FINAL MODEL VALIDATION STATUS")
print("=" * 70)


dimension_pass = (
    dimension_validation["status"]
    .eq("PASS")
    .all()
)


foreign_key_pass = (
    foreign_key_results["status"]
    .eq("PASS")
    .all()
)


orphan_pass = (
    all(
        count == 0
        for count in orphan_results.values()
    )
)


critical_null_pass = (
    null_validation["status"]
    .eq("PASS")
    .all()
)


duplicate_pass = (
    duplicate_validation["status"]
    .eq("PASS")
    .all()
)


customer_dimension_pass = (
    len(dim_customer) == 96096
    and
    dim_customer["customer_unique_id"].nunique() == 96096
    and
    dim_customer["customer_unique_id"].duplicated().sum() == 0
)


if all([
    dimension_pass,
    foreign_key_pass,
    orphan_pass,
    critical_null_pass,
    duplicate_pass,
    customer_dimension_pass
]):

    print("STATUS: PASS")

    print(
        "All model validation checks completed successfully."
    )

else:

    print("STATUS: CHECK")

    print(
        "One or more validation checks require review."
    )


print("=" * 70)
print("SECTION 13.1 VALIDATION COMPLETED")
print("=" * 70)
# Out:
# ======================================================================
# SECTION 13.1 — FINAL MODEL TABLE VALIDATION
# ======================================================================
#
# 1. DIMENSION TABLES
# ----------------------------------------------------------------------
# Dim_Customer    | Rows:  99,441 | Key duplicates: 3345
# Dim_Product     | Rows:  32,951 | Key duplicates:   0
# Dim_Seller      | Rows:   3,095 | Key duplicates:   0
# Dim_Order       | Rows:  99,441 | Key duplicates:   0
# Dim_Date        | Rows:     800 | Key duplicates:   0
#
# 2. FACT TABLES
# ----------------------------------------------------------------------
# Fact_Order_Items   | Rows: 112,650
# Fact_Payments      | Rows: 103,886
# Fact_Reviews       | Rows:  99,224
#
# 3. FOREIGN KEY VALIDATION
# ----------------------------------------------------------------------
# Order Items → Orders: 112650 / 112650
# Order Items → Products: 112650 / 112650
# Order Items → Sellers: 112650 / 112650
# Payments → Orders: 103886 / 103886
# Reviews → Orders: 99224 / 99224
# Orders → Customers: 99441 / 99441
# Orders → Dates: 99441 / 99441
#
# 4. CRITICAL NULL CHECK
# ----------------------------------------------------------------------
# Dim_Customer       | customer_unique_id             | Missing: 0
# Dim_Product        | product_id                     | Missing: 0
# Dim_Seller         | seller_id                      | Missing: 0
# Dim_Order          | order_id                       | Missing: 0
# Dim_Order          | customer_id                    | Missing: 0
# Dim_Order          | order_purchase_date            | Missing: 0
# Dim_Date           | date                           | Missing: 0
# Fact_Order_Items   | order_id                       | Missing: 0
# Fact_Order_Items   | product_id                     | Missing: 0
# Fact_Order_Items   | seller_id                      | Missing: 0
# Fact_Payments      | order_id                       | Missing: 0
# Fact_Reviews       | review_id                      | Missing: 0
# Fact_Reviews       | order_id                       | Missing: 0
#
# ======================================================================
# SECTION 13.1 VALIDATION COMPLETED
# ======================================================================
